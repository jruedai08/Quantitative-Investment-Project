# %%
import pandas as pd
import numpy as np
from scipy import stats

def read_excel_file(file_path):
    """
    读取Excel文件，处理编码问题
    """
    try:
        return pd.read_excel(file_path)
    except Exception as e:
        print(f"读取文件 {file_path} 时出错: {str(e)}")
        raise

def calculate_portfolio_metrics(returns_series, rf_series):
    """计算投资组合指标"""
    try:
        start_date = pd.Timestamp('2007-01-01')
        end_date = pd.Timestamp('2023-12-31')
        
        # 确保索引是datetime
        returns_series.index = pd.to_datetime(returns_series.index)
        rf_series.index = pd.to_datetime(rf_series.index)
        
        # 数据过滤
        returns = returns_series.loc[start_date:end_date].astype(float)
        rf_rates = rf_series.loc[start_date:end_date].astype(float)
        
        if len(returns) == 0:
            print("警告：所选时间范围内没有收益率数据")
            return {k: np.nan for k in ['mean_monthly_return', 'annualized_return', 'monthly_std_dev', 
                                      'annualized_std_dev', 't_statistic', 't_stat_p_value', 
                                      'annualized_sharpe_ratio', 'maximum_drawdown']}
        
        mean_return = returns.mean()
        std_dev = returns.std()
        t_stat = (mean_return) / (std_dev / np.sqrt(len(returns)))
        p_value = 2 * (1 - stats.t.cdf(abs(t_stat), len(returns)-1))
        
        annual_factor = 12
        annual_return = mean_return * annual_factor
        annual_rf = rf_rates.mean() * annual_factor
        annual_std = std_dev * np.sqrt(annual_factor)
        sharpe_ratio = (annual_return - annual_rf) / annual_std if annual_std != 0 else np.nan
        
        cumulative_returns = (1 + returns).cumprod()
        rolling_max = cumulative_returns.expanding().max()
        drawdowns = (cumulative_returns - rolling_max) / rolling_max
        max_drawdown = drawdowns.min()
        
        return {
            'mean_monthly_return': mean_return,
            'annualized_return': annual_return,
            'monthly_std_dev': std_dev,
            'annualized_std_dev': annual_std,
            't_statistic': t_stat,
            't_stat_p_value': p_value,
            'annualized_sharpe_ratio': sharpe_ratio,
            'maximum_drawdown': max_drawdown
        }
        
    except Exception as e:
        print(f"计算投资组合指标时出错: {str(e)}")
        return {k: np.nan for k in ['mean_monthly_return', 'annualized_return', 'monthly_std_dev', 
                                  'annualized_std_dev', 't_statistic', 't_stat_p_value', 
                                  'annualized_sharpe_ratio', 'maximum_drawdown']}

def calculate_ic(indicator_file, indicator_config, portfolio_name):
    """计算IC: (1/T) * sum(Corr(X_t, R_{t+1}))"""
    try:
        df = read_excel_file(indicator_file)
        df[indicator_config['date_col']] = pd.to_datetime(df[indicator_config['date_col']])
        
        # 时间范围过滤
        date_mask = (df[indicator_config['date_col']] >= '2007-01-01') & \
                   (df[indicator_config['date_col']] <= '2023-12-31')
        df = df[date_mask]
        
        if len(df) == 0:
            print(f"警告：{portfolio_name} 在指定时间范围内没有数据")
            return {'ic_mean': np.nan, 'ic_std': np.nan, 'ic_ir': np.nan}
        
        # 异常值处理
        df[indicator_config['value_col']] = df[indicator_config['value_col']].replace([np.inf, -np.inf], np.nan)
        df[indicator_config['return_col']] = df[indicator_config['return_col']].replace([np.inf, -np.inf], np.nan)
        
        # 截面标准化
        df['indicator_std'] = df.groupby(indicator_config['date_col'])[indicator_config['value_col']].transform(
            lambda x: (x - x.mean()) / x.std()
        )
        
        df = df.sort_values(indicator_config['date_col'])
        unique_dates = df[indicator_config['date_col']].unique()
        correlations = []
        
        for t in range(len(unique_dates)-1):
            current_date = unique_dates[t]
            next_date = unique_dates[t+1]
            
            current_period = df[df[indicator_config['date_col']] == current_date]
            next_period = df[df[indicator_config['date_col']] == next_date]
            
            merged = pd.merge(
                current_period[[indicator_config['stock_col'], 'indicator_std']],
                next_period[[indicator_config['stock_col'], indicator_config['return_col']]],
                on=indicator_config['stock_col']
            )
            
            if len(merged) >= 30:
                corr = stats.spearmanr(
                    merged['indicator_std'].dropna(), 
                    merged[indicator_config['return_col']].dropna()
                )[0]
                if not np.isnan(corr):
                    correlations.append(corr)
                    print(f"期间 {current_date.strftime('%Y-%m')} -> {next_date.strftime('%Y-%m')}: "
                          f"样本数={len(merged)}, IC={corr:.4f}")
        
        if not correlations:
            print(f"警告: {portfolio_name} 未能计算出有效的IC值")
            return {'ic_mean': np.nan, 'ic_std': np.nan, 'ic_ir': np.nan}
        
        ic_mean = np.mean(correlations)
        ic_std = np.std(correlations)
        ic_ir = ic_mean / ic_std if ic_std != 0 else 0
        
        print(f"\n{portfolio_name} IC统计:")
        print(f"计算期数: {len(correlations)}")
        print(f"IC均值: {ic_mean:.4f}")
        print(f"IC标准差: {ic_std:.4f}")
        print(f"IC_IR: {ic_ir:.4f}")
        
        return {
            'ic_mean': ic_mean,
            'ic_std': ic_std,
            'ic_ir': ic_ir
        }
        
    except Exception as e:
        print(f"IC计算出错: {str(e)}")
        return {'ic_mean': np.nan, 'ic_std': np.nan, 'ic_ir': np.nan}

def process_portfolios(portfolio_configs, rf_config, output_file):
    """处理投资组合并计算指标"""
    try:
        rf_df = pd.read_csv(rf_config['file'], encoding='utf-8-sig')
        rf_df[rf_config['date_col']] = pd.to_datetime(rf_df[rf_config['date_col']])
        rf_df = rf_df.set_index(rf_config['date_col'])
        rf_series = rf_df[rf_config['rate_col']]
        
        all_metrics = []
        
        for config in portfolio_configs:
            try:
                print(f"\n处理投资组合: {config['name']}")
                
                portfolio_df = read_excel_file(config['portfolio_file'])
                portfolio_df[config['portfolio']['date_col']] = pd.to_datetime(
                    portfolio_df[config['portfolio']['date_col']]
                )
                portfolio_df = portfolio_df.set_index(config['portfolio']['date_col']).sort_index()
                
                # 市值加权组合
                vw_metrics = calculate_portfolio_metrics(
                    portfolio_df[config['portfolio']['vw_return_col']], 
                    rf_series
                )
                
                # 计算IC（市值加权和等权重共用相同的IC）
                ic_metrics = calculate_ic(
                    config['indicator_file'],
                    config['indicator'],
                    config['name']
                )
                
                vw_metrics.update(ic_metrics)
                vw_metrics['portfolio_name'] = f"{config['name']}_VW"
                vw_metrics['weight_scheme'] = '市值加权'
                all_metrics.append(vw_metrics)
                
                # 等权重组合
                ew_metrics = calculate_portfolio_metrics(
                    portfolio_df[config['portfolio']['ew_return_col']], 
                    rf_series
                )
                
                ew_metrics.update(ic_metrics)  # 使用相同的IC
                ew_metrics['portfolio_name'] = f"{config['name']}_EW"
                ew_metrics['weight_scheme'] = '等权重'
                all_metrics.append(ew_metrics)
                
            except Exception as e:
                print(f"处理投资组合 {config['name']} 时出错: {str(e)}")
                continue
        
        if not all_metrics:
            raise ValueError("没有成功处理任何投资组合")
        
        results_df = pd.DataFrame(all_metrics)
        
        cols = ['portfolio_name', 'weight_scheme'] + [
            col for col in results_df.columns 
            if col not in ['portfolio_name', 'weight_scheme']
        ]
        results_df = results_df[cols]
        
        chinese_columns = {
            'portfolio_name': '投资组合',
            'weight_scheme': '权重方案',
            'mean_monthly_return': '月均收益率',
            'annualized_return': '年化收益率',
            'monthly_std_dev': '月度标准差',
            'annualized_std_dev': '年化标准差',
            't_statistic': 't统计量',
            't_stat_p_value': 'p值',
            'annualized_sharpe_ratio': '年化夏普比率',
            'maximum_drawdown': '最大回撤率',
            'ic_mean': 'IC均值',
            'ic_std': 'IC标准差',
            'ic_ir': 'IC_IR'
        }
        
        results_df = results_df.rename(columns=chinese_columns)
        
        percentage_cols = ['月均收益率', '年化收益率', '月度标准差', '年化标准差', '最大回撤率']
        for col in percentage_cols:
            results_df[col] = results_df[col].apply(lambda x: '{:.2%}'.format(x))
        
        decimal_cols = ['年化夏普比率', 't统计量', 'IC均值', 'IC标准差', 'IC_IR']
        for col in decimal_cols:
            results_df[col] = results_df[col].apply(lambda x: '{:.2f}'.format(x))
        
        results_df['p值'] = results_df['p值'].apply(lambda x: '{:.4f}'.format(x))
        
        # 保存结果
        results_df.to_csv(output_file, index=False, encoding='utf-8-sig')
        
        return results_df
        
    except Exception as e:
        print(f"处理过程出错: {str(e)}")
        raise

# %%
# 使用示例
if __name__ == "__main__":
    portfolio_configs = [
        {
            'name': 'dfin',
            'portfolio_file': 'dfin_standardized.xlsx',
            'indicator_file': 'dfin_standardized_indicators.xlsx',
            'portfolio': {
                'date_col': 'year_month',
                'vw_return_col': 'return_spread_mv',
                'ew_return_col': 'return_spread_eq'
            },
            'indicator': {
                'date_col': 'year_month',
                'stock_col': 'code',
                'value_col': 'indicator_value',
                'return_col': 'monthly_return'
            }
        },
        {
            'name': 'ami3',
            'portfolio_file': 'ami3.xlsx',
            'indicator_file': 'ami3_indicators.xlsx',
            'portfolio': {
                'date_col': 'year_month',
                'vw_return_col': 'return_spread_mv',
                'ew_return_col': 'return_spread_eq'
            },
           'indicator': {
                'date_col': 'year_month',
                'stock_col': 'code',
                'value_col': 'indicator_value',
                'return_col': 'monthly_return'
            }
        },
        {
            'name': 'ami6',
            'portfolio_file': 'ami6.xlsx',
            'indicator_file': 'ami6_indicators.xlsx',
            'portfolio': {
                'date_col': 'year_month',
                'vw_return_col': 'return_spread_mv',
                'ew_return_col': 'return_spread_eq'
            },
            'indicator': {
                'date_col': 'year_month',
                'stock_col': 'code',
                'value_col': 'indicator_value',
                'return_col': 'monthly_return'
            }
        },
        {
            'name': 'ami9',
            'portfolio_file': 'ami9.xlsx',
            'indicator_file': 'ami9_indicators.xlsx',
            'portfolio': {
                'date_col': 'year_month',
                'vw_return_col': 'return_spread_mv',
                'ew_return_col': 'return_spread_eq'
            },
            'indicator': {
                'date_col': 'year_month',
                'stock_col': 'code',
                'value_col': 'indicator_value',
                'return_col': 'monthly_return'
            }
        },
        {
            'name': 'ami12',
            'portfolio_file': 'ami12.xlsx',
            'indicator_file': 'ami12_indicators.xlsx',
            'portfolio': {
                'date_col': 'year_month',
                'vw_return_col': 'return_spread_mv',
                'ew_return_col': 'return_spread_eq'
            },
            'indicator': {
                'date_col': 'year_month',
                'stock_col': 'code',
                'value_col': 'indicator_value',
                'return_col': 'monthly_return'
            }
        }
    ]
    
    rf_config = {
        'file': 'monthly_risk_free.csv',
        'date_col': 'year_month',
        'rate_col': 'risk_free_month'
    }
    
    results = process_portfolios(
        portfolio_configs=portfolio_configs,
        rf_config=rf_config,
        output_file='portfolio_analysis_results.csv'
    )
# Out:
# 处理投资组合: dfin
# 期间 2007-01 -> 2007-02: 样本数=1165, IC=0.0135
# 期间 2007-02 -> 2007-03: 样本数=1187, IC=0.0630
# 期间 2007-03 -> 2007-04: 样本数=1193, IC=-0.0205
# 期间 2007-04 -> 2007-05: 样本数=1169, IC=-0.0071
# 期间 2007-05 -> 2007-06: 样本数=1183, IC=-0.0913
# 期间 2007-06 -> 2007-07: 样本数=1191, IC=-0.0109
# 期间 2007-07 -> 2007-08: 样本数=1197, IC=-0.0250
# 期间 2007-08 -> 2007-09: 样本数=1190, IC=-0.0349
# 期间 2007-09 -> 2007-10: 样本数=1182, IC=-0.0388
# 期间 2007-10 -> 2007-11: 样本数=1177, IC=0.0710
# 期间 2007-11 -> 2007-12: 样本数=1182, IC=-0.0162
# 期间 2007-12 -> 2008-01: 样本数=1176, IC=-0.0397
# 期间 2008-01 -> 2008-02: 样本数=1172, IC=0.0151
# 期间 2008-02 -> 2008-03: 样本数=1173, IC=-0.0072
# 期间 2008-03 -> 2008-04: 样本数=1173, IC=-0.0132
# 期间 2008-04 -> 2008-05: 样本数=1172, IC=-0.0077
# 期间 2008-05 -> 2008-06: 样本数=1260, IC=0.0069
# 期间 2008-06 -> 2008-07: 样本数=1280, IC=0.0195
# 期间 2008-07 -> 2008-08: 样本数=1282, IC=0.0818
# 期间 2008-08 -> 2008-09: 样本数=1290, IC=0.0064
# 期间 2008-09 -> 2008-10: 样本数=1299, IC=0.0439
# 期间 2008-10 -> 2008-11: 样本数=1317, IC=-0.0601
# 期间 2008-11 -> 2008-12: 样本数=1336, IC=0.0359
# 期间 2008-12 -> 2009-01: 样本数=1343, IC=-0.0478
# 期间 2009-01 -> 2009-02: 样本数=1345, IC=0.0350
# 期间 2009-02 -> 2009-03: 样本数=1347, IC=0.0157
# 期间 2009-03 -> 2009-04: 样本数=1345, IC=0.0826
# 期间 2009-04 -> 2009-05: 样本数=1342, IC=0.0452
# 期间 2009-05 -> 2009-06: 样本数=1480, IC=0.0333
# 期间 2009-06 -> 2009-07: 样本数=1477, IC=-0.0688
# 期间 2009-07 -> 2009-08: 样本数=1479, IC=0.0765
# 期间 2009-08 -> 2009-09: 样本数=1481, IC=0.0232
# 期间 2009-09 -> 2009-10: 样本数=1486, IC=0.0724
# 期间 2009-10 -> 2009-11: 样本数=1484, IC=0.0114
# 期间 2009-11 -> 2009-12: 样本数=1485, IC=0.0789
# 期间 2009-12 -> 2010-01: 样本数=1480, IC=0.0520
# 期间 2010-01 -> 2010-02: 样本数=1480, IC=0.0005
# 期间 2010-02 -> 2010-03: 样本数=1482, IC=0.0482
# 期间 2010-03 -> 2010-04: 样本数=1479, IC=0.0915
# 期间 2010-04 -> 2010-05: 样本数=1471, IC=0.0117
# 期间 2010-05 -> 2010-06: 样本数=1524, IC=0.0237
# 期间 2010-06 -> 2010-07: 样本数=1520, IC=-0.0129
# 期间 2010-07 -> 2010-08: 样本数=1519, IC=-0.0054
# 期间 2010-08 -> 2010-09: 样本数=1517, IC=-0.0536
# 期间 2010-09 -> 2010-10: 样本数=1512, IC=-0.0704
# 期间 2010-10 -> 2010-11: 样本数=1512, IC=0.0425
# 期间 2010-11 -> 2010-12: 样本数=1511, IC=-0.1034
# 期间 2010-12 -> 2011-01: 样本数=1505, IC=0.0076
# 期间 2011-01 -> 2011-02: 样本数=1503, IC=0.0090
# 期间 2011-02 -> 2011-03: 样本数=1505, IC=-0.0042
# 期间 2011-03 -> 2011-04: 样本数=1496, IC=0.0023
# 期间 2011-04 -> 2011-05: 样本数=1490, IC=0.0291
# 期间 2011-05 -> 2011-06: 样本数=1651, IC=-0.0123
# 期间 2011-06 -> 2011-07: 样本数=1651, IC=0.0527
# 期间 2011-07 -> 2011-08: 样本数=1645, IC=0.0133
# 期间 2011-08 -> 2011-09: 样本数=1646, IC=0.0504
# 期间 2011-09 -> 2011-10: 样本数=1649, IC=-0.0127
# 期间 2011-10 -> 2011-11: 样本数=1642, IC=0.0588
# 期间 2011-11 -> 2011-12: 样本数=1637, IC=-0.0195
# 期间 2011-12 -> 2012-01: 样本数=1640, IC=-0.0213
# 期间 2012-01 -> 2012-02: 样本数=1641, IC=-0.0203
# 期间 2012-02 -> 2012-03: 样本数=1641, IC=0.0395
# 期间 2012-03 -> 2012-04: 样本数=1644, IC=-0.0528
# 期间 2012-04 -> 2012-05: 样本数=1641, IC=-0.0506
# 期间 2012-05 -> 2012-06: 样本数=1997, IC=0.0734
# 期间 2012-06 -> 2012-07: 样本数=1999, IC=0.0043
# 期间 2012-07 -> 2012-08: 样本数=2003, IC=0.0917
# 期间 2012-08 -> 2012-09: 样本数=2005, IC=-0.0128
# 期间 2012-09 -> 2012-10: 样本数=2002, IC=0.0195
# 期间 2012-10 -> 2012-11: 样本数=2012, IC=-0.0103
# 期间 2012-11 -> 2012-12: 样本数=2012, IC=-0.0070
# 期间 2012-12 -> 2013-01: 样本数=2006, IC=0.0710
# 期间 2013-01 -> 2013-02: 样本数=2006, IC=0.0495
# 期间 2013-02 -> 2013-03: 样本数=1995, IC=0.0030
# 期间 2013-03 -> 2013-04: 样本数=1989, IC=0.0035
# 期间 2013-04 -> 2013-05: 样本数=1986, IC=0.0269
# 期间 2013-05 -> 2013-06: 样本数=2193, IC=0.0046
# 期间 2013-06 -> 2013-07: 样本数=2185, IC=0.1072
# 期间 2013-07 -> 2013-08: 样本数=2181, IC=-0.0043
# 期间 2013-08 -> 2013-09: 样本数=2167, IC=0.0112
# 期间 2013-09 -> 2013-10: 样本数=2163, IC=0.0122
# 期间 2013-10 -> 2013-11: 样本数=2154, IC=0.0153
# 期间 2013-11 -> 2013-12: 样本数=2144, IC=0.0098
# 期间 2013-12 -> 2014-01: 样本数=2139, IC=0.0536
# 期间 2014-01 -> 2014-02: 样本数=2136, IC=0.0277
# 期间 2014-02 -> 2014-03: 样本数=2118, IC=-0.0386
# 期间 2014-03 -> 2014-04: 样本数=2087, IC=0.0405
# 期间 2014-04 -> 2014-05: 样本数=2047, IC=-0.0356
# 期间 2014-05 -> 2014-06: 样本数=2142, IC=0.0529
# 期间 2014-06 -> 2014-07: 样本数=2134, IC=-0.0466
# 期间 2014-07 -> 2014-08: 样本数=2095, IC=0.0179
# 期间 2014-08 -> 2014-09: 样本数=2081, IC=0.0297
# 期间 2014-09 -> 2014-10: 样本数=2044, IC=-0.0219
# 期间 2014-10 -> 2014-11: 样本数=2029, IC=-0.0194
# 期间 2014-11 -> 2014-12: 样本数=2030, IC=-0.0310
# 期间 2014-12 -> 2015-01: 样本数=2010, IC=-0.0124
# 期间 2015-01 -> 2015-02: 样本数=1992, IC=0.0178
# 期间 2015-02 -> 2015-03: 样本数=2012, IC=0.0065
# 期间 2015-03 -> 2015-04: 样本数=1980, IC=-0.0267
# 期间 2015-04 -> 2015-05: 样本数=1933, IC=0.0120
# 期间 2015-05 -> 2015-06: 样本数=1938, IC=-0.0279
# 期间 2015-06 -> 2015-07: 样本数=1873, IC=-0.0033
# 期间 2015-07 -> 2015-08: 样本数=1795, IC=0.0553
# 期间 2015-08 -> 2015-09: 样本数=1767, IC=0.0413
# 期间 2015-09 -> 2015-10: 样本数=1771, IC=-0.0160
# 期间 2015-10 -> 2015-11: 样本数=1801, IC=-0.0048
# 期间 2015-11 -> 2015-12: 样本数=1830, IC=0.0452
# 期间 2015-12 -> 2016-01: 样本数=1827, IC=-0.0220
# 期间 2016-01 -> 2016-02: 样本数=1857, IC=-0.0227
# 期间 2016-02 -> 2016-03: 样本数=1911, IC=0.0021
# 期间 2016-03 -> 2016-04: 样本数=1954, IC=-0.0143
# 期间 2016-04 -> 2016-05: 样本数=1989, IC=0.0313
# 期间 2016-05 -> 2016-06: 样本数=2144, IC=-0.0440
# 期间 2016-06 -> 2016-07: 样本数=2170, IC=0.0340
# 期间 2016-07 -> 2016-08: 样本数=2177, IC=-0.0350
# 期间 2016-08 -> 2016-09: 样本数=2197, IC=-0.0328
# 期间 2016-09 -> 2016-10: 样本数=2187, IC=0.0300
# 期间 2016-10 -> 2016-11: 样本数=2218, IC=0.0635
# 期间 2016-11 -> 2016-12: 样本数=2231, IC=-0.0108
# 期间 2016-12 -> 2017-01: 样本数=2256, IC=-0.0243
# 期间 2017-01 -> 2017-02: 样本数=2262, IC=0.0282
# 期间 2017-02 -> 2017-03: 样本数=2279, IC=-0.0299
# 期间 2017-03 -> 2017-04: 样本数=2284, IC=-0.0079
# 期间 2017-04 -> 2017-05: 样本数=2267, IC=0.0182
# 期间 2017-05 -> 2017-06: 样本数=2426, IC=0.0128
# 期间 2017-06 -> 2017-07: 样本数=2428, IC=0.0421
# 期间 2017-07 -> 2017-08: 样本数=2403, IC=-0.0116
# 期间 2017-08 -> 2017-09: 样本数=2434, IC=-0.0456
# 期间 2017-09 -> 2017-10: 样本数=2437, IC=-0.0273
# 期间 2017-10 -> 2017-11: 样本数=2441, IC=0.0033
# 期间 2017-11 -> 2017-12: 样本数=2439, IC=-0.0056
# 期间 2017-12 -> 2018-01: 样本数=2442, IC=0.0308
# 期间 2018-01 -> 2018-02: 样本数=2448, IC=-0.0584
# 期间 2018-02 -> 2018-03: 样本数=2441, IC=0.0013
# 期间 2018-03 -> 2018-04: 样本数=2435, IC=-0.0408
# 期间 2018-04 -> 2018-05: 样本数=2442, IC=0.0060
# 期间 2018-05 -> 2018-06: 样本数=2616, IC=0.0424
# 期间 2018-06 -> 2018-07: 样本数=2623, IC=0.0160
# 期间 2018-07 -> 2018-08: 样本数=2640, IC=0.0404
# 期间 2018-08 -> 2018-09: 样本数=2677, IC=0.0345
# 期间 2018-09 -> 2018-10: 样本数=2709, IC=0.0538
# 期间 2018-10 -> 2018-11: 样本数=2773, IC=-0.0265
# 期间 2018-11 -> 2018-12: 样本数=2820, IC=0.0455
# 期间 2018-12 -> 2019-01: 样本数=2869, IC=0.0255
# 期间 2019-01 -> 2019-02: 样本数=2914, IC=-0.0493
# 期间 2019-02 -> 2019-03: 样本数=2938, IC=0.0272
# 期间 2019-03 -> 2019-04: 样本数=2959, IC=-0.0085
# 期间 2019-04 -> 2019-05: 样本数=2973, IC=-0.0032
# 期间 2019-05 -> 2019-06: 样本数=3214, IC=0.0172
# 期间 2019-06 -> 2019-07: 样本数=3217, IC=-0.0181
# 期间 2019-07 -> 2019-08: 样本数=3216, IC=0.0048
# 期间 2019-08 -> 2019-09: 样本数=3216, IC=-0.0411
# 期间 2019-09 -> 2019-10: 样本数=3215, IC=-0.0301
# 期间 2019-10 -> 2019-11: 样本数=3213, IC=0.0214
# 期间 2019-11 -> 2019-12: 样本数=3212, IC=-0.0315
# 期间 2019-12 -> 2020-01: 样本数=3212, IC=-0.0855
# 期间 2020-01 -> 2020-02: 样本数=3211, IC=-0.0446
# 期间 2020-02 -> 2020-03: 样本数=3211, IC=0.0541
# 期间 2020-03 -> 2020-04: 样本数=3206, IC=-0.0294
# 期间 2020-04 -> 2020-05: 样本数=3200, IC=-0.0029
# 期间 2020-05 -> 2020-06: 样本数=3350, IC=0.0142
# 期间 2020-06 -> 2020-07: 样本数=3346, IC=0.0031
# 期间 2020-07 -> 2020-08: 样本数=3341, IC=0.0044
# 期间 2020-08 -> 2020-09: 样本数=3341, IC=-0.0038
# 期间 2020-09 -> 2020-10: 样本数=3341, IC=0.0279
# 期间 2020-10 -> 2020-11: 样本数=3341, IC=-0.0338
# 期间 2020-11 -> 2020-12: 样本数=3343, IC=-0.0086
# 期间 2020-12 -> 2021-01: 样本数=3343, IC=-0.0112
# 期间 2021-01 -> 2021-02: 样本数=3363, IC=0.0036
# 期间 2021-02 -> 2021-03: 样本数=3363, IC=0.0180
# 期间 2021-03 -> 2021-04: 样本数=3362, IC=0.0225
# 期间 2021-04 -> 2021-05: 样本数=3362, IC=0.0434
# 期间 2021-05 -> 2021-06: 样本数=3536, IC=0.0040
# 期间 2021-06 -> 2021-07: 样本数=3541, IC=-0.0256
# 期间 2021-07 -> 2021-08: 样本数=3543, IC=-0.0090
# 期间 2021-08 -> 2021-09: 样本数=3546, IC=0.0188
# 期间 2021-09 -> 2021-10: 样本数=3545, IC=-0.0277
# 期间 2021-10 -> 2021-11: 样本数=3544, IC=0.0133
# 期间 2021-11 -> 2021-12: 样本数=3544, IC=-0.0063
# 期间 2021-12 -> 2022-01: 样本数=3547, IC=-0.0104
# 期间 2022-01 -> 2022-02: 样本数=3551, IC=-0.0238
# 期间 2022-02 -> 2022-03: 样本数=3557, IC=0.0286
# 期间 2022-03 -> 2022-04: 样本数=3553, IC=0.0126
# 期间 2022-04 -> 2022-05: 样本数=3524, IC=0.0025
# 期间 2022-05 -> 2022-06: 样本数=3924, IC=-0.0462
# 期间 2022-06 -> 2022-07: 样本数=3924, IC=-0.0183
# 期间 2022-07 -> 2022-08: 样本数=3926, IC=0.0146
# 期间 2022-08 -> 2022-09: 样本数=3926, IC=-0.0031
# 期间 2022-09 -> 2022-10: 样本数=3930, IC=0.0229
# 期间 2022-10 -> 2022-11: 样本数=3930, IC=0.0068
# 期间 2022-11 -> 2022-12: 样本数=3938, IC=-0.0554
# 期间 2022-12 -> 2023-01: 样本数=3949, IC=0.0224
# 期间 2023-01 -> 2023-02: 样本数=3951, IC=0.0253
# 期间 2023-02 -> 2023-03: 样本数=3952, IC=0.0125
# 期间 2023-03 -> 2023-04: 样本数=3954, IC=-0.0002
# 期间 2023-04 -> 2023-05: 样本数=3937, IC=0.0053
# 期间 2023-05 -> 2023-06: 样本数=4609, IC=-0.0109
# 期间 2023-06 -> 2023-07: 样本数=4635, IC=0.0571
# 期间 2023-07 -> 2023-08: 样本数=4642, IC=0.0237
# 期间 2023-08 -> 2023-09: 样本数=4648, IC=0.0352
# 期间 2023-09 -> 2023-10: 样本数=4658, IC=-0.0194
# 期间 2023-10 -> 2023-11: 样本数=4663, IC=0.0337
# 期间 2023-11 -> 2023-12: 样本数=4668, IC=0.0140
#
# dfin IC统计:
# 计算期数: 203
# IC均值: 0.0053
# IC标准差: 0.0360
# IC_IR: 0.1475
#
# 处理投资组合: ami3
# 期间 2007-01 -> 2007-02: 样本数=1160, IC=0.1964
# 期间 2007-02 -> 2007-03: 样本数=1184, IC=0.3123
# 期间 2007-03 -> 2007-04: 样本数=1192, IC=-0.0491
# 期间 2007-04 -> 2007-05: 样本数=1169, IC=0.0061
# 期间 2007-05 -> 2007-06: 样本数=1171, IC=-0.1479
# 期间 2007-06 -> 2007-07: 样本数=1179, IC=0.0382
# 期间 2007-07 -> 2007-08: 样本数=1186, IC=-0.0444
# 期间 2007-08 -> 2007-09: 样本数=1190, IC=-0.0373
# 期间 2007-09 -> 2007-10: 样本数=1182, IC=-0.1575
# 期间 2007-10 -> 2007-11: 样本数=1177, IC=0.3508
# 期间 2007-11 -> 2007-12: 样本数=1182, IC=0.0079
# 期间 2007-12 -> 2008-01: 样本数=1176, IC=0.0792
# 期间 2008-01 -> 2008-02: 样本数=1172, IC=0.2451
# 期间 2008-02 -> 2008-03: 样本数=1173, IC=0.1378
# 期间 2008-03 -> 2008-04: 样本数=1173, IC=-0.2094
# 期间 2008-04 -> 2008-05: 样本数=1172, IC=0.1791
# 期间 2008-05 -> 2008-06: 样本数=1173, IC=-0.0385
# 期间 2008-06 -> 2008-07: 样本数=1193, IC=0.2764
# 期间 2008-07 -> 2008-08: 样本数=1195, IC=0.1397
# 期间 2008-08 -> 2008-09: 样本数=1290, IC=-0.1676
# 期间 2008-09 -> 2008-10: 样本数=1299, IC=0.1628
# 期间 2008-10 -> 2008-11: 样本数=1316, IC=0.1267
# 期间 2008-11 -> 2008-12: 样本数=1335, IC=0.1986
# 期间 2008-12 -> 2009-01: 样本数=1342, IC=-0.0357
# 期间 2009-01 -> 2009-02: 样本数=1345, IC=0.0923
# 期间 2009-02 -> 2009-03: 样本数=1347, IC=0.1313
# 期间 2009-03 -> 2009-04: 样本数=1345, IC=0.1699
# 期间 2009-04 -> 2009-05: 样本数=1342, IC=0.1947
# 期间 2009-05 -> 2009-06: 样本数=1356, IC=0.0884
# 期间 2009-06 -> 2009-07: 样本数=1353, IC=-0.1089
# 期间 2009-07 -> 2009-08: 样本数=1355, IC=0.2092
# 期间 2009-08 -> 2009-09: 样本数=1480, IC=0.0041
# 期间 2009-09 -> 2009-10: 样本数=1485, IC=0.0726
# 期间 2009-10 -> 2009-11: 样本数=1483, IC=0.1740
# 期间 2009-11 -> 2009-12: 样本数=1485, IC=0.1480
# 期间 2009-12 -> 2010-01: 样本数=1479, IC=0.1675
# 期间 2010-01 -> 2010-02: 样本数=1479, IC=0.2280
# 期间 2010-02 -> 2010-03: 样本数=1481, IC=0.2034
# 期间 2010-03 -> 2010-04: 样本数=1479, IC=0.0648
# 期间 2010-04 -> 2010-05: 样本数=1471, IC=0.0276
# 期间 2010-05 -> 2010-06: 样本数=1469, IC=0.0508
# 期间 2010-06 -> 2010-07: 样本数=1465, IC=0.0873
# 期间 2010-07 -> 2010-08: 样本数=1464, IC=0.1211
# 期间 2010-08 -> 2010-09: 样本数=1517, IC=0.0102
# 期间 2010-09 -> 2010-10: 样本数=1512, IC=-0.2543
# 期间 2010-10 -> 2010-11: 样本数=1512, IC=0.2416
# 期间 2010-11 -> 2010-12: 样本数=1511, IC=0.0455
# 期间 2010-12 -> 2011-01: 样本数=1505, IC=0.0302
# 期间 2011-01 -> 2011-02: 样本数=1503, IC=0.0272
# 期间 2011-02 -> 2011-03: 样本数=1505, IC=0.2242
# 期间 2011-03 -> 2011-04: 样本数=1496, IC=0.0875
# 期间 2011-04 -> 2011-05: 样本数=1490, IC=0.0292
# 期间 2011-05 -> 2011-06: 样本数=1494, IC=0.0582
# 期间 2011-06 -> 2011-07: 样本数=1495, IC=0.1551
# 期间 2011-07 -> 2011-08: 样本数=1490, IC=0.2020
# 期间 2011-08 -> 2011-09: 样本数=1646, IC=0.0802
# 期间 2011-09 -> 2011-10: 样本数=1649, IC=-0.0005
# 期间 2011-10 -> 2011-11: 样本数=1642, IC=0.1392
# 期间 2011-11 -> 2011-12: 样本数=1637, IC=-0.1285
# 期间 2011-12 -> 2012-01: 样本数=1639, IC=-0.1960
# 期间 2012-01 -> 2012-02: 样本数=1640, IC=0.1794
# 期间 2012-02 -> 2012-03: 样本数=1641, IC=0.0949
# 期间 2012-03 -> 2012-04: 样本数=1643, IC=0.0447
# 期间 2012-04 -> 2012-05: 样本数=1641, IC=-0.0088
# 期间 2012-05 -> 2012-06: 样本数=1647, IC=0.1518
# 期间 2012-06 -> 2012-07: 样本数=1647, IC=-0.0976
# 期间 2012-07 -> 2012-08: 样本数=1650, IC=0.3372
# 期间 2012-08 -> 2012-09: 样本数=2002, IC=-0.1011
# 期间 2012-09 -> 2012-10: 样本数=2000, IC=0.1806
# 期间 2012-10 -> 2012-11: 样本数=2011, IC=0.0224
# 期间 2012-11 -> 2012-12: 样本数=2010, IC=-0.1670
# 期间 2012-12 -> 2013-01: 样本数=2004, IC=0.0239
# 期间 2013-01 -> 2013-02: 样本数=2004, IC=0.1622
# 期间 2013-02 -> 2013-03: 样本数=1994, IC=0.1953
# 期间 2013-03 -> 2013-04: 样本数=1988, IC=-0.0361
# 期间 2013-04 -> 2013-05: 样本数=1985, IC=0.0983
# 期间 2013-05 -> 2013-06: 样本数=1961, IC=0.1155
# 期间 2013-06 -> 2013-07: 样本数=1954, IC=0.1343
# 期间 2013-07 -> 2013-08: 样本数=1954, IC=0.1510
# 期间 2013-08 -> 2013-09: 样本数=2167, IC=0.0281
# 期间 2013-09 -> 2013-10: 样本数=2163, IC=0.1132
# 期间 2013-10 -> 2013-11: 样本数=2154, IC=0.1530
# 期间 2013-11 -> 2013-12: 样本数=2142, IC=0.0899
# 期间 2013-12 -> 2014-01: 样本数=2135, IC=0.1790
# 期间 2014-01 -> 2014-02: 样本数=2130, IC=0.1957
# 期间 2014-02 -> 2014-03: 样本数=2114, IC=0.2152
# 期间 2014-03 -> 2014-04: 样本数=2087, IC=0.0312
# 期间 2014-04 -> 2014-05: 样本数=2047, IC=0.0672
# 期间 2014-05 -> 2014-06: 样本数=2033, IC=0.1274
# 期间 2014-06 -> 2014-07: 样本数=2022, IC=0.0186
# 期间 2014-07 -> 2014-08: 样本数=1988, IC=0.2488
# 期间 2014-08 -> 2014-09: 样本数=2076, IC=0.2814
# 期间 2014-09 -> 2014-10: 样本数=2043, IC=-0.0103
# 期间 2014-10 -> 2014-11: 样本数=2026, IC=-0.0330
# 期间 2014-11 -> 2014-12: 样本数=2025, IC=-0.3600
# 期间 2014-12 -> 2015-01: 样本数=2001, IC=0.1825
# 期间 2015-01 -> 2015-02: 样本数=1981, IC=0.1240
# 期间 2015-02 -> 2015-03: 样本数=2001, IC=0.1956
# 期间 2015-03 -> 2015-04: 样本数=1976, IC=0.0099
# 期间 2015-04 -> 2015-05: 样本数=1932, IC=0.2793
# 期间 2015-05 -> 2015-06: 样本数=1902, IC=-0.0829
# 期间 2015-06 -> 2015-07: 样本数=1839, IC=-0.0526
# 期间 2015-07 -> 2015-08: 样本数=1761, IC=-0.0337
# 期间 2015-08 -> 2015-09: 样本数=1763, IC=0.1593
# 期间 2015-09 -> 2015-10: 样本数=1768, IC=0.2823
# 期间 2015-10 -> 2015-11: 样本数=1797, IC=0.3358
# 期间 2015-11 -> 2015-12: 样本数=1826, IC=0.2519
# 期间 2015-12 -> 2016-01: 样本数=1821, IC=-0.1364
# 期间 2016-01 -> 2016-02: 样本数=1851, IC=0.0271
# 期间 2016-02 -> 2016-03: 样本数=1907, IC=0.1401
# 期间 2016-03 -> 2016-04: 样本数=1949, IC=0.2237
# 期间 2016-04 -> 2016-05: 样本数=1988, IC=-0.1010
# 期间 2016-05 -> 2016-06: 样本数=2042, IC=0.1275
# 期间 2016-06 -> 2016-07: 样本数=2069, IC=-0.0238
# 期间 2016-07 -> 2016-08: 样本数=2079, IC=0.2018
# 期间 2016-08 -> 2016-09: 样本数=2195, IC=0.3199
# 期间 2016-09 -> 2016-10: 样本数=2186, IC=0.1095
# 期间 2016-10 -> 2016-11: 样本数=2211, IC=0.0232
# 期间 2016-11 -> 2016-12: 样本数=2222, IC=0.1987
# 期间 2016-12 -> 2017-01: 样本数=2247, IC=-0.1621
# 期间 2017-01 -> 2017-02: 样本数=2255, IC=0.0278
# 期间 2017-02 -> 2017-03: 样本数=2273, IC=-0.0647
# 期间 2017-03 -> 2017-04: 样本数=2280, IC=-0.1412
# 期间 2017-04 -> 2017-05: 样本数=2265, IC=-0.0583
# 期间 2017-05 -> 2017-06: 样本数=2263, IC=-0.1463
# 期间 2017-06 -> 2017-07: 样本数=2269, IC=-0.1537
# 期间 2017-07 -> 2017-08: 样本数=2244, IC=0.0855
# 期间 2017-08 -> 2017-09: 样本数=2425, IC=0.0840
# 期间 2017-09 -> 2017-10: 样本数=2428, IC=-0.0518
# 期间 2017-10 -> 2017-11: 样本数=2433, IC=-0.1868
# 期间 2017-11 -> 2017-12: 样本数=2432, IC=-0.0859
# 期间 2017-12 -> 2018-01: 样本数=2431, IC=-0.1800
# 期间 2018-01 -> 2018-02: 样本数=2436, IC=-0.1596
# 期间 2018-02 -> 2018-03: 样本数=2426, IC=0.2693
# 期间 2018-03 -> 2018-04: 样本数=2425, IC=-0.0444
# 期间 2018-04 -> 2018-05: 样本数=2432, IC=0.0151
# 期间 2018-05 -> 2018-06: 样本数=2429, IC=-0.1765
# 期间 2018-06 -> 2018-07: 样本数=2439, IC=0.1342
# 期间 2018-07 -> 2018-08: 样本数=2457, IC=0.0276
# 期间 2018-08 -> 2018-09: 样本数=2673, IC=-0.0425
# 期间 2018-09 -> 2018-10: 样本数=2704, IC=0.1298
# 期间 2018-10 -> 2018-11: 样本数=2769, IC=0.2349
# 期间 2018-11 -> 2018-12: 样本数=2811, IC=0.0475
# 期间 2018-12 -> 2019-01: 样本数=2862, IC=-0.1511
# 期间 2019-01 -> 2019-02: 样本数=2904, IC=0.0299
# 期间 2019-02 -> 2019-03: 样本数=2933, IC=0.1262
# 期间 2019-03 -> 2019-04: 样本数=2955, IC=0.0258
# 期间 2019-04 -> 2019-05: 样本数=2973, IC=0.1132
# 期间 2019-05 -> 2019-06: 样本数=2984, IC=-0.0682
# 期间 2019-06 -> 2019-07: 样本数=2987, IC=-0.0805
# 期间 2019-07 -> 2019-08: 样本数=2986, IC=-0.0493
# 期间 2019-08 -> 2019-09: 样本数=3215, IC=0.0809
# 期间 2019-09 -> 2019-10: 样本数=3215, IC=-0.0014
# 期间 2019-10 -> 2019-11: 样本数=3213, IC=-0.0188
# 期间 2019-11 -> 2019-12: 样本数=3212, IC=-0.0609
# 期间 2019-12 -> 2020-01: 样本数=3212, IC=-0.0852
# 期间 2020-01 -> 2020-02: 样本数=3211, IC=-0.1381
# 期间 2020-02 -> 2020-03: 样本数=3211, IC=0.2763
# 期间 2020-03 -> 2020-04: 样本数=3206, IC=-0.2168
# 期间 2020-04 -> 2020-05: 样本数=3200, IC=0.0770
# 期间 2020-05 -> 2020-06: 样本数=3199, IC=-0.1555
# 期间 2020-06 -> 2020-07: 样本数=3194, IC=0.0010
# 期间 2020-07 -> 2020-08: 样本数=3189, IC=0.1352
# 期间 2020-08 -> 2020-09: 样本数=3340, IC=0.1115
# 期间 2020-09 -> 2020-10: 样本数=3341, IC=0.0993
# 期间 2020-10 -> 2020-11: 样本数=3341, IC=0.0101
# 期间 2020-11 -> 2020-12: 样本数=3343, IC=-0.1762
# 期间 2020-12 -> 2021-01: 样本数=3343, IC=-0.1558
# 期间 2021-01 -> 2021-02: 样本数=3340, IC=0.1763
# 期间 2021-02 -> 2021-03: 样本数=3340, IC=0.2927
# 期间 2021-03 -> 2021-04: 样本数=3339, IC=-0.0315
# 期间 2021-04 -> 2021-05: 样本数=3362, IC=0.0237
# 期间 2021-05 -> 2021-06: 样本数=3363, IC=0.1625
# 期间 2021-06 -> 2021-07: 样本数=3363, IC=0.0444
# 期间 2021-07 -> 2021-08: 样本数=3363, IC=0.0524
# 期间 2021-08 -> 2021-09: 样本数=3534, IC=0.0438
# 期间 2021-09 -> 2021-10: 样本数=3538, IC=-0.1012
# 期间 2021-10 -> 2021-11: 样本数=3539, IC=0.1694
# 期间 2021-11 -> 2021-12: 样本数=3543, IC=0.1873
# 期间 2021-12 -> 2022-01: 样本数=3544, IC=0.2334
# 期间 2022-01 -> 2022-02: 样本数=3545, IC=-0.0426
# 期间 2022-02 -> 2022-03: 样本数=3546, IC=0.2565
# 期间 2022-03 -> 2022-04: 样本数=3543, IC=-0.1118
# 期间 2022-04 -> 2022-05: 样本数=3516, IC=0.1486
# 期间 2022-05 -> 2022-06: 样本数=3508, IC=-0.0905
# 期间 2022-06 -> 2022-07: 样本数=3509, IC=0.3519
# 期间 2022-07 -> 2022-08: 样本数=3510, IC=0.0139
# 期间 2022-08 -> 2022-09: 样本数=3923, IC=0.0001
# 期间 2022-09 -> 2022-10: 样本数=3923, IC=0.1370
# 期间 2022-10 -> 2022-11: 样本数=3925, IC=0.0048
# 期间 2022-11 -> 2022-12: 样本数=3929, IC=-0.0413
# 期间 2022-12 -> 2023-01: 样本数=3937, IC=-0.0105
# 期间 2023-01 -> 2023-02: 样本数=3934, IC=0.1601
# 期间 2023-02 -> 2023-03: 样本数=3937, IC=0.0196
# 期间 2023-03 -> 2023-04: 样本数=3940, IC=-0.0201
# 期间 2023-04 -> 2023-05: 样本数=3923, IC=0.2429
# 期间 2023-05 -> 2023-06: 样本数=3913, IC=0.1360
# 期间 2023-06 -> 2023-07: 样本数=3919, IC=0.0931
# 期间 2023-07 -> 2023-08: 样本数=3924, IC=0.1816
# 期间 2023-08 -> 2023-09: 样本数=4608, IC=0.1095
# 期间 2023-09 -> 2023-10: 样本数=4634, IC=0.1149
# 期间 2023-10 -> 2023-11: 样本数=4641, IC=0.3354
# 期间 2023-11 -> 2023-12: 样本数=4647, IC=0.1617
#
# ami3 IC统计:
# 计算期数: 203
# IC均值: 0.0619
# IC标准差: 0.1374
# IC_IR: 0.4506
#
# 处理投资组合: ami6
# 期间 2007-01 -> 2007-02: 样本数=1156, IC=0.1909
# 期间 2007-02 -> 2007-03: 样本数=1178, IC=0.3068
# 期间 2007-03 -> 2007-04: 样本数=1184, IC=-0.0211
# 期间 2007-04 -> 2007-05: 样本数=1162, IC=-0.0188
# 期间 2007-05 -> 2007-06: 样本数=1168, IC=-0.2370
# 期间 2007-06 -> 2007-07: 样本数=1178, IC=0.0721
# 期间 2007-07 -> 2007-08: 样本数=1185, IC=-0.0510
# 期间 2007-08 -> 2007-09: 样本数=1179, IC=-0.0600
# 期间 2007-09 -> 2007-10: 样本数=1171, IC=-0.1385
# 期间 2007-10 -> 2007-11: 样本数=1167, IC=0.3179
# 期间 2007-11 -> 2007-12: 样本数=1182, IC=0.0228
# 期间 2007-12 -> 2008-01: 样本数=1176, IC=0.0667
# 期间 2008-01 -> 2008-02: 样本数=1172, IC=0.2231
# 期间 2008-02 -> 2008-03: 样本数=1173, IC=0.1356
# 期间 2008-03 -> 2008-04: 样本数=1172, IC=-0.1840
# 期间 2008-04 -> 2008-05: 样本数=1171, IC=0.1932
# 期间 2008-05 -> 2008-06: 样本数=1172, IC=-0.0428
# 期间 2008-06 -> 2008-07: 样本数=1193, IC=0.2771
# 期间 2008-07 -> 2008-08: 样本数=1195, IC=0.1171
# 期间 2008-08 -> 2008-09: 样本数=1203, IC=-0.1815
# 期间 2008-09 -> 2008-10: 样本数=1211, IC=0.1690
# 期间 2008-10 -> 2008-11: 样本数=1227, IC=0.1104
# 期间 2008-11 -> 2008-12: 样本数=1334, IC=0.1956
# 期间 2008-12 -> 2009-01: 样本数=1342, IC=-0.0470
# 期间 2009-01 -> 2009-02: 样本数=1344, IC=0.0905
# 期间 2009-02 -> 2009-03: 样本数=1346, IC=0.1176
# 期间 2009-03 -> 2009-04: 样本数=1344, IC=0.1803
# 期间 2009-04 -> 2009-05: 样本数=1342, IC=0.1861
# 期间 2009-05 -> 2009-06: 样本数=1356, IC=0.0816
# 期间 2009-06 -> 2009-07: 样本数=1353, IC=-0.1122
# 期间 2009-07 -> 2009-08: 样本数=1355, IC=0.1857
# 期间 2009-08 -> 2009-09: 样本数=1356, IC=-0.0056
# 期间 2009-09 -> 2009-10: 样本数=1361, IC=0.0586
# 期间 2009-10 -> 2009-11: 样本数=1359, IC=0.1261
# 期间 2009-11 -> 2009-12: 样本数=1484, IC=0.1366
# 期间 2009-12 -> 2010-01: 样本数=1478, IC=0.1663
# 期间 2010-01 -> 2010-02: 样本数=1478, IC=0.2393
# 期间 2010-02 -> 2010-03: 样本数=1480, IC=0.2215
# 期间 2010-03 -> 2010-04: 样本数=1477, IC=0.0541
# 期间 2010-04 -> 2010-05: 样本数=1470, IC=0.0351
# 期间 2010-05 -> 2010-06: 样本数=1468, IC=0.0489
# 期间 2010-06 -> 2010-07: 样本数=1465, IC=0.0854
# 期间 2010-07 -> 2010-08: 样本数=1464, IC=0.1649
# 期间 2010-08 -> 2010-09: 样本数=1462, IC=0.0228
# 期间 2010-09 -> 2010-10: 样本数=1457, IC=-0.2698
# 期间 2010-10 -> 2010-11: 样本数=1457, IC=0.2268
# 期间 2010-11 -> 2010-12: 样本数=1511, IC=0.0469
# 期间 2010-12 -> 2011-01: 样本数=1505, IC=0.0222
# 期间 2011-01 -> 2011-02: 样本数=1503, IC=0.0249
# 期间 2011-02 -> 2011-03: 样本数=1505, IC=0.2196
# 期间 2011-03 -> 2011-04: 样本数=1496, IC=0.0781
# 期间 2011-04 -> 2011-05: 样本数=1490, IC=0.0220
# 期间 2011-05 -> 2011-06: 样本数=1494, IC=0.0682
# 期间 2011-06 -> 2011-07: 样本数=1495, IC=0.1481
# 期间 2011-07 -> 2011-08: 样本数=1490, IC=0.1881
# 期间 2011-08 -> 2011-09: 样本数=1491, IC=0.0662
# 期间 2011-09 -> 2011-10: 样本数=1494, IC=-0.0362
# 期间 2011-10 -> 2011-11: 样本数=1488, IC=0.1441
# 期间 2011-11 -> 2011-12: 样本数=1637, IC=-0.1301
# 期间 2011-12 -> 2012-01: 样本数=1638, IC=-0.2156
# 期间 2012-01 -> 2012-02: 样本数=1639, IC=0.1649
# 期间 2012-02 -> 2012-03: 样本数=1640, IC=0.1041
# 期间 2012-03 -> 2012-04: 样本数=1641, IC=0.0102
# 期间 2012-04 -> 2012-05: 样本数=1638, IC=-0.0137
# 期间 2012-05 -> 2012-06: 样本数=1645, IC=0.1281
# 期间 2012-06 -> 2012-07: 样本数=1646, IC=-0.1100
# 期间 2012-07 -> 2012-08: 样本数=1650, IC=0.3207
# 期间 2012-08 -> 2012-09: 样本数=1653, IC=-0.1154
# 期间 2012-09 -> 2012-10: 样本数=1650, IC=0.2372
# 期间 2012-10 -> 2012-11: 样本数=1660, IC=-0.0148
# 期间 2012-11 -> 2012-12: 样本数=2007, IC=-0.1595
# 期间 2012-12 -> 2013-01: 样本数=2002, IC=0.0215
# 期间 2013-01 -> 2013-02: 样本数=2003, IC=0.1423
# 期间 2013-02 -> 2013-03: 样本数=1992, IC=0.1704
# 期间 2013-03 -> 2013-04: 样本数=1985, IC=-0.0299
# 期间 2013-04 -> 2013-05: 样本数=1982, IC=0.1352
# 期间 2013-05 -> 2013-06: 样本数=1958, IC=0.1138
# 期间 2013-06 -> 2013-07: 样本数=1953, IC=0.1774
# 期间 2013-07 -> 2013-08: 样本数=1953, IC=0.1243
# 期间 2013-08 -> 2013-09: 样本数=1942, IC=0.0443
# 期间 2013-09 -> 2013-10: 样本数=1940, IC=0.0628
# 期间 2013-10 -> 2013-11: 样本数=1936, IC=0.1583
# 期间 2013-11 -> 2013-12: 样本数=2142, IC=0.0707
# 期间 2013-12 -> 2014-01: 样本数=2135, IC=0.1611
# 期间 2014-01 -> 2014-02: 样本数=2130, IC=0.1927
# 期间 2014-02 -> 2014-03: 样本数=2112, IC=0.1691
# 期间 2014-03 -> 2014-04: 样本数=2078, IC=0.0279
# 期间 2014-04 -> 2014-05: 样本数=2037, IC=0.0900
# 期间 2014-05 -> 2014-06: 样本数=2024, IC=0.1231
# 期间 2014-06 -> 2014-07: 样本数=2019, IC=0.0598
# 期间 2014-07 -> 2014-08: 样本数=1987, IC=0.2194
# 期间 2014-08 -> 2014-09: 样本数=1978, IC=0.2937
# 期间 2014-09 -> 2014-10: 样本数=1944, IC=-0.0316
# 期间 2014-10 -> 2014-11: 样本数=1929, IC=-0.0362
# 期间 2014-11 -> 2014-12: 样本数=2020, IC=-0.3370
# 期间 2014-12 -> 2015-01: 样本数=2000, IC=0.1527
# 期间 2015-01 -> 2015-02: 样本数=1979, IC=0.1054
# 期间 2015-02 -> 2015-03: 样本数=1996, IC=0.1821
# 期间 2015-03 -> 2015-04: 样本数=1964, IC=0.0123
# 期间 2015-04 -> 2015-05: 样本数=1916, IC=0.2711
# 期间 2015-05 -> 2015-06: 样本数=1886, IC=-0.0953
# 期间 2015-06 -> 2015-07: 样本数=1830, IC=-0.0823
# 期间 2015-07 -> 2015-08: 样本数=1756, IC=-0.0379
# 期间 2015-08 -> 2015-09: 样本数=1727, IC=0.1760
# 期间 2015-09 -> 2015-10: 样本数=1733, IC=0.2692
# 期间 2015-10 -> 2015-11: 样本数=1760, IC=0.3426
# 期间 2015-11 -> 2015-12: 样本数=1820, IC=0.2088
# 期间 2015-12 -> 2016-01: 样本数=1816, IC=-0.2104
# 期间 2016-01 -> 2016-02: 样本数=1845, IC=0.0183
# 期间 2016-02 -> 2016-03: 样本数=1903, IC=0.1802
# 期间 2016-03 -> 2016-04: 样本数=1943, IC=0.2275
# 期间 2016-04 -> 2016-05: 样本数=1981, IC=-0.1340
# 期间 2016-05 -> 2016-06: 样本数=2036, IC=0.1205
# 期间 2016-06 -> 2016-07: 样本数=2064, IC=-0.0524
# 期间 2016-07 -> 2016-08: 样本数=2077, IC=0.1724
# 期间 2016-08 -> 2016-09: 样本数=2099, IC=0.2893
# 期间 2016-09 -> 2016-10: 样本数=2090, IC=0.0885
# 期间 2016-10 -> 2016-11: 样本数=2115, IC=-0.0062
# 期间 2016-11 -> 2016-12: 样本数=2220, IC=0.2073
# 期间 2016-12 -> 2017-01: 样本数=2244, IC=-0.1606
# 期间 2017-01 -> 2017-02: 样本数=2248, IC=0.0080
# 期间 2017-02 -> 2017-03: 样本数=2265, IC=-0.0876
# 期间 2017-03 -> 2017-04: 样本数=2272, IC=-0.1628
# 期间 2017-04 -> 2017-05: 样本数=2257, IC=-0.0809
# 期间 2017-05 -> 2017-06: 样本数=2255, IC=-0.1435
# 期间 2017-06 -> 2017-07: 样本数=2262, IC=-0.1861
# 期间 2017-07 -> 2017-08: 样本数=2240, IC=0.0972
# 期间 2017-08 -> 2017-09: 样本数=2269, IC=0.0545
# 期间 2017-09 -> 2017-10: 样本数=2271, IC=-0.0895
# 期间 2017-10 -> 2017-11: 样本数=2275, IC=-0.1764
# 期间 2017-11 -> 2017-12: 样本数=2422, IC=-0.0792
# 期间 2017-12 -> 2018-01: 样本数=2420, IC=-0.2135
# 期间 2018-01 -> 2018-02: 样本数=2427, IC=-0.1249
# 期间 2018-02 -> 2018-03: 样本数=2419, IC=0.2659
# 期间 2018-03 -> 2018-04: 样本数=2413, IC=-0.0344
# 期间 2018-04 -> 2018-05: 样本数=2416, IC=0.0151
# 期间 2018-05 -> 2018-06: 样本数=2409, IC=-0.1688
# 期间 2018-06 -> 2018-07: 样本数=2423, IC=0.1111
# 期间 2018-07 -> 2018-08: 样本数=2445, IC=0.0155
# 期间 2018-08 -> 2018-09: 样本数=2486, IC=-0.0594
# 期间 2018-09 -> 2018-10: 样本数=2519, IC=0.1365
# 期间 2018-10 -> 2018-11: 样本数=2584, IC=0.2422
# 期间 2018-11 -> 2018-12: 样本数=2805, IC=0.0501
# 期间 2018-12 -> 2019-01: 样本数=2857, IC=-0.1469
# 期间 2019-01 -> 2019-02: 样本数=2900, IC=0.0223
# 期间 2019-02 -> 2019-03: 样本数=2924, IC=0.1266
# 期间 2019-03 -> 2019-04: 样本数=2948, IC=0.0079
# 期间 2019-04 -> 2019-05: 样本数=2962, IC=0.1322
# 期间 2019-05 -> 2019-06: 样本数=2979, IC=-0.0825
# 期间 2019-06 -> 2019-07: 样本数=2982, IC=-0.0737
# 期间 2019-07 -> 2019-08: 样本数=2985, IC=-0.0398
# 期间 2019-08 -> 2019-09: 样本数=2985, IC=0.0617
# 期间 2019-09 -> 2019-10: 样本数=2985, IC=-0.0190
# 期间 2019-10 -> 2019-11: 样本数=2983, IC=-0.0347
# 期间 2019-11 -> 2019-12: 样本数=3211, IC=-0.0507
# 期间 2019-12 -> 2020-01: 样本数=3212, IC=-0.0523
# 期间 2020-01 -> 2020-02: 样本数=3211, IC=-0.1435
# 期间 2020-02 -> 2020-03: 样本数=3211, IC=0.2613
# 期间 2020-03 -> 2020-04: 样本数=3206, IC=-0.2102
# 期间 2020-04 -> 2020-05: 样本数=3200, IC=0.0788
# 期间 2020-05 -> 2020-06: 样本数=3199, IC=-0.1495
# 期间 2020-06 -> 2020-07: 样本数=3194, IC=-0.0056
# 期间 2020-07 -> 2020-08: 样本数=3189, IC=0.1294
# 期间 2020-08 -> 2020-09: 样本数=3189, IC=0.0879
# 期间 2020-09 -> 2020-10: 样本数=3189, IC=0.0848
# 期间 2020-10 -> 2020-11: 样本数=3189, IC=-0.0040
# 期间 2020-11 -> 2020-12: 样本数=3342, IC=-0.1803
# 期间 2020-12 -> 2021-01: 样本数=3343, IC=-0.1651
# 期间 2021-01 -> 2021-02: 样本数=3340, IC=0.1779
# 期间 2021-02 -> 2021-03: 样本数=3340, IC=0.3000
# 期间 2021-03 -> 2021-04: 样本数=3339, IC=-0.0205
# 期间 2021-04 -> 2021-05: 样本数=3339, IC=0.0311
# 期间 2021-05 -> 2021-06: 样本数=3340, IC=0.1307
# 期间 2021-06 -> 2021-07: 样本数=3340, IC=0.0299
# 期间 2021-07 -> 2021-08: 样本数=3363, IC=0.0578
# 期间 2021-08 -> 2021-09: 样本数=3361, IC=0.0279
# 期间 2021-09 -> 2021-10: 样本数=3361, IC=-0.0903
# 期间 2021-10 -> 2021-11: 样本数=3360, IC=0.1884
# 期间 2021-11 -> 2021-12: 样本数=3531, IC=0.1399
# 期间 2021-12 -> 2022-01: 样本数=3537, IC=0.2207
# 期间 2022-01 -> 2022-02: 样本数=3540, IC=-0.0341
# 期间 2022-02 -> 2022-03: 样本数=3545, IC=0.2681
# 期间 2022-03 -> 2022-04: 样本数=3540, IC=-0.1381
# 期间 2022-04 -> 2022-05: 样本数=3510, IC=0.1212
# 期间 2022-05 -> 2022-06: 样本数=3497, IC=-0.1419
# 期间 2022-06 -> 2022-07: 样本数=3499, IC=0.3263
# 期间 2022-07 -> 2022-08: 样本数=3502, IC=0.0249
# 期间 2022-08 -> 2022-09: 样本数=3507, IC=-0.0192
# 期间 2022-09 -> 2022-10: 样本数=3508, IC=0.1430
# 期间 2022-10 -> 2022-11: 样本数=3509, IC=-0.0269
# 期间 2022-11 -> 2022-12: 样本数=3926, IC=-0.0654
# 期间 2022-12 -> 2023-01: 样本数=3930, IC=-0.0186
# 期间 2023-01 -> 2023-02: 样本数=3929, IC=0.1646
# 期间 2023-02 -> 2023-03: 样本数=3928, IC=0.0399
# 期间 2023-03 -> 2023-04: 样本数=3928, IC=-0.0202
# 期间 2023-04 -> 2023-05: 样本数=3906, IC=0.2558
# 期间 2023-05 -> 2023-06: 样本数=3898, IC=0.1484
# 期间 2023-06 -> 2023-07: 样本数=3905, IC=0.0396
# 期间 2023-07 -> 2023-08: 样本数=3910, IC=0.2044
# 期间 2023-08 -> 2023-09: 样本数=3912, IC=0.1261
# 期间 2023-09 -> 2023-10: 样本数=3918, IC=0.1225
# 期间 2023-10 -> 2023-11: 样本数=3923, IC=0.3278
# 期间 2023-11 -> 2023-12: 样本数=4607, IC=0.1218
#
# ami6 IC统计:
# 计算期数: 203
# IC均值: 0.0552
# IC标准差: 0.1385
# IC_IR: 0.3988
#
# 处理投资组合: ami9
# 期间 2007-01 -> 2007-02: 样本数=1061, IC=0.1944
# 期间 2007-02 -> 2007-03: 样本数=1173, IC=0.3115
# 期间 2007-03 -> 2007-04: 样本数=1180, IC=-0.0166
# 期间 2007-04 -> 2007-05: 样本数=1157, IC=-0.0223
# 期间 2007-05 -> 2007-06: 样本数=1160, IC=-0.2598
# 期间 2007-06 -> 2007-07: 样本数=1168, IC=0.1000
# 期间 2007-07 -> 2007-08: 样本数=1177, IC=-0.0675
# 期间 2007-08 -> 2007-09: 样本数=1176, IC=-0.0701
# 期间 2007-09 -> 2007-10: 样本数=1169, IC=-0.1491
# 期间 2007-10 -> 2007-11: 样本数=1166, IC=0.2920
# 期间 2007-11 -> 2007-12: 样本数=1172, IC=0.0420
# 期间 2007-12 -> 2008-01: 样本数=1166, IC=0.0414
# 期间 2008-01 -> 2008-02: 样本数=1163, IC=0.1911
# 期间 2008-02 -> 2008-03: 样本数=1173, IC=0.1200
# 期间 2008-03 -> 2008-04: 样本数=1172, IC=-0.1782
# 期间 2008-04 -> 2008-05: 样本数=1171, IC=0.1904
# 期间 2008-05 -> 2008-06: 样本数=1172, IC=-0.0426
# 期间 2008-06 -> 2008-07: 样本数=1192, IC=0.2780
# 期间 2008-07 -> 2008-08: 样本数=1194, IC=0.0936
# 期间 2008-08 -> 2008-09: 样本数=1202, IC=-0.1957
# 期间 2008-09 -> 2008-10: 样本数=1211, IC=0.1668
# 期间 2008-10 -> 2008-11: 样本数=1227, IC=0.1073
# 期间 2008-11 -> 2008-12: 样本数=1246, IC=0.1521
# 期间 2008-12 -> 2009-01: 样本数=1253, IC=-0.0441
# 期间 2009-01 -> 2009-02: 样本数=1255, IC=0.0884
# 期间 2009-02 -> 2009-03: 样本数=1345, IC=0.1141
# 期间 2009-03 -> 2009-04: 样本数=1344, IC=0.1764
# 期间 2009-04 -> 2009-05: 样本数=1341, IC=0.1645
# 期间 2009-05 -> 2009-06: 样本数=1355, IC=0.0561
# 期间 2009-06 -> 2009-07: 样本数=1352, IC=-0.0980
# 期间 2009-07 -> 2009-08: 样本数=1355, IC=0.1657
# 期间 2009-08 -> 2009-09: 样本数=1356, IC=0.0151
# 期间 2009-09 -> 2009-10: 样本数=1361, IC=0.0733
# 期间 2009-10 -> 2009-11: 样本数=1359, IC=0.1095
# 期间 2009-11 -> 2009-12: 样本数=1360, IC=0.0950
# 期间 2009-12 -> 2010-01: 样本数=1354, IC=0.1431
# 期间 2010-01 -> 2010-02: 样本数=1354, IC=0.2372
# 期间 2010-02 -> 2010-03: 样本数=1479, IC=0.2152
# 期间 2010-03 -> 2010-04: 样本数=1476, IC=0.0489
# 期间 2010-04 -> 2010-05: 样本数=1468, IC=0.0336
# 期间 2010-05 -> 2010-06: 样本数=1467, IC=0.0496
# 期间 2010-06 -> 2010-07: 样本数=1463, IC=0.0911
# 期间 2010-07 -> 2010-08: 样本数=1463, IC=0.1847
# 期间 2010-08 -> 2010-09: 样本数=1461, IC=0.0228
# 期间 2010-09 -> 2010-10: 样本数=1457, IC=-0.2718
# 期间 2010-10 -> 2010-11: 样本数=1457, IC=0.2305
# 期间 2010-11 -> 2010-12: 样本数=1456, IC=0.0499
# 期间 2010-12 -> 2011-01: 样本数=1451, IC=0.0091
# 期间 2011-01 -> 2011-02: 样本数=1449, IC=0.0320
# 期间 2011-02 -> 2011-03: 样本数=1505, IC=0.2063
# 期间 2011-03 -> 2011-04: 样本数=1496, IC=0.0624
# 期间 2011-04 -> 2011-05: 样本数=1490, IC=0.0156
# 期间 2011-05 -> 2011-06: 样本数=1494, IC=0.0760
# 期间 2011-06 -> 2011-07: 样本数=1495, IC=0.1458
# 期间 2011-07 -> 2011-08: 样本数=1490, IC=0.1779
# 期间 2011-08 -> 2011-09: 样本数=1490, IC=0.0419
# 期间 2011-09 -> 2011-10: 样本数=1494, IC=-0.0497
# 期间 2011-10 -> 2011-11: 样本数=1488, IC=0.1502
# 期间 2011-11 -> 2011-12: 样本数=1483, IC=-0.1651
# 期间 2011-12 -> 2012-01: 样本数=1485, IC=-0.1739
# 期间 2012-01 -> 2012-02: 样本数=1486, IC=0.1634
# 期间 2012-02 -> 2012-03: 样本数=1639, IC=0.1126
# 期间 2012-03 -> 2012-04: 样本数=1640, IC=-0.0187
# 期间 2012-04 -> 2012-05: 样本数=1637, IC=-0.0125
# 期间 2012-05 -> 2012-06: 样本数=1644, IC=0.1353
# 期间 2012-06 -> 2012-07: 样本数=1643, IC=-0.1012
# 期间 2012-07 -> 2012-08: 样本数=1645, IC=0.3094
# 期间 2012-08 -> 2012-09: 样本数=1650, IC=-0.1246
# 期间 2012-09 -> 2012-10: 样本数=1649, IC=0.2423
# 期间 2012-10 -> 2012-11: 样本数=1660, IC=-0.0355
# 期间 2012-11 -> 2012-12: 样本数=1661, IC=-0.1689
# 期间 2012-12 -> 2013-01: 样本数=1655, IC=0.0446
# 期间 2013-01 -> 2013-02: 样本数=1656, IC=0.1331
# 期间 2013-02 -> 2013-03: 样本数=1989, IC=0.1791
# 期间 2013-03 -> 2013-04: 样本数=1983, IC=-0.0358
# 期间 2013-04 -> 2013-05: 样本数=1981, IC=0.1298
# 期间 2013-05 -> 2013-06: 样本数=1955, IC=0.1144
# 期间 2013-06 -> 2013-07: 样本数=1947, IC=0.1759
# 期间 2013-07 -> 2013-08: 样本数=1946, IC=0.0886
# 期间 2013-08 -> 2013-09: 样本数=1939, IC=0.0660
# 期间 2013-09 -> 2013-10: 样本数=1939, IC=0.0352
# 期间 2013-10 -> 2013-11: 样本数=1935, IC=0.1527
# 期间 2013-11 -> 2013-12: 样本数=1927, IC=0.0593
# 期间 2013-12 -> 2014-01: 样本数=1924, IC=0.1977
# 期间 2014-01 -> 2014-02: 样本数=1925, IC=0.1959
# 期间 2014-02 -> 2014-03: 样本数=2112, IC=0.1504
# 期间 2014-03 -> 2014-04: 样本数=2078, IC=0.0221
# 期间 2014-04 -> 2014-05: 样本数=2037, IC=0.0880
# 期间 2014-05 -> 2014-06: 样本数=2020, IC=0.1323
# 期间 2014-06 -> 2014-07: 样本数=2004, IC=0.0427
# 期间 2014-07 -> 2014-08: 样本数=1970, IC=0.2344
# 期间 2014-08 -> 2014-09: 样本数=1961, IC=0.2890
# 期间 2014-09 -> 2014-10: 样本数=1939, IC=-0.0267
# 期间 2014-10 -> 2014-11: 样本数=1928, IC=-0.0114
# 期间 2014-11 -> 2014-12: 样本数=1930, IC=-0.3341
# 期间 2014-12 -> 2015-01: 样本数=1909, IC=0.1340
# 期间 2015-01 -> 2015-02: 样本数=1891, IC=0.0835
# 期间 2015-02 -> 2015-03: 样本数=1992, IC=0.1813
# 期间 2015-03 -> 2015-04: 样本数=1963, IC=0.0360
# 期间 2015-04 -> 2015-05: 样本数=1914, IC=0.2588
# 期间 2015-05 -> 2015-06: 样本数=1882, IC=-0.0857
# 期间 2015-06 -> 2015-07: 样本数=1814, IC=-0.0865
# 期间 2015-07 -> 2015-08: 样本数=1738, IC=-0.0505
# 期间 2015-08 -> 2015-09: 样本数=1708, IC=0.1745
# 期间 2015-09 -> 2015-10: 样本数=1724, IC=0.2667
# 期间 2015-10 -> 2015-11: 样本数=1754, IC=0.3448
# 期间 2015-11 -> 2015-12: 样本数=1783, IC=0.2124
# 期间 2015-12 -> 2016-01: 样本数=1782, IC=-0.2119
# 期间 2016-01 -> 2016-02: 样本数=1809, IC=0.0056
# 期间 2016-02 -> 2016-03: 样本数=1893, IC=0.1912
# 期间 2016-03 -> 2016-04: 样本数=1934, IC=0.1944
# 期间 2016-04 -> 2016-05: 样本数=1972, IC=-0.1557
# 期间 2016-05 -> 2016-06: 样本数=2029, IC=0.1324
# 期间 2016-06 -> 2016-07: 样本数=2056, IC=-0.0878
# 期间 2016-07 -> 2016-08: 样本数=2069, IC=0.1536
# 期间 2016-08 -> 2016-09: 样本数=2092, IC=0.2768
# 期间 2016-09 -> 2016-10: 样本数=2084, IC=0.0678
# 期间 2016-10 -> 2016-11: 样本数=2114, IC=-0.0351
# 期间 2016-11 -> 2016-12: 样本数=2127, IC=0.1909
# 期间 2016-12 -> 2017-01: 样本数=2153, IC=-0.1682
# 期间 2017-01 -> 2017-02: 样本数=2158, IC=0.0217
# 期间 2017-02 -> 2017-03: 样本数=2263, IC=-0.0912
# 期间 2017-03 -> 2017-04: 样本数=2268, IC=-0.1668
# 期间 2017-04 -> 2017-05: 样本数=2250, IC=-0.0964
# 期间 2017-05 -> 2017-06: 样本数=2246, IC=-0.1221
# 期间 2017-06 -> 2017-07: 样本数=2254, IC=-0.1826
# 期间 2017-07 -> 2017-08: 样本数=2232, IC=0.0900
# 期间 2017-08 -> 2017-09: 样本数=2259, IC=0.0431
# 期间 2017-09 -> 2017-10: 样本数=2261, IC=-0.0838
# 期间 2017-10 -> 2017-11: 样本数=2269, IC=-0.1706
# 期间 2017-11 -> 2017-12: 样本数=2270, IC=-0.0759
# 期间 2017-12 -> 2018-01: 样本数=2269, IC=-0.2115
# 期间 2018-01 -> 2018-02: 样本数=2276, IC=-0.0965
# 期间 2018-02 -> 2018-03: 样本数=2409, IC=0.2619
# 期间 2018-03 -> 2018-04: 样本数=2402, IC=-0.0180
# 期间 2018-04 -> 2018-05: 样本数=2407, IC=0.0152
# 期间 2018-05 -> 2018-06: 样本数=2401, IC=-0.1661
# 期间 2018-06 -> 2018-07: 样本数=2409, IC=0.1051
# 期间 2018-07 -> 2018-08: 样本数=2427, IC=0.0191
# 期间 2018-08 -> 2018-09: 样本数=2463, IC=-0.0724
# 期间 2018-09 -> 2018-10: 样本数=2501, IC=0.1233
# 期间 2018-10 -> 2018-11: 样本数=2569, IC=0.2389
# 期间 2018-11 -> 2018-12: 样本数=2615, IC=0.0388
# 期间 2018-12 -> 2019-01: 样本数=2669, IC=-0.1391
# 期间 2019-01 -> 2019-02: 样本数=2714, IC=0.0221
# 期间 2019-02 -> 2019-03: 样本数=2918, IC=0.1254
# 期间 2019-03 -> 2019-04: 样本数=2943, IC=0.0037
# 期间 2019-04 -> 2019-05: 样本数=2957, IC=0.1362
# 期间 2019-05 -> 2019-06: 样本数=2970, IC=-0.0901
# 期间 2019-06 -> 2019-07: 样本数=2975, IC=-0.0776
# 期间 2019-07 -> 2019-08: 样本数=2974, IC=-0.0425
# 期间 2019-08 -> 2019-09: 样本数=2980, IC=0.0421
# 期间 2019-09 -> 2019-10: 样本数=2980, IC=-0.0168
# 期间 2019-10 -> 2019-11: 样本数=2982, IC=-0.0583
# 期间 2019-11 -> 2019-12: 样本数=2981, IC=-0.0600
# 期间 2019-12 -> 2020-01: 样本数=2982, IC=-0.0361
# 期间 2020-01 -> 2020-02: 样本数=2981, IC=-0.1314
# 期间 2020-02 -> 2020-03: 样本数=3210, IC=0.2355
# 期间 2020-03 -> 2020-04: 样本数=3206, IC=-0.1923
# 期间 2020-04 -> 2020-05: 样本数=3200, IC=0.0773
# 期间 2020-05 -> 2020-06: 样本数=3199, IC=-0.1408
# 期间 2020-06 -> 2020-07: 样本数=3194, IC=-0.0029
# 期间 2020-07 -> 2020-08: 样本数=3189, IC=0.1131
# 期间 2020-08 -> 2020-09: 样本数=3189, IC=0.0846
# 期间 2020-09 -> 2020-10: 样本数=3189, IC=0.0679
# 期间 2020-10 -> 2020-11: 样本数=3189, IC=-0.0095
# 期间 2020-11 -> 2020-12: 样本数=3191, IC=-0.1657
# 期间 2020-12 -> 2021-01: 样本数=3191, IC=-0.1538
# 期间 2021-01 -> 2021-02: 样本数=3188, IC=0.1694
# 期间 2021-02 -> 2021-03: 样本数=3339, IC=0.2982
# 期间 2021-03 -> 2021-04: 样本数=3339, IC=-0.0200
# 期间 2021-04 -> 2021-05: 样本数=3339, IC=0.0361
# 期间 2021-05 -> 2021-06: 样本数=3340, IC=0.1228
# 期间 2021-06 -> 2021-07: 样本数=3340, IC=0.0304
# 期间 2021-07 -> 2021-08: 样本数=3340, IC=0.0794
# 期间 2021-08 -> 2021-09: 样本数=3338, IC=0.0182
# 期间 2021-09 -> 2021-10: 样本数=3338, IC=-0.0998
# 期间 2021-10 -> 2021-11: 样本数=3360, IC=0.1898
# 期间 2021-11 -> 2021-12: 样本数=3359, IC=0.1087
# 期间 2021-12 -> 2022-01: 样本数=3360, IC=0.1930
# 期间 2022-01 -> 2022-02: 样本数=3361, IC=-0.0108
# 期间 2022-02 -> 2022-03: 样本数=3533, IC=0.2551
# 期间 2022-03 -> 2022-04: 样本数=3533, IC=-0.1361
# 期间 2022-04 -> 2022-05: 样本数=3505, IC=0.1205
# 期间 2022-05 -> 2022-06: 样本数=3496, IC=-0.1608
# 期间 2022-06 -> 2022-07: 样本数=3496, IC=0.2990
# 期间 2022-07 -> 2022-08: 样本数=3496, IC=0.0371
# 期间 2022-08 -> 2022-09: 样本数=3496, IC=-0.0065
# 期间 2022-09 -> 2022-10: 样本数=3498, IC=0.1256
# 期间 2022-10 -> 2022-11: 样本数=3501, IC=-0.0046
# 期间 2022-11 -> 2022-12: 样本数=3510, IC=-0.0766
# 期间 2022-12 -> 2023-01: 样本数=3515, IC=0.0057
# 期间 2023-01 -> 2023-02: 样本数=3513, IC=0.1146
# 期间 2023-02 -> 2023-03: 样本数=3925, IC=0.0282
# 期间 2023-03 -> 2023-04: 样本数=3921, IC=-0.0239
# 期间 2023-04 -> 2023-05: 样本数=3901, IC=0.2603
# 期间 2023-05 -> 2023-06: 样本数=3889, IC=0.1173
# 期间 2023-06 -> 2023-07: 样本数=3893, IC=0.0184
# 期间 2023-07 -> 2023-08: 样本数=3893, IC=0.2251
# 期间 2023-08 -> 2023-09: 样本数=3897, IC=0.1219
# 期间 2023-09 -> 2023-10: 样本数=3904, IC=0.1193
# 期间 2023-10 -> 2023-11: 样本数=3909, IC=0.3262
# 期间 2023-11 -> 2023-12: 样本数=3911, IC=0.1181
#
# ami9 IC统计:
# 计算期数: 203
# IC均值: 0.0512
# IC标准差: 0.1359
# IC_IR: 0.3771
#
# 处理投资组合: ami12
# 期间 2007-01 -> 2007-02: 样本数=1034, IC=0.2021
# 期间 2007-02 -> 2007-03: 样本数=1067, IC=0.3345
# 期间 2007-03 -> 2007-04: 样本数=1078, IC=-0.0299
# 期间 2007-04 -> 2007-05: 样本数=1058, IC=0.0024
# 期间 2007-05 -> 2007-06: 样本数=1155, IC=-0.2595
# 期间 2007-06 -> 2007-07: 样本数=1161, IC=0.1104
# 期间 2007-07 -> 2007-08: 样本数=1171, IC=-0.0717
# 期间 2007-08 -> 2007-09: 样本数=1167, IC=-0.0654
# 期间 2007-09 -> 2007-10: 样本数=1158, IC=-0.1750
# 期间 2007-10 -> 2007-11: 样本数=1156, IC=0.2988
# 期间 2007-11 -> 2007-12: 样本数=1166, IC=0.0379
# 期间 2007-12 -> 2008-01: 样本数=1162, IC=0.0306
# 期间 2008-01 -> 2008-02: 样本数=1160, IC=0.1740
# 期间 2008-02 -> 2008-03: 样本数=1163, IC=0.0981
# 期间 2008-03 -> 2008-04: 样本数=1161, IC=-0.1634
# 期间 2008-04 -> 2008-05: 样本数=1160, IC=0.2014
# 期间 2008-05 -> 2008-06: 样本数=1172, IC=-0.0383
# 期间 2008-06 -> 2008-07: 样本数=1191, IC=0.2689
# 期间 2008-07 -> 2008-08: 样本数=1194, IC=0.0792
# 期间 2008-08 -> 2008-09: 样本数=1202, IC=-0.2110
# 期间 2008-09 -> 2008-10: 样本数=1210, IC=0.1665
# 期间 2008-10 -> 2008-11: 样本数=1226, IC=0.1079
# 期间 2008-11 -> 2008-12: 样本数=1245, IC=0.1580
# 期间 2008-12 -> 2009-01: 样本数=1253, IC=-0.0440
# 期间 2009-01 -> 2009-02: 样本数=1255, IC=0.0847
# 期间 2009-02 -> 2009-03: 样本数=1257, IC=0.1197
# 期间 2009-03 -> 2009-04: 样本数=1255, IC=0.1764
# 期间 2009-04 -> 2009-05: 样本数=1252, IC=0.1609
# 期间 2009-05 -> 2009-06: 样本数=1354, IC=0.0579
# 期间 2009-06 -> 2009-07: 样本数=1352, IC=-0.1137
# 期间 2009-07 -> 2009-08: 样本数=1354, IC=0.1671
# 期间 2009-08 -> 2009-09: 样本数=1355, IC=0.0253
# 期间 2009-09 -> 2009-10: 样本数=1359, IC=0.0984
# 期间 2009-10 -> 2009-11: 样本数=1358, IC=0.0910
# 期间 2009-11 -> 2009-12: 样本数=1359, IC=0.0888
# 期间 2009-12 -> 2010-01: 样本数=1353, IC=0.1294
# 期间 2010-01 -> 2010-02: 样本数=1354, IC=0.2330
# 期间 2010-02 -> 2010-03: 样本数=1354, IC=0.2057
# 期间 2010-03 -> 2010-04: 样本数=1351, IC=0.0329
# 期间 2010-04 -> 2010-05: 样本数=1345, IC=0.0188
# 期间 2010-05 -> 2010-06: 样本数=1466, IC=0.0554
# 期间 2010-06 -> 2010-07: 样本数=1462, IC=0.0924
# 期间 2010-07 -> 2010-08: 样本数=1461, IC=0.1937
# 期间 2010-08 -> 2010-09: 样本数=1460, IC=0.0211
# 期间 2010-09 -> 2010-10: 样本数=1455, IC=-0.2750
# 期间 2010-10 -> 2010-11: 样本数=1456, IC=0.2383
# 期间 2010-11 -> 2010-12: 样本数=1455, IC=0.0450
# 期间 2010-12 -> 2011-01: 样本数=1451, IC=-0.0039
# 期间 2011-01 -> 2011-02: 样本数=1449, IC=0.0346
# 期间 2011-02 -> 2011-03: 样本数=1451, IC=0.2042
# 期间 2011-03 -> 2011-04: 样本数=1443, IC=0.0463
# 期间 2011-04 -> 2011-05: 样本数=1437, IC=0.0164
# 期间 2011-05 -> 2011-06: 样本数=1494, IC=0.0955
# 期间 2011-06 -> 2011-07: 样本数=1495, IC=0.1476
# 期间 2011-07 -> 2011-08: 样本数=1490, IC=0.1636
# 期间 2011-08 -> 2011-09: 样本数=1490, IC=0.0236
# 期间 2011-09 -> 2011-10: 样本数=1493, IC=-0.0479
# 期间 2011-10 -> 2011-11: 样本数=1487, IC=0.1484
# 期间 2011-11 -> 2011-12: 样本数=1482, IC=-0.1862
# 期间 2011-12 -> 2012-01: 样本数=1485, IC=-0.1617
# 期间 2012-01 -> 2012-02: 样本数=1485, IC=0.1687
# 期间 2012-02 -> 2012-03: 样本数=1486, IC=0.1172
# 期间 2012-03 -> 2012-04: 样本数=1488, IC=0.0103
# 期间 2012-04 -> 2012-05: 样本数=1485, IC=-0.0116
# 期间 2012-05 -> 2012-06: 样本数=1643, IC=0.1472
# 期间 2012-06 -> 2012-07: 样本数=1642, IC=-0.0975
# 期间 2012-07 -> 2012-08: 样本数=1644, IC=0.3101
# 期间 2012-08 -> 2012-09: 样本数=1648, IC=-0.1323
# 期间 2012-09 -> 2012-10: 样本数=1645, IC=0.2386
# 期间 2012-10 -> 2012-11: 样本数=1655, IC=-0.0488
# 期间 2012-11 -> 2012-12: 样本数=1657, IC=-0.1468
# 期间 2012-12 -> 2013-01: 样本数=1654, IC=0.0449
# 期间 2013-01 -> 2013-02: 样本数=1656, IC=0.1437
# 期间 2013-02 -> 2013-03: 样本数=1647, IC=0.2255
# 期间 2013-03 -> 2013-04: 样本数=1641, IC=-0.0528
# 期间 2013-04 -> 2013-05: 样本数=1639, IC=0.1177
# 期间 2013-05 -> 2013-06: 样本数=1951, IC=0.1056
# 期间 2013-06 -> 2013-07: 样本数=1945, IC=0.1702
# 期间 2013-07 -> 2013-08: 样本数=1944, IC=0.0831
# 期间 2013-08 -> 2013-09: 样本数=1931, IC=0.0704
# 期间 2013-09 -> 2013-10: 样本数=1931, IC=0.0228
# 期间 2013-10 -> 2013-11: 样本数=1924, IC=0.1722
# 期间 2013-11 -> 2013-12: 样本数=1921, IC=0.0706
# 期间 2013-12 -> 2014-01: 样本数=1922, IC=0.2411
# 期间 2014-01 -> 2014-02: 样本数=1924, IC=0.1915
# 期间 2014-02 -> 2014-03: 样本数=1914, IC=0.1430
# 期间 2014-03 -> 2014-04: 样本数=1884, IC=0.0048
# 期间 2014-04 -> 2014-05: 样本数=1852, IC=0.0876
# 期间 2014-05 -> 2014-06: 样本数=2020, IC=0.1272
# 期间 2014-06 -> 2014-07: 样本数=2004, IC=0.0240
# 期间 2014-07 -> 2014-08: 样本数=1970, IC=0.2320
# 期间 2014-08 -> 2014-09: 样本数=1959, IC=0.2862
# 期间 2014-09 -> 2014-10: 样本数=1921, IC=-0.0349
# 期间 2014-10 -> 2014-11: 样本数=1902, IC=-0.0282
# 期间 2014-11 -> 2014-12: 样本数=1903, IC=-0.3386
# 期间 2014-12 -> 2015-01: 样本数=1900, IC=0.1182
# 期间 2015-01 -> 2015-02: 样本数=1886, IC=0.0670
# 期间 2015-02 -> 2015-03: 样本数=1905, IC=0.1832
# 期间 2015-03 -> 2015-04: 样本数=1877, IC=0.0497
# 期间 2015-04 -> 2015-05: 样本数=1833, IC=0.2510
# 期间 2015-05 -> 2015-06: 样本数=1875, IC=-0.0630
# 期间 2015-06 -> 2015-07: 样本数=1810, IC=-0.0832
# 期间 2015-07 -> 2015-08: 样本数=1737, IC=-0.0442
# 期间 2015-08 -> 2015-09: 样本数=1704, IC=0.1672
# 期间 2015-09 -> 2015-10: 样本数=1707, IC=0.2657
# 期间 2015-10 -> 2015-11: 样本数=1731, IC=0.3362
# 期间 2015-11 -> 2015-12: 样本数=1762, IC=0.2018
# 期间 2015-12 -> 2016-01: 样本数=1771, IC=-0.2245
# 期间 2016-01 -> 2016-02: 样本数=1804, IC=-0.0089
# 期间 2016-02 -> 2016-03: 样本数=1857, IC=0.1931
# 期间 2016-03 -> 2016-04: 样本数=1896, IC=0.2001
# 期间 2016-04 -> 2016-05: 样本数=1932, IC=-0.1686
# 期间 2016-05 -> 2016-06: 样本数=2017, IC=0.1491
# 期间 2016-06 -> 2016-07: 样本数=2048, IC=-0.1498
# 期间 2016-07 -> 2016-08: 样本数=2060, IC=0.1004
# 期间 2016-08 -> 2016-09: 样本数=2084, IC=0.2468
# 期间 2016-09 -> 2016-10: 样本数=2076, IC=0.0613
# 期间 2016-10 -> 2016-11: 样本数=2105, IC=-0.0494
# 期间 2016-11 -> 2016-12: 样本数=2120, IC=0.1792
# 期间 2016-12 -> 2017-01: 样本数=2146, IC=-0.1832
# 期间 2017-01 -> 2017-02: 样本数=2157, IC=0.0364
# 期间 2017-02 -> 2017-03: 样本数=2176, IC=-0.1002
# 期间 2017-03 -> 2017-04: 样本数=2180, IC=-0.1741
# 期间 2017-04 -> 2017-05: 样本数=2164, IC=-0.0988
# 期间 2017-05 -> 2017-06: 样本数=2243, IC=-0.1120
# 期间 2017-06 -> 2017-07: 样本数=2248, IC=-0.1812
# 期间 2017-07 -> 2017-08: 样本数=2223, IC=0.0802
# 期间 2017-08 -> 2017-09: 样本数=2249, IC=0.0309
# 期间 2017-09 -> 2017-10: 样本数=2252, IC=-0.0854
# 期间 2017-10 -> 2017-11: 样本数=2256, IC=-0.1625
# 期间 2017-11 -> 2017-12: 样本数=2258, IC=-0.0771
# 期间 2017-12 -> 2018-01: 样本数=2258, IC=-0.2144
# 期间 2018-01 -> 2018-02: 样本数=2271, IC=-0.0816
# 期间 2018-02 -> 2018-03: 样本数=2268, IC=0.2462
# 期间 2018-03 -> 2018-04: 样本数=2263, IC=-0.0152
# 期间 2018-04 -> 2018-05: 样本数=2269, IC=0.0018
# 期间 2018-05 -> 2018-06: 样本数=2391, IC=-0.1611
# 期间 2018-06 -> 2018-07: 样本数=2398, IC=0.0907
# 期间 2018-07 -> 2018-08: 样本数=2419, IC=0.0122
# 期间 2018-08 -> 2018-09: 样本数=2455, IC=-0.0767
# 期间 2018-09 -> 2018-10: 样本数=2483, IC=0.1212
# 期间 2018-10 -> 2018-11: 样本数=2543, IC=0.2337
# 期间 2018-11 -> 2018-12: 样本数=2584, IC=0.0384
# 期间 2018-12 -> 2019-01: 样本数=2641, IC=-0.1519
# 期间 2019-01 -> 2019-02: 样本数=2698, IC=0.0243
# 期间 2019-02 -> 2019-03: 样本数=2727, IC=0.1195
# 期间 2019-03 -> 2019-04: 样本数=2754, IC=0.0149
# 期间 2019-04 -> 2019-05: 样本数=2771, IC=0.1359
# 期间 2019-05 -> 2019-06: 样本数=2963, IC=-0.0938
# 期间 2019-06 -> 2019-07: 样本数=2969, IC=-0.0780
# 期间 2019-07 -> 2019-08: 样本数=2969, IC=-0.0417
# 期间 2019-08 -> 2019-09: 样本数=2971, IC=0.0404
# 期间 2019-09 -> 2019-10: 样本数=2973, IC=-0.0120
# 期间 2019-10 -> 2019-11: 样本数=2971, IC=-0.0826
# 期间 2019-11 -> 2019-12: 样本数=2976, IC=-0.0538
# 期间 2019-12 -> 2020-01: 样本数=2977, IC=-0.0259
# 期间 2020-01 -> 2020-02: 样本数=2980, IC=-0.1288
# 期间 2020-02 -> 2020-03: 样本数=2980, IC=0.2254
# 期间 2020-03 -> 2020-04: 样本数=2976, IC=-0.1931
# 期间 2020-04 -> 2020-05: 样本数=2970, IC=0.0693
# 期间 2020-05 -> 2020-06: 样本数=3198, IC=-0.1234
# 期间 2020-06 -> 2020-07: 样本数=3194, IC=-0.0078
# 期间 2020-07 -> 2020-08: 样本数=3189, IC=0.0991
# 期间 2020-08 -> 2020-09: 样本数=3189, IC=0.0769
# 期间 2020-09 -> 2020-10: 样本数=3189, IC=0.0645
# 期间 2020-10 -> 2020-11: 样本数=3189, IC=-0.0215
# 期间 2020-11 -> 2020-12: 样本数=3191, IC=-0.1551
# 期间 2020-12 -> 2021-01: 样本数=3191, IC=-0.1658
# 期间 2021-01 -> 2021-02: 样本数=3188, IC=0.1626
# 期间 2021-02 -> 2021-03: 样本数=3188, IC=0.2923
# 期间 2021-03 -> 2021-04: 样本数=3187, IC=-0.0107
# 期间 2021-04 -> 2021-05: 样本数=3187, IC=0.0351
# 期间 2021-05 -> 2021-06: 样本数=3339, IC=0.1226
# 期间 2021-06 -> 2021-07: 样本数=3340, IC=0.0384
# 期间 2021-07 -> 2021-08: 样本数=3340, IC=0.0917
# 期间 2021-08 -> 2021-09: 样本数=3338, IC=0.0126
# 期间 2021-09 -> 2021-10: 样本数=3338, IC=-0.1106
# 期间 2021-10 -> 2021-11: 样本数=3338, IC=0.1823
# 期间 2021-11 -> 2021-12: 样本数=3337, IC=0.1070
# 期间 2021-12 -> 2022-01: 样本数=3338, IC=0.1777
# 期间 2022-01 -> 2022-02: 样本数=3361, IC=0.0162
# 期间 2022-02 -> 2022-03: 样本数=3361, IC=0.2552
# 期间 2022-03 -> 2022-04: 样本数=3356, IC=-0.1512
# 期间 2022-04 -> 2022-05: 样本数=3326, IC=0.1342
# 期间 2022-05 -> 2022-06: 样本数=3484, IC=-0.1661
# 期间 2022-06 -> 2022-07: 样本数=3489, IC=0.2937
# 期间 2022-07 -> 2022-08: 样本数=3491, IC=0.0429
# 期间 2022-08 -> 2022-09: 样本数=3495, IC=-0.0027
# 期间 2022-09 -> 2022-10: 样本数=3495, IC=0.1215
# 期间 2022-10 -> 2022-11: 样本数=3495, IC=0.0305
# 期间 2022-11 -> 2022-12: 样本数=3499, IC=-0.0793
# 期间 2022-12 -> 2023-01: 样本数=3505, IC=-0.0149
# 期间 2023-01 -> 2023-02: 样本数=3505, IC=0.1013
# 期间 2023-02 -> 2023-03: 样本数=3509, IC=-0.0119
# 期间 2023-03 -> 2023-04: 样本数=3506, IC=-0.0389
# 期间 2023-04 -> 2023-05: 样本数=3486, IC=0.2706
# 期间 2023-05 -> 2023-06: 样本数=3886, IC=0.1253
# 期间 2023-06 -> 2023-07: 样本数=3886, IC=-0.0011
# 期间 2023-07 -> 2023-08: 样本数=3888, IC=0.2418
# 期间 2023-08 -> 2023-09: 样本数=3888, IC=0.1144
# 期间 2023-09 -> 2023-10: 样本数=3892, IC=0.1159
# 期间 2023-10 -> 2023-11: 样本数=3892, IC=0.3303
# 期间 2023-11 -> 2023-12: 样本数=3896, IC=0.1113
#
# ami12 IC统计:
# 计算期数: 203
# IC均值: 0.0489
# IC标准差: 0.1369
# IC_IR: 0.3571
