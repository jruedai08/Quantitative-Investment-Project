# %%
# 导入必要的库
import pandas as pd
import numpy as np
from pathlib import Path
import warnings

# 忽略所有警告
warnings.filterwarnings('ignore')

# %%
# 设置文件路径
amihud_path = './amihud.pkl'
ede_excel_path = './EDE20241125.xlsx'  # 主板股票文件
price_month_path = './price_month.pkl'
dfin_path = './dfin_final.csv'
fs_combas_path = './FS_Combas.xlsx'  # 总资产数据文件

# 输出目录
output_dir = Path('./output')
output_dir.mkdir(exist_ok=True)

# %%
# %%time
# ------------------- 读取数据 -------------------

# 1. 读取 amihud.pkl
amihud_df = pd.read_pickle(amihud_path)
print(f"amihud数据行数: {amihud_df.shape[0]}")
print(f"amihud数据时间范围: {amihud_df['year'].min()}-{amihud_df['month'].min()} 到 {amihud_df['year'].max()}-{amihud_df['month'].max()}")

# 2. 读取 EDE20241125.xlsx，用于标记主板股票
ede_df = pd.read_excel(ede_excel_path)

# 提取主板股票代码，确保为6位字符串
if '股票代码' not in ede_df.columns:
    raise KeyError("EDE20241125.xlsx中缺少 '股票代码' 列。请检查文件格式。")

# 转换股票代码为字符串格式，并补全6位
ede_df['股票代码'] = ede_df['股票代码'].astype(str).str.split('.').str[0].str.zfill(6)
mainboard_codes = ede_df['股票代码'].unique()
print(f"主板股票代码数量: {len(mainboard_codes)}")
print(f"主板股票代码样例: {mainboard_codes[:5]}")

# 3. 读取 price_month.csv，选择需要的列，假设第一列是无用的索引列
# 需要的列为 'code', 'year', 'month', 'close_price', 'market_value', 'return', 'total_value', 'risk_free_month'
price_month_df = pd.read_pickle(
    price_month_path
)
price_month_df = price_month_df[['code', 'year', 'month', 'close_price', 'market_value', 'return', 'total_value', 'risk_free_month']]
price_month_df['code'] = price_month_df['code'].astype(str).str.zfill(6)  # 补全前导零至6位
price_month_df['risk_free_month'] = price_month_df['risk_free_month']*0.01
initial_price_month_rows = price_month_df.shape[0]
price_month_df.drop_duplicates(subset=['code', 'year', 'month'], inplace=True)
print(f"price_month去重前行数: {initial_price_month_rows}, 去重后行数: {price_month_df.shape[0]}")

# 4. 读取 dfin_final.csv，选择需要的列，假设第一列是无用的索引列
# 需要的列为 'code', 'year', 'month', 'dfin'
dfin_df = pd.read_csv(
    dfin_path,
    usecols=['code', 'year', 'month', 'dfin'],
    dtype={'code': str}
)
dfin_df['code'] = dfin_df['code'].str.zfill(6)  # 补全前导零至6位
initial_dfin_rows = dfin_df.shape[0]
dfin_df.drop_duplicates(subset=['code', 'year', 'month'], inplace=True)
print(f"dfin数据去重前行数: {initial_dfin_rows}, 去重后行数: {dfin_df.shape[0]}")

# ------------------- 读取并处理 FS_Combas.xlsx -------------------

# 5. 读取总资产数据
fs_df = pd.read_excel(fs_combas_path)

# 筛选 Typrep == 'A' 的合并报表
fs_df = fs_df[fs_df['Typrep'] == 'A']
print(f"筛选合并报表后的总资产数据行数: {fs_df.shape[0]}")

# 转换股票代码为字符串格式，并补全6位
fs_df['code'] = fs_df['Stkcd'].astype(str).str.zfill(6)

# 转换 Accper 为日期格式，并提取 year 和 month
fs_df['Accper'] = pd.to_datetime(fs_df['Accper'])
fs_df['year'] = fs_df['Accper'].dt.year
fs_df['month'] = fs_df['Accper'].dt.month
fs_df['day'] = fs_df['Accper'].dt.day

# 删除连续日期为上月最后一天和下月第一天的重复数据
fs_df = fs_df.sort_values(by=['code', 'Accper'])
fs_df['prev_Accper'] = fs_df.groupby('code')['Accper'].shift(1)
fs_df['date_diff'] = (fs_df['Accper'] - fs_df['prev_Accper']).dt.days
# 假设一个月最多有31天，且月末前一日到月初一日的差为1天
fs_df = fs_df[~((fs_df['date_diff'] == 1) & (fs_df['day'] == 1))]

# 删除辅助列
fs_df.drop(columns=['prev_Accper', 'date_diff', 'day'], inplace=True)

# 转换 A001000000 为亿元
fs_df['A001000000'] = fs_df['A001000000'] / 1e8  # 转换为亿元
fs_df.rename(columns={'A001000000': 'total_assets'}, inplace=True)

print(f"处理后的总资产数据行数: {fs_df.shape[0]}")

# ------------------- 将总资产数据与 dfin 进行匹配并标准化 -------------------

# 6. 为 dfin_df 添加日期列
dfin_df['date'] = pd.to_datetime(dfin_df['year'].astype(str) + '-' + dfin_df['month'].astype(str) + '-01')

# 7. 将 fs_df 的数据日期向后移动一个月，表示使用上一期的总资产
fs_df['next_date'] = fs_df.groupby('code')['Accper'].shift(-1)
fs_df['next_total_assets'] = fs_df.groupby('code')['total_assets'].shift(-1)

# 8. 创建总资产展开的数据
total_assets_expanded = []

for code, group in fs_df.groupby('code'):
    group = group.sort_values(by='Accper')
    for idx, row in group.iterrows():
        start_date = row['Accper'] + pd.Timedelta(days=1)
        if pd.notna(row['next_date']):
            end_date = row['next_date'] - pd.Timedelta(days=1)
        else:
            end_date = pd.Timestamp('2024-12-31')  # 设定一个结束日期
        
        ta = row['next_total_assets']
        if pd.isna(ta):
            ta = row['total_assets']  # 如果没有下一期总资产，使用当前期总资产
        
        # 生成每月的开始日期
        date_range = pd.date_range(start=start_date, end=end_date, freq='MS')
        temp_df = pd.DataFrame({
            'code': code,
            'date': date_range,
            'prev_total_assets': ta
        })
        total_assets_expanded.append(temp_df)

# 合并所有展开的数据
if total_assets_expanded:
    total_assets_df = pd.concat(total_assets_expanded, ignore_index=True)
    print(f"总资产展开后的数据行数: {total_assets_df.shape[0]}")
else:
    total_assets_df = pd.DataFrame(columns=['code', 'date', 'prev_total_assets'])
    print("总资产展开后的数据行数: 0")

# 9. 将 total_assets_df 与 dfin_df 合并
dfin_df = pd.merge(dfin_df, total_assets_df, on=['code', 'date'], how='left')
print(f"dfin与总资产合并后的数据行数: {dfin_df.shape[0]}")
print(f"dfin与总资产合并后的缺失值数: {dfin_df['prev_total_assets'].isna().sum()}")

# 10. 删除缺失 prev_total_assets 的行
dfin_df = dfin_df.dropna(subset=['prev_total_assets'])
print(f"删除缺失prev_total_assets后的数据行数: {dfin_df.shape[0]}")

# 11. 计算标准化的 dfin
dfin_df['dfin_standardized'] = dfin_df['dfin'] / dfin_df['prev_total_assets']
print(f"标准化后的dfin的描述统计:\n{dfin_df['dfin_standardized'].describe()}")

# 12. 删除辅助列
dfin_df.drop(columns=['prev_total_assets', 'date'], inplace=True)

# ------------------- 继续数据处理 -------------------

# 13. 确保 dfin_standardized 数据按股票代码和时间排序
dfin_df = dfin_df.sort_values(by=['code', 'year', 'month'])

# 14. 创建完整的年月范围
full_years = range(dfin_df['year'].min(), dfin_df['year'].max() + 1)
full_months = range(1, 13)
full_date_index = pd.MultiIndex.from_product(
    [dfin_df['code'].unique(), full_years, full_months],
    names=['code', 'year', 'month']
)

# 15. 使用 MultiIndex 重新索引，确保每只股票在所有年份和月份都有记录
dfin_df = dfin_df.set_index(['code', 'year', 'month']).reindex(full_date_index).reset_index()

# 16. 再次进行前向填充，确保所有空缺月份使用最新的 dfin_standardized 值
dfin_df['dfin_standardized'] = dfin_df.groupby('code')['dfin_standardized'].ffill()

# 17. 检查填充后的缺失值情况
print(f"dfin重新索引并填充后的缺失值数: {dfin_df['dfin_standardized'].isna().sum()}")

# ------------------- 合并数据 -------------------

# 18. 标记主板股票
mainboard_df = pd.DataFrame({'code': mainboard_codes, 'is_main_board': True})
merged_df = pd.merge(amihud_df, mainboard_df, on='code', how='left')
merged_df['is_main_board'] = merged_df['is_main_board'].fillna(False)
print(f"主板股票标记数量: {merged_df['is_main_board'].sum()}")

# 19. 处理日期格式，确保 year 和 month 为整数类型
merged_df['year'] = merged_df['year'].astype(int)
merged_df['month'] = merged_df['month'].astype(int)

# 20. 合并价格数据，基于 code、year 和 month
merged_df = pd.merge(merged_df, price_month_df, on=['code', 'year', 'month'], how='left')
print(f"合并价格数据后的数据行数: {merged_df.shape[0]}")
print(f"价格数据缺失值数: {merged_df['close_price'].isna().sum()}")

# 21. 合并标准化后的 dfin 数据，基于 code、year 和 month
merged_df = pd.merge(merged_df, dfin_df, on=['code', 'year', 'month'], how='left')
print(f"合并标准化后的dfin数据后的数据行数: {merged_df.shape[0]}")
print(f"标准化后的dfin缺失值数: {merged_df['dfin_standardized'].isna().sum()}")

# 22. 删除缺失 dfin_standardized 的行
merged_df = merged_df.dropna(subset=['dfin_standardized'])
print(f"删除缺失dfin_standardized后的数据行数: {merged_df.shape[0]}")

# 23. 删除缺失 return 或 market_value 的行
initial_rows = merged_df.shape[0]
merged_df = merged_df.dropna(subset=['return', 'market_value'])
print(f"删除缺失return或market_value前行数: {initial_rows}, 删除后行数: {merged_df.shape[0]}")

# 24. 添加 year_month 列，格式为 "YYYY-MM"
merged_df['year_month'] = merged_df['year'].astype(str) + '-' + merged_df['month'].astype(str).str.zfill(2)
print("year_month列已添加")
# Out:
# amihud数据行数: 636494
# amihud数据时间范围: 2005-1 到 2024-12
# 主板股票代码数量: 3173
# 主板股票代码样例: ['000001' '000002' '000004' '000006' '000007']
# price_month去重前行数: 818205, 去重后行数: 756603
# dfin数据去重前行数: 58036, 去重后行数: 58036
# 筛选合并报表后的总资产数据行数: 338696
# 处理后的总资产数据行数: 277531
# 总资产展开后的数据行数: 925189
# dfin与总资产合并后的数据行数: 58036
# dfin与总资产合并后的缺失值数: 0
# 删除缺失prev_total_assets后的数据行数: 58036
# 标准化后的dfin的描述统计:
# count    5.803600e+04
# mean             -inf
# std               NaN
# min              -inf
# 25%     -5.591565e+06
# 50%     -4.886176e+05
# 75%      3.170984e+06
# max      4.257925e+11
# Name: dfin_standardized, dtype: float64
# dfin重新索引并填充后的缺失值数: 1367919
# 主板股票标记数量: 473854
# 合并价格数据后的数据行数: 636494
# 价格数据缺失值数: 47920
# 合并标准化后的dfin数据后的数据行数: 636494
# 标准化后的dfin缺失值数: 70708
# 删除缺失dfin_standardized后的数据行数: 565786
# 删除缺失return或market_value前行数: 565786, 删除后行数: 520904
# year_month列已添加
# CPU times: total: 2min 32s
# Wall time: 7min 21s

# %%
# ------------------- 构造投资组合 -------------------

def calculate_investment_portfolio(data, value_column, period_name):
    """
    根据指定的指标计算投资组合
    :param data: 合并后的数据
    :param value_column: 用于计算投资组合的指标列名（如 'ami3', 'dfin_standardized'）
    :param period_name: 投资组合的名称，用于输出文件名
    """
    print(f"\n开始构造 {period_name} 投资组合")
    grouped = data.groupby(['year', 'month'])
    results = []

    for (year, month), group in grouped:
        year_month = f"{year}-{str(month).zfill(2)}"
        main_board_group = group[group['is_main_board']]
        main_board_count = main_board_group.shape[0]
        unique_values = main_board_group[value_column].nunique()
        print(f"月份 {year_month} - 主板股票数: {main_board_count}, {value_column}唯一值数: {unique_values}")
        
        # 确保主板股票数量和唯一值数目足够
        if unique_values < 5:
            print(f"跳过月份 {year_month}，因为{value_column}的主板股票唯一值数目少于5")
            continue
        
        # 计算分位数并分组
        try:
            # 使用主板股票计算分位数
            main_board_group = main_board_group.copy()
            main_board_group['quintile'] = pd.qcut(main_board_group[value_column], 5, labels=False, duplicates='drop')
        except Exception as e:
            print(f"跳过月份 {year_month}，分位数计算失败: {e}")
            continue
        
        # 创建 code 到 quintile 的映射
        quintile_map = main_board_group[['code', 'quintile']].drop_duplicates()
        
        # 合并 quintile_map 到所有股票
        group = pd.merge(group, quintile_map, on='code', how='left')
        
        # 做多最低分位组，做空最高分位组
        long_group = group[group['quintile'] == 0]
        short_group = group[group['quintile'] == 4]
        
        # 确保做多和做空组不为空
        if long_group.empty or short_group.empty:
            print(f"跳过月份 {year_month}，做多或做空组为空")
            continue
        
        # 计算流动市值加权收益
        try:
            # 流动市值加权
            long_weight = long_group['market_value'] / long_group['market_value'].sum()
            short_weight = short_group['market_value'] / short_group['market_value'].sum()
            
            return_long_mv = (long_weight * long_group['return']).sum()
            return_short_mv = (short_weight * short_group['return']).sum()
            anomaly_return_mv = return_long_mv - return_short_mv
            
            # 等权重收益
            return_long_eq = long_group['return'].mean()
            return_short_eq = short_group['return'].mean()
            anomaly_return_eq = return_long_eq - return_short_eq
            
            # 获取当前月的无风险收益率
            risk_free_rate = group['risk_free_month'].iloc[0] if 'risk_free_month' in group.columns else 0.0
            print(f"月份 {year_month} 的无风险收益率: {risk_free_rate}")
            
            # 计算做多组减做空组减无风险收益率
            anomaly_return_mv_rf = anomaly_return_mv - risk_free_rate
            anomaly_return_eq_rf = anomaly_return_eq - risk_free_rate
            
            # 存储结果
            results.append({
                'year_month': year_month,
                'return_long_mv': return_long_mv,
                'return_short_mv': return_short_mv,
                'risk_free_month': risk_free_rate,
                'anomaly_return_mv_rf': anomaly_return_mv_rf,
                'return_long_eq': return_long_eq,
                'return_short_eq': return_short_eq,
                'anomaly_return_eq_rf': anomaly_return_eq_rf
            })
        except Exception as e:
            print(f"计算收益时出错，月份 {year_month}: {e}")
            continue
    
    # 转为 DataFrame 并导出
    results_df = pd.DataFrame(results)
    if not results_df.empty:
        results_df = results_df.sort_values(by='year_month')
        # 选择输出列的顺序
        results_df = results_df[[
            'year_month',
            'return_long_mv',
            'return_short_mv',
            'risk_free_month',
            'anomaly_return_mv_rf',
            'return_long_eq',
            'return_short_eq',
            'anomaly_return_eq_rf'
        ]]
        results_df.to_excel(output_dir / f'{period_name}.xlsx', index=False)
        print(f"{period_name} 投资组合完成，生成记录数: {results_df.shape[0]}")
        print(f"{period_name} 投资组合已导出至 {output_dir / f'{period_name}.xlsx'}")
    else:
        print(f"{period_name} 投资组合结果为空，未生成任何记录。")

# ------------------- 计算投资组合 -------------------

# 25. 计算 ami3、ami6、ami9、ami12 投资组合
ami_periods = [3, 6, 9, 12]
for N in ami_periods:
    column_name = f'ami{N}'
    # 计算滚动平均 amihud，窗口为 N 个月，最小周期为 N，向前滚动，排除当前月
    merged_df[column_name] = merged_df.groupby('code')['amihud']\
        .rolling(window=N, min_periods=N).mean().shift(1).reset_index(level=0, drop=True)
    
    # 打印非缺失值数
    non_na_count = merged_df[column_name].notna().sum()
    print(f"{column_name} 计算完成，非缺失值数: {non_na_count}")
    
    # 计算投资组合
    calculate_investment_portfolio(merged_df, column_name, column_name)

# 26. 计算 dfin_standardized 投资组合
calculate_investment_portfolio(merged_df, 'dfin_standardized', 'dfin_standardized')

print("\n所有投资组合已完成，结果存储在 output 目录。")
# Out:
# ami3 计算完成，非缺失值数: 511119
#
# 开始构造 ami3 投资组合
# 月份 2005-06 - 主板股票数: 1075, ami3唯一值数: 1074
# 月份 2005-06 的无风险收益率: 0.001856
# 月份 2005-07 - 主板股票数: 1074, ami3唯一值数: 0
# 跳过月份 2005-07，因为ami3的主板股票唯一值数目少于5
# 月份 2005-08 - 主板股票数: 1073, ami3唯一值数: 0
# 跳过月份 2005-08，因为ami3的主板股票唯一值数目少于5
# 月份 2005-09 - 主板股票数: 1072, ami3唯一值数: 1072
# 月份 2005-09 的无风险收益率: 0.001856
# 月份 2005-10 - 主板股票数: 1070, ami3唯一值数: 1070
# 月份 2005-10 的无风险收益率: 0.001856
# 月份 2005-11 - 主板股票数: 1069, ami3唯一值数: 1068
# 月份 2005-11 的无风险收益率: 0.001856
# 月份 2005-12 - 主板股票数: 1063, ami3唯一值数: 1060
# 月份 2005-12 的无风险收益率: 0.001856
# 月份 2006-01 - 主板股票数: 1045, ami3唯一值数: 1040
# 月份 2006-01 的无风险收益率: 0.001856
# 月份 2006-02 - 主板股票数: 1028, ami3唯一值数: 1024
# 月份 2006-02 的无风险收益率: 0.001856
# 月份 2006-03 - 主板股票数: 1014, ami3唯一值数: 1014
# 月份 2006-03 的无风险收益率: 0.001856
# 月份 2006-04 - 主板股票数: 1073, ami3唯一值数: 1071
# 月份 2006-04 的无风险收益率: 0.001856
# 月份 2006-05 - 主板股票数: 1040, ami3唯一值数: 947
# 月份 2006-05 的无风险收益率: 0.001856
# 月份 2006-06 - 主板股票数: 1042, ami3唯一值数: 950
# 月份 2006-06 的无风险收益率: 0.001856
# 月份 2006-07 - 主板股票数: 1046, ami3唯一值数: 1043
# 月份 2006-07 的无风险收益率: 0.001856
# 月份 2006-08 - 主板股票数: 1044, ami3唯一值数: 1041
# 月份 2006-08 的无风险收益率: 0.001856
# 月份 2006-09 - 主板股票数: 1051, ami3唯一值数: 1049
# 月份 2006-09 的无风险收益率: 0.002076
# 月份 2006-10 - 主板股票数: 1064, ami3唯一值数: 1061
# 月份 2006-10 的无风险收益率: 0.002076
# 月份 2006-11 - 主板股票数: 1079, ami3唯一值数: 1076
# 月份 2006-11 的无风险收益率: 0.002076
# 月份 2006-12 - 主板股票数: 1080, ami3唯一值数: 1077
# 月份 2006-12 的无风险收益率: 0.002076
# 月份 2007-01 - 主板股票数: 1066, ami3唯一值数: 1064
# 月份 2007-01 的无风险收益率: 0.002076
# 月份 2007-02 - 主板股票数: 1069, ami3唯一值数: 1069
# 月份 2007-02 的无风险收益率: 0.002076
# 月份 2007-03 - 主板股票数: 1076, ami3唯一值数: 1076
# 月份 2007-03 的无风险收益率: 0.002076
# 月份 2007-04 - 主板股票数: 1096, ami3唯一值数: 1096
# 月份 2007-04 的无风险收益率: 0.002296
# 月份 2007-05 - 主板股票数: 1074, ami3唯一值数: 1063
# 月份 2007-05 的无风险收益率: 0.002296
# 月份 2007-06 - 主板股票数: 1076, ami3唯一值数: 1065
# 月份 2007-06 的无风险收益率: 0.002515
# 月份 2007-07 - 主板股票数: 1087, ami3唯一值数: 1087
# 月份 2007-07 的无风险收益率: 0.002515
# 月份 2007-08 - 主板股票数: 1092, ami3唯一值数: 1092
# 月份 2007-08 的无风险收益率: 0.002734
# 月份 2007-09 - 主板股票数: 1084, ami3唯一值数: 1084
# 月份 2007-09 的无风险收益率: 0.002952
# 月份 2007-10 - 主板股票数: 1076, ami3唯一值数: 1076
# 月份 2007-10 的无风险收益率: 0.0031690000000000004
# 月份 2007-11 - 主板股票数: 1082, ami3唯一值数: 1082
# 月份 2007-11 的无风险收益率: 0.0031690000000000004
# 月份 2007-12 - 主板股票数: 1077, ami3唯一值数: 1077
# 月份 2007-12 的无风险收益率: 0.0031690000000000004
# 月份 2008-01 - 主板股票数: 1074, ami3唯一值数: 1074
# 月份 2008-01 的无风险收益率: 0.003386
# 月份 2008-02 - 主板股票数: 1069, ami3唯一值数: 1069
# 月份 2008-02 的无风险收益率: 0.003386
# 月份 2008-03 - 主板股票数: 1074, ami3唯一值数: 1074
# 月份 2008-03 的无风险收益率: 0.003386
# 月份 2008-04 - 主板股票数: 1157, ami3唯一值数: 1157
# 月份 2008-04 的无风险收益率: 0.003386
# 月份 2008-05 - 主板股票数: 1143, ami3唯一值数: 1062
# 月份 2008-05 的无风险收益率: 0.003386
# 月份 2008-06 - 主板股票数: 1154, ami3唯一值数: 1073
# 月份 2008-06 的无风险收益率: 0.003386
# 月份 2008-07 - 主板股票数: 1159, ami3唯一值数: 1159
# 月份 2008-07 的无风险收益率: 0.003386
# 月份 2008-08 - 主板股票数: 1163, ami3唯一值数: 1163
# 月份 2008-08 的无风险收益率: 0.003386
# 月份 2008-09 - 主板股票数: 1172, ami3唯一值数: 1172
# 月份 2008-09 的无风险收益率: 0.003386
# 月份 2008-10 - 主板股票数: 1190, ami3唯一值数: 1189
# 月份 2008-10 的无风险收益率: 0.003386
# 月份 2008-11 - 主板股票数: 1204, ami3唯一值数: 1203
# 月份 2008-11 的无风险收益率: 0.002952
# 月份 2008-12 - 主板股票数: 1215, ami3唯一值数: 1215
# 月份 2008-12 的无风险收益率: 0.002076
# 月份 2009-01 - 主板股票数: 1210, ami3唯一值数: 1210
# 月份 2009-01 的无风险收益率: 0.001856
# 月份 2009-02 - 主板股票数: 1214, ami3唯一值数: 1214
# 月份 2009-02 的无风险收益率: 0.001856
# 月份 2009-03 - 主板股票数: 1215, ami3唯一值数: 1215
# 月份 2009-03 的无风险收益率: 0.001856
# 月份 2009-04 - 主板股票数: 1341, ami3唯一值数: 1341
# 月份 2009-04 的无风险收益率: 0.001856
# 月份 2009-05 - 主板股票数: 1344, ami3唯一值数: 1223
# 月份 2009-05 的无风险收益率: 0.001856
# 月份 2009-06 - 主板股票数: 1346, ami3唯一值数: 1225
# 月份 2009-06 的无风险收益率: 0.001856
# 月份 2009-07 - 主板股票数: 1350, ami3唯一值数: 1350
# 月份 2009-07 的无风险收益率: 0.001856
# 月份 2009-08 - 主板股票数: 1350, ami3唯一值数: 1349
# 月份 2009-08 的无风险收益率: 0.001856
# 月份 2009-09 - 主板股票数: 1356, ami3唯一值数: 1355
# 月份 2009-09 的无风险收益率: 0.001856
# 月份 2009-10 - 主板股票数: 1355, ami3唯一值数: 1355
# 月份 2009-10 的无风险收益率: 0.001856
# 月份 2009-11 - 主板股票数: 1360, ami3唯一值数: 1360
# 月份 2009-11 的无风险收益率: 0.001856
# 月份 2009-12 - 主板股票数: 1357, ami3唯一值数: 1356
# 月份 2009-12 的无风险收益率: 0.001856
# 月份 2010-01 - 主板股票数: 1354, ami3唯一值数: 1353
# 月份 2010-01 的无风险收益率: 0.001856
# 月份 2010-02 - 主板股票数: 1357, ami3唯一值数: 1357
# 月份 2010-02 的无风险收益率: 0.001856
# 月份 2010-03 - 主板股票数: 1357, ami3唯一值数: 1357
# 月份 2010-03 的无风险收益率: 0.001856
# 月份 2010-04 - 主板股票数: 1409, ami3唯一值数: 1409
# 月份 2010-04 的无风险收益率: 0.001856
# 月份 2010-05 - 主板股票数: 1400, ami3唯一值数: 1346
# 月份 2010-05 的无风险收益率: 0.001856
# 月份 2010-06 - 主板股票数: 1396, ami3唯一值数: 1342
# 月份 2010-06 的无风险收益率: 0.001856
# 月份 2010-07 - 主板股票数: 1398, ami3唯一值数: 1398
# 月份 2010-07 的无风险收益率: 0.001856
# 月份 2010-08 - 主板股票数: 1392, ami3唯一值数: 1392
# 月份 2010-08 的无风险收益率: 0.001856
# 月份 2010-09 - 主板股票数: 1392, ami3唯一值数: 1392
# 月份 2010-09 的无风险收益率: 0.001856
# 月份 2010-10 - 主板股票数: 1391, ami3唯一值数: 1391
# 月份 2010-10 的无风险收益率: 0.001856
# 月份 2010-11 - 主板股票数: 1391, ami3唯一值数: 1391
# 月份 2010-11 的无风险收益率: 0.0020599999999999998
# 月份 2010-12 - 主板股票数: 1386, ami3唯一值数: 1386
# 月份 2010-12 的无风险收益率: 0.0020599999999999998
# 月份 2011-01 - 主板股票数: 1381, ami3唯一值数: 1381
# 月份 2011-01 的无风险收益率: 0.0022630000000000003
# 月份 2011-02 - 主板股票数: 1387, ami3唯一值数: 1387
# 月份 2011-02 的无风险收益率: 0.0022630000000000003
# 月份 2011-03 - 主板股票数: 1380, ami3唯一值数: 1380
# 月份 2011-03 的无风险收益率: 0.0024660000000000003
# 月份 2011-04 - 主板股票数: 1467, ami3唯一值数: 1467
# 月份 2011-04 的无风险收益率: 0.0024660000000000003
# 月份 2011-05 - 主板股票数: 1464, ami3唯一值数: 1372
# 月份 2011-05 的无风险收益率: 0.0026690000000000004
# 月份 2011-06 - 主板股票数: 1465, ami3唯一值数: 1373
# 月份 2011-06 的无风险收益率: 0.0026690000000000004
# 月份 2011-07 - 主板股票数: 1464, ami3唯一值数: 1464
# 月份 2011-07 的无风险收益率: 0.0026690000000000004
# 月份 2011-08 - 主板股票数: 1464, ami3唯一值数: 1464
# 月份 2011-08 的无风险收益率: 0.0028710000000000003
# 月份 2011-09 - 主板股票数: 1467, ami3唯一值数: 1467
# 月份 2011-09 的无风险收益率: 0.0028710000000000003
# 月份 2011-10 - 主板股票数: 1467, ami3唯一值数: 1467
# 月份 2011-10 的无风险收益率: 0.0028710000000000003
# 月份 2011-11 - 主板股票数: 1461, ami3唯一值数: 1461
# 月份 2011-11 的无风险收益率: 0.0028710000000000003
# 月份 2011-12 - 主板股票数: 1464, ami3唯一值数: 1464
# 月份 2011-12 的无风险收益率: 0.0028710000000000003
# 月份 2012-01 - 主板股票数: 1469, ami3唯一值数: 1469
# 月份 2012-01 的无风险收益率: 0.0028710000000000003
# 月份 2012-02 - 主板股票数: 1467, ami3唯一值数: 1467
# 月份 2012-02 的无风险收益率: 0.0028710000000000003
# 月份 2012-03 - 主板股票数: 1466, ami3唯一值数: 1466
# 月份 2012-03 的无风险收益率: 0.0028710000000000003
# 月份 2012-04 - 主板股票数: 1675, ami3唯一值数: 1675
# 月份 2012-04 的无风险收益率: 0.0028710000000000003
# 月份 2012-05 - 主板股票数: 1677, ami3唯一值数: 1469
# 月份 2012-05 的无风险收益率: 0.0028710000000000003
# 月份 2012-06 - 主板股票数: 1679, ami3唯一值数: 1471
# 月份 2012-06 的无风险收益率: 0.0028710000000000003
# 月份 2012-07 - 主板股票数: 1686, ami3唯一值数: 1685
# 月份 2012-07 的无风险收益率: 0.0026690000000000004
# 月份 2012-08 - 主板股票数: 1684, ami3唯一值数: 1684
# 月份 2012-08 的无风险收益率: 0.0024660000000000003
# 月份 2012-09 - 主板股票数: 1686, ami3唯一值数: 1686
# 月份 2012-09 的无风险收益率: 0.0024660000000000003
# 月份 2012-10 - 主板股票数: 1689, ami3唯一值数: 1689
# 月份 2012-10 的无风险收益率: 0.0024660000000000003
# 月份 2012-11 - 主板股票数: 1696, ami3唯一值数: 1695
# 月份 2012-11 的无风险收益率: 0.0024660000000000003
# 月份 2012-12 - 主板股票数: 1694, ami3唯一值数: 1692
# 月份 2012-12 的无风险收益率: 0.0024660000000000003
# 月份 2013-01 - 主板股票数: 1688, ami3唯一值数: 1687
# 月份 2013-01 的无风险收益率: 0.0024660000000000003
# 月份 2013-02 - 主板股票数: 1683, ami3唯一值数: 1683
# 月份 2013-02 的无风险收益率: 0.0024660000000000003
# 月份 2013-03 - 主板股票数: 1678, ami3唯一值数: 1677
# 月份 2013-03 的无风险收益率: 0.0024660000000000003
# 月份 2013-04 - 主板股票数: 1799, ami3唯一值数: 1799
# 月份 2013-04 的无风险收益率: 0.0024660000000000003
# 月份 2013-05 - 主板股票数: 1795, ami3唯一值数: 1670
# 月份 2013-05 的无风险收益率: 0.0024660000000000003
# 月份 2013-06 - 主板股票数: 1780, ami3唯一值数: 1656
# 月份 2013-06 的无风险收益率: 0.0024660000000000003
# 月份 2013-07 - 主板股票数: 1783, ami3唯一值数: 1783
# 月份 2013-07 的无风险收益率: 0.0024660000000000003
# 月份 2013-08 - 主板股票数: 1779, ami3唯一值数: 1779
# 月份 2013-08 的无风险收益率: 0.0024660000000000003
# 月份 2013-09 - 主板股票数: 1770, ami3唯一值数: 1770
# 月份 2013-09 的无风险收益率: 0.0024660000000000003
# 月份 2013-10 - 主板股票数: 1768, ami3唯一值数: 1768
# 月份 2013-10 的无风险收益率: 0.0024660000000000003
# 月份 2013-11 - 主板股票数: 1761, ami3唯一值数: 1760
# 月份 2013-11 的无风险收益率: 0.0024660000000000003
# 月份 2013-12 - 主板股票数: 1767, ami3唯一值数: 1765
# 月份 2013-12 的无风险收益率: 0.0024660000000000003
# 月份 2014-01 - 主板股票数: 1768, ami3唯一值数: 1766
# 月份 2014-01 的无风险收益率: 0.0024660000000000003
# 月份 2014-02 - 主板股票数: 1765, ami3唯一值数: 1765
# 月份 2014-02 的无风险收益率: 0.0024660000000000003
# 月份 2014-03 - 主板股票数: 1758, ami3唯一值数: 1758
# 月份 2014-03 的无风险收益率: 0.0024660000000000003
# 月份 2014-04 - 主板股票数: 1800, ami3唯一值数: 1800
# 月份 2014-04 的无风险收益率: 0.0024660000000000003
# 月份 2014-05 - 主板股票数: 1769, ami3唯一值数: 1706
# 月份 2014-05 的无风险收益率: 0.0024660000000000003
# 月份 2014-06 - 主板股票数: 1757, ami3唯一值数: 1695
# 月份 2014-06 的无风险收益率: 0.0024660000000000003
# 月份 2014-07 - 主板股票数: 1736, ami3唯一值数: 1735
# 月份 2014-07 的无风险收益率: 0.0024660000000000003
# 月份 2014-08 - 主板股票数: 1727, ami3唯一值数: 1727
# 月份 2014-08 的无风险收益率: 0.0024660000000000003
# 月份 2014-09 - 主板股票数: 1712, ami3唯一值数: 1712
# 月份 2014-09 的无风险收益率: 0.0024660000000000003
# 月份 2014-10 - 主板股票数: 1688, ami3唯一值数: 1688
# 月份 2014-10 的无风险收益率: 0.0024660000000000003
# 月份 2014-11 - 主板股票数: 1686, ami3唯一值数: 1685
# 月份 2014-11 的无风险收益率: 0.0024660000000000003
# 月份 2014-12 - 主板股票数: 1687, ami3唯一值数: 1686
# 月份 2014-12 的无风险收益率: 0.0022630000000000003
# 月份 2015-01 - 主板股票数: 1679, ami3唯一值数: 1678
# 月份 2015-01 的无风险收益率: 0.0022630000000000003
# 月份 2015-02 - 主板股票数: 1671, ami3唯一值数: 1670
# 月份 2015-02 的无风险收益率: 0.0022630000000000003
# 月份 2015-03 - 主板股票数: 1664, ami3唯一值数: 1664
# 月份 2015-03 的无风险收益率: 0.0020599999999999998
# 月份 2015-04 - 主板股票数: 1669, ami3唯一值数: 1669
# 月份 2015-04 的无风险收益率: 0.0020599999999999998
# 月份 2015-05 - 主板股票数: 1649, ami3唯一值数: 1631
# 月份 2015-05 的无风险收益率: 0.0020599999999999998
# 月份 2015-06 - 主板股票数: 1604, ami3唯一值数: 1585
# 月份 2015-06 的无风险收益率: 0.001856
# 月份 2015-07 - 主板股票数: 1544, ami3唯一值数: 1543
# 月份 2015-07 的无风险收益率: 0.0016520000000000003
# 月份 2015-08 - 主板股票数: 1502, ami3唯一值数: 1502
# 月份 2015-08 的无风险收益率: 0.0016520000000000003
# 月份 2015-09 - 主板股票数: 1482, ami3唯一值数: 1482
# 月份 2015-09 的无风险收益率: 0.001447
# 月份 2015-10 - 主板股票数: 1489, ami3唯一值数: 1488
# 月份 2015-10 的无风险收益率: 0.001447
# 月份 2015-11 - 主板股票数: 1507, ami3唯一值数: 1506
# 月份 2015-11 的无风险收益率: 0.0012410000000000001
# 月份 2015-12 - 主板股票数: 1518, ami3唯一值数: 1518
# 月份 2015-12 的无风险收益率: 0.0012410000000000001
# 月份 2016-01 - 主板股票数: 1536, ami3唯一值数: 1534
# 月份 2016-01 的无风险收益率: 0.0012410000000000001
# 月份 2016-02 - 主板股票数: 1577, ami3唯一值数: 1575
# 月份 2016-02 的无风险收益率: 0.0012410000000000001
# 月份 2016-03 - 主板股票数: 1612, ami3唯一值数: 1612
# 月份 2016-03 的无风险收益率: 0.0012410000000000001
# 月份 2016-04 - 主板股票数: 1712, ami3唯一值数: 1711
# 月份 2016-04 的无风险收益率: 0.0012410000000000001
# 月份 2016-05 - 主板股票数: 1734, ami3唯一值数: 1665
# 月份 2016-05 的无风险收益率: 0.0012410000000000001
# 月份 2016-06 - 主板股票数: 1747, ami3唯一值数: 1678
# 月份 2016-06 的无风险收益率: 0.0012410000000000001
# 月份 2016-07 - 主板股票数: 1754, ami3唯一值数: 1753
# 月份 2016-07 的无风险收益率: 0.0012410000000000001
# 月份 2016-08 - 主板股票数: 1774, ami3唯一值数: 1774
# 月份 2016-08 的无风险收益率: 0.0012410000000000001
# 月份 2016-09 - 主板股票数: 1777, ami3唯一值数: 1777
# 月份 2016-09 的无风险收益率: 0.0012410000000000001
# 月份 2016-10 - 主板股票数: 1775, ami3唯一值数: 1772
# 月份 2016-10 的无风险收益率: 0.0012410000000000001
# 月份 2016-11 - 主板股票数: 1796, ami3唯一值数: 1791
# 月份 2016-11 的无风险收益率: 0.0012410000000000001
# 月份 2016-12 - 主板股票数: 1817, ami3唯一值数: 1814
# 月份 2016-12 的无风险收益率: 0.0012410000000000001
# 月份 2017-01 - 主板股票数: 1820, ami3唯一值数: 1818
# 月份 2017-01 的无风险收益率: 0.0012410000000000001
# 月份 2017-02 - 主板股票数: 1826, ami3唯一值数: 1824
# 月份 2017-02 的无风险收益率: 0.0012410000000000001
# 月份 2017-03 - 主板股票数: 1827, ami3唯一值数: 1826
# 月份 2017-03 的无风险收益率: 0.0012410000000000001
# 月份 2017-04 - 主板股票数: 1944, ami3唯一值数: 1944
# 月份 2017-04 的无风险收益率: 0.0012410000000000001
# 月份 2017-05 - 主板股票数: 1932, ami3唯一值数: 1827
# 月份 2017-05 的无风险收益率: 0.0012410000000000001
# 月份 2017-06 - 主板股票数: 1924, ami3唯一值数: 1821
# 月份 2017-06 的无风险收益率: 0.0012410000000000001
# 月份 2017-07 - 主板股票数: 1919, ami3唯一值数: 1918
# 月份 2017-07 的无风险收益率: 0.0012410000000000001
# 月份 2017-08 - 主板股票数: 1919, ami3唯一值数: 1918
# 月份 2017-08 的无风险收益率: 0.0012410000000000001
# 月份 2017-09 - 主板股票数: 1935, ami3唯一值数: 1932
# 月份 2017-09 的无风险收益率: 0.0012410000000000001
# 月份 2017-10 - 主板股票数: 1942, ami3唯一值数: 1940
# 月份 2017-10 的无风险收益率: 0.0012410000000000001
# 月份 2017-11 - 主板股票数: 1940, ami3唯一值数: 1938
# 月份 2017-11 的无风险收益率: 0.0012410000000000001
# 月份 2017-12 - 主板股票数: 1949, ami3唯一值数: 1946
# 月份 2017-12 的无风险收益率: 0.0012410000000000001
# 月份 2018-01 - 主板股票数: 1948, ami3唯一值数: 1945
# 月份 2018-01 的无风险收益率: 0.0012410000000000001
# 月份 2018-02 - 主板股票数: 1955, ami3唯一值数: 1954
# 月份 2018-02 的无风险收益率: 0.0012410000000000001
# 月份 2018-03 - 主板股票数: 1941, ami3唯一值数: 1940
# 月份 2018-03 的无风险收益率: 0.0012410000000000001
# 月份 2018-04 - 主板股票数: 2054, ami3唯一值数: 2052
# 月份 2018-04 的无风险收益率: 0.0012410000000000001
# 月份 2018-05 - 主板股票数: 2045, ami3唯一值数: 1926
# 月份 2018-05 的无风险收益率: 0.0012410000000000001
# 月份 2018-06 - 主板股票数: 2047, ami3唯一值数: 1928
# 月份 2018-06 的无风险收益率: 0.0012410000000000001
# 月份 2018-07 - 主板股票数: 2037, ami3唯一值数: 2036
# 月份 2018-07 的无风险收益率: 0.0012410000000000001
# 月份 2018-08 - 主板股票数: 2065, ami3唯一值数: 2064
# 月份 2018-08 的无风险收益率: 0.0012410000000000001
# 月份 2018-09 - 主板股票数: 2085, ami3唯一值数: 2083
# 月份 2018-09 的无风险收益率: 0.0012410000000000001
# 月份 2018-10 - 主板股票数: 2133, ami3唯一值数: 2131
# 月份 2018-10 的无风险收益率: 0.0012410000000000001
# 月份 2018-11 - 主板股票数: 2165, ami3唯一值数: 2160
# 月份 2018-11 的无风险收益率: 0.0012410000000000001
# 月份 2018-12 - 主板股票数: 2198, ami3唯一值数: 2192
# 月份 2018-12 的无风险收益率: 0.0012410000000000001
# 月份 2019-01 - 主板股票数: 2230, ami3唯一值数: 2228
# 月份 2019-01 的无风险收益率: 0.0012410000000000001
# 月份 2019-02 - 主板股票数: 2249, ami3唯一值数: 2247
# 月份 2019-02 的无风险收益率: 0.0012410000000000001
# 月份 2019-03 - 主板股票数: 2266, ami3唯一值数: 2266
# 月份 2019-03 的无风险收益率: 0.0012410000000000001
# 月份 2019-04 - 主板股票数: 2436, ami3唯一值数: 2436
# 月份 2019-04 的无风险收益率: 0.0012410000000000001
# 月份 2019-05 - 主板股票数: 2442, ami3唯一值数: 2287
# 月份 2019-05 的无风险收益率: 0.0012410000000000001
# 月份 2019-06 - 主板股票数: 2442, ami3唯一值数: 2286
# 月份 2019-06 的无风险收益率: 0.0012410000000000001
# 月份 2019-07 - 主板股票数: 2442, ami3唯一值数: 2441
# 月份 2019-07 的无风险收益率: 0.0012410000000000001
# 月份 2019-08 - 主板股票数: 2442, ami3唯一值数: 2442
# 月份 2019-08 的无风险收益率: 0.0012410000000000001
# 月份 2019-09 - 主板股票数: 2442, ami3唯一值数: 2442
# 月份 2019-09 的无风险收益率: 0.0012410000000000001
# 月份 2019-10 - 主板股票数: 2442, ami3唯一值数: 2442
# 月份 2019-10 的无风险收益率: 0.0012410000000000001
# 月份 2019-11 - 主板股票数: 2443, ami3唯一值数: 2443
# 月份 2019-11 的无风险收益率: 0.0012410000000000001
# 月份 2019-12 - 主板股票数: 2443, ami3唯一值数: 2443
# 月份 2019-12 的无风险收益率: 0.0012410000000000001
# 月份 2020-01 - 主板股票数: 2443, ami3唯一值数: 2443
# 月份 2020-01 的无风险收益率: 0.0012410000000000001
# 月份 2020-02 - 主板股票数: 2443, ami3唯一值数: 2443
# 月份 2020-02 的无风险收益率: 0.0012410000000000001
# 月份 2020-03 - 主板股票数: 2443, ami3唯一值数: 2443
# 月份 2020-03 的无风险收益率: 0.0012410000000000001
# 月份 2020-04 - 主板股票数: 2553, ami3唯一值数: 2553
# 月份 2020-04 的无风险收益率: 0.0012410000000000001
# 月份 2020-05 - 主板股票数: 2552, ami3唯一值数: 2440
# 月份 2020-05 的无风险收益率: 0.0012410000000000001
# 月份 2020-06 - 主板股票数: 2552, ami3唯一值数: 2439
# 月份 2020-06 的无风险收益率: 0.0012410000000000001
# 月份 2020-07 - 主板股票数: 2552, ami3唯一值数: 2551
# 月份 2020-07 的无风险收益率: 0.0012410000000000001
# 月份 2020-08 - 主板股票数: 2551, ami3唯一值数: 2551
# 月份 2020-08 的无风险收益率: 0.0012410000000000001
# 月份 2020-09 - 主板股票数: 2551, ami3唯一值数: 2551
# 月份 2020-09 的无风险收益率: 0.0012410000000000001
# 月份 2020-10 - 主板股票数: 2551, ami3唯一值数: 2551
# 月份 2020-10 的无风险收益率: 0.0012410000000000001
# 月份 2020-11 - 主板股票数: 2553, ami3唯一值数: 2553
# 月份 2020-11 的无风险收益率: 0.0012410000000000001
# 月份 2020-12 - 主板股票数: 2554, ami3唯一值数: 2554
# 月份 2020-12 的无风险收益率: 0.0012410000000000001
# 月份 2021-01 - 主板股票数: 2555, ami3唯一值数: 2555
# 月份 2021-01 的无风险收益率: 0.0012410000000000001
# 月份 2021-02 - 主板股票数: 2556, ami3唯一值数: 2556
# 月份 2021-02 的无风险收益率: 0.0012410000000000001
# 月份 2021-03 - 主板股票数: 2556, ami3唯一值数: 2556
# 月份 2021-03 的无风险收益率: 0.0012410000000000001
# 月份 2021-04 - 主板股票数: 2632, ami3唯一值数: 2632
# 月份 2021-04 的无风险收益率: 0.0012410000000000001
# 月份 2021-05 - 主板股票数: 2633, ami3唯一值数: 2558
# 月份 2021-05 的无风险收益率: 0.0012410000000000001
# 月份 2021-06 - 主板股票数: 2633, ami3唯一值数: 2558
# 月份 2021-06 的无风险收益率: 0.0012410000000000001
# 月份 2021-07 - 主板股票数: 2633, ami3唯一值数: 2633
# 月份 2021-07 的无风险收益率: 0.0012410000000000001
# 月份 2021-08 - 主板股票数: 2633, ami3唯一值数: 2633
# 月份 2021-08 的无风险收益率: 0.0012410000000000001
# 月份 2021-09 - 主板股票数: 2633, ami3唯一值数: 2633
# 月份 2021-09 的无风险收益率: 0.0012410000000000001
# 月份 2021-10 - 主板股票数: 2633, ami3唯一值数: 2633
# 月份 2021-10 的无风险收益率: 0.0012410000000000001
# 月份 2021-11 - 主板股票数: 2633, ami3唯一值数: 2633
# 月份 2021-11 的无风险收益率: 0.0012410000000000001
# 月份 2021-12 - 主板股票数: 2633, ami3唯一值数: 2633
# 月份 2021-12 的无风险收益率: 0.0012410000000000001
# 月份 2022-01 - 主板股票数: 2634, ami3唯一值数: 2634
# 月份 2022-01 的无风险收益率: 0.0012410000000000001
# 月份 2022-02 - 主板股票数: 2634, ami3唯一值数: 2634
# 月份 2022-02 的无风险收益率: 0.0012410000000000001
# 月份 2022-03 - 主板股票数: 2634, ami3唯一值数: 2634
# 月份 2022-03 的无风险收益率: 0.0012410000000000001
# 月份 2022-04 - 主板股票数: 2802, ami3唯一值数: 2802
# 月份 2022-04 的无风险收益率: 0.0012410000000000001
# 月份 2022-05 - 主板股票数: 2802, ami3唯一值数: 2634
# 月份 2022-05 的无风险收益率: 0.0012410000000000001
# 月份 2022-06 - 主板股票数: 2801, ami3唯一值数: 2633
# 月份 2022-06 的无风险收益率: 0.0012410000000000001
# 月份 2022-07 - 主板股票数: 2801, ami3唯一值数: 2801
# 月份 2022-07 的无风险收益率: 0.0012410000000000001
# 月份 2022-08 - 主板股票数: 2801, ami3唯一值数: 2801
# 月份 2022-08 的无风险收益率: 0.0012410000000000001
# 月份 2022-09 - 主板股票数: 2801, ami3唯一值数: 2801
# 月份 2022-09 的无风险收益率: 0.0012410000000000001
# 月份 2022-10 - 主板股票数: 2801, ami3唯一值数: 2801
# 月份 2022-10 的无风险收益率: 0.0013650000000000001
# 月份 2022-11 - 主板股票数: 2801, ami3唯一值数: 2801
# 月份 2022-11 的无风险收益率: 0.0013650000000000001
# 月份 2022-12 - 主板股票数: 2802, ami3唯一值数: 2802
# 月份 2022-12 的无风险收益率: 0.0013650000000000001
# 月份 2023-01 - 主板股票数: 2803, ami3唯一值数: 2803
# 月份 2023-01 的无风险收益率: 0.0013650000000000001
# 月份 2023-02 - 主板股票数: 2803, ami3唯一值数: 2803
# 月份 2023-02 的无风险收益率: 0.0013650000000000001
# 月份 2023-03 - 主板股票数: 2803, ami3唯一值数: 2803
# 月份 2023-03 的无风险收益率: 0.0013650000000000001
# 月份 2023-04 - 主板股票数: 2987, ami3唯一值数: 2987
# 月份 2023-04 的无风险收益率: 0.0013650000000000001
# 月份 2023-05 - 主板股票数: 2984, ami3唯一值数: 2800
# 月份 2023-05 的无风险收益率: 0.0013650000000000001
# 月份 2023-06 - 主板股票数: 2984, ami3唯一值数: 2800
# 月份 2023-06 的无风险收益率: 0.0013650000000000001
# 月份 2023-07 - 主板股票数: 2984, ami3唯一值数: 2984
# 月份 2023-07 的无风险收益率: 0.0013650000000000001
# 月份 2023-08 - 主板股票数: 2984, ami3唯一值数: 2984
# 月份 2023-08 的无风险收益率: 0.0013650000000000001
# 月份 2023-09 - 主板股票数: 2984, ami3唯一值数: 2984
# 月份 2023-09 的无风险收益率: 0.001283
# 月份 2023-10 - 主板股票数: 2984, ami3唯一值数: 2984
# 月份 2023-10 的无风险收益率: 0.001283
# 月份 2023-11 - 主板股票数: 2986, ami3唯一值数: 2986
# 月份 2023-11 的无风险收益率: 0.001283
# 月份 2023-12 - 主板股票数: 2987, ami3唯一值数: 2987
# 月份 2023-12 的无风险收益率: 0.001283
# 月份 2024-01 - 主板股票数: 2987, ami3唯一值数: 2987
# 月份 2024-01 的无风险收益率: 0.001283
# 月份 2024-02 - 主板股票数: 2985, ami3唯一值数: 2985
# 月份 2024-02 的无风险收益率: 0.001283
# ami3 投资组合完成，生成记录数: 223
# ami3 投资组合已导出至 output\ami3.xlsx
# ami6 计算完成，非缺失值数: 496486
#
# 开始构造 ami6 投资组合
# 月份 2005-06 - 主板股票数: 1075, ami6唯一值数: 1072
# 月份 2005-06 的无风险收益率: 0.001856
# 月份 2005-07 - 主板股票数: 1074, ami6唯一值数: 0
# 跳过月份 2005-07，因为ami6的主板股票唯一值数目少于5
# 月份 2005-08 - 主板股票数: 1073, ami6唯一值数: 0
# 跳过月份 2005-08，因为ami6的主板股票唯一值数目少于5
# 月份 2005-09 - 主板股票数: 1072, ami6唯一值数: 0
# 跳过月份 2005-09，因为ami6的主板股票唯一值数目少于5
# 月份 2005-10 - 主板股票数: 1070, ami6唯一值数: 1
# 跳过月份 2005-10，因为ami6的主板股票唯一值数目少于5
# 月份 2005-11 - 主板股票数: 1069, ami6唯一值数: 2
# 跳过月份 2005-11，因为ami6的主板股票唯一值数目少于5
# 月份 2005-12 - 主板股票数: 1063, ami6唯一值数: 1060
# 月份 2005-12 的无风险收益率: 0.001856
# 月份 2006-01 - 主板股票数: 1045, ami6唯一值数: 1039
# 月份 2006-01 的无风险收益率: 0.001856
# 月份 2006-02 - 主板股票数: 1028, ami6唯一值数: 1021
# 月份 2006-02 的无风险收益率: 0.001856
# 月份 2006-03 - 主板股票数: 1014, ami6唯一值数: 1006
# 月份 2006-03 的无风险收益率: 0.001856
# 月份 2006-04 - 主板股票数: 1073, ami6唯一值数: 1063
# 月份 2006-04 的无风险收益率: 0.001856
# 月份 2006-05 - 主板股票数: 1040, ami6唯一值数: 939
# 月份 2006-05 的无风险收益率: 0.001856
# 月份 2006-06 - 主板股票数: 1042, ami6唯一值数: 947
# 月份 2006-06 的无风险收益率: 0.001856
# 月份 2006-07 - 主板股票数: 1046, ami6唯一值数: 950
# 月份 2006-07 的无风险收益率: 0.001856
# 月份 2006-08 - 主板股票数: 1044, ami6唯一值数: 950
# 月份 2006-08 的无风险收益率: 0.001856
# 月份 2006-09 - 主板股票数: 1051, ami6唯一值数: 959
# 月份 2006-09 的无风险收益率: 0.002076
# 月份 2006-10 - 主板股票数: 1064, ami6唯一值数: 1057
# 月份 2006-10 的无风险收益率: 0.002076
# 月份 2006-11 - 主板股票数: 1079, ami6唯一值数: 1072
# 月份 2006-11 的无风险收益率: 0.002076
# 月份 2006-12 - 主板股票数: 1080, ami6唯一值数: 1073
# 月份 2006-12 的无风险收益率: 0.002076
# 月份 2007-01 - 主板股票数: 1066, ami6唯一值数: 1059
# 月份 2007-01 的无风险收益率: 0.002076
# 月份 2007-02 - 主板股票数: 1069, ami6唯一值数: 1062
# 月份 2007-02 的无风险收益率: 0.002076
# 月份 2007-03 - 主板股票数: 1076, ami6唯一值数: 1070
# 月份 2007-03 的无风险收益率: 0.002076
# 月份 2007-04 - 主板股票数: 1096, ami6唯一值数: 1094
# 月份 2007-04 的无风险收益率: 0.002296
# 月份 2007-05 - 主板股票数: 1074, ami6唯一值数: 1063
# 月份 2007-05 的无风险收益率: 0.002296
# 月份 2007-06 - 主板股票数: 1076, ami6唯一值数: 1065
# 月份 2007-06 的无风险收益率: 0.002515
# 月份 2007-07 - 主板股票数: 1087, ami6唯一值数: 1075
# 月份 2007-07 的无风险收益率: 0.002515
# 月份 2007-08 - 主板股票数: 1092, ami6唯一值数: 1081
# 月份 2007-08 的无风险收益率: 0.002734
# 月份 2007-09 - 主板股票数: 1084, ami6唯一值数: 1075
# 月份 2007-09 的无风险收益率: 0.002952
# 月份 2007-10 - 主板股票数: 1076, ami6唯一值数: 1076
# 月份 2007-10 的无风险收益率: 0.0031690000000000004
# 月份 2007-11 - 主板股票数: 1082, ami6唯一值数: 1082
# 月份 2007-11 的无风险收益率: 0.0031690000000000004
# 月份 2007-12 - 主板股票数: 1077, ami6唯一值数: 1077
# 月份 2007-12 的无风险收益率: 0.0031690000000000004
# 月份 2008-01 - 主板股票数: 1074, ami6唯一值数: 1074
# 月份 2008-01 的无风险收益率: 0.003386
# 月份 2008-02 - 主板股票数: 1069, ami6唯一值数: 1069
# 月份 2008-02 的无风险收益率: 0.003386
# 月份 2008-03 - 主板股票数: 1074, ami6唯一值数: 1073
# 月份 2008-03 的无风险收益率: 0.003386
# 月份 2008-04 - 主板股票数: 1157, ami6唯一值数: 1156
# 月份 2008-04 的无风险收益率: 0.003386
# 月份 2008-05 - 主板股票数: 1143, ami6唯一值数: 1062
# 月份 2008-05 的无风险收益率: 0.003386
# 月份 2008-06 - 主板股票数: 1154, ami6唯一值数: 1073
# 月份 2008-06 的无风险收益率: 0.003386
# 月份 2008-07 - 主板股票数: 1159, ami6唯一值数: 1078
# 月份 2008-07 的无风险收益率: 0.003386
# 月份 2008-08 - 主板股票数: 1163, ami6唯一值数: 1082
# 月份 2008-08 的无风险收益率: 0.003386
# 月份 2008-09 - 主板股票数: 1172, ami6唯一值数: 1090
# 月份 2008-09 的无风险收益率: 0.003386
# 月份 2008-10 - 主板股票数: 1190, ami6唯一值数: 1188
# 月份 2008-10 的无风险收益率: 0.003386
# 月份 2008-11 - 主板股票数: 1204, ami6唯一值数: 1203
# 月份 2008-11 的无风险收益率: 0.002952
# 月份 2008-12 - 主板股票数: 1215, ami6唯一值数: 1214
# 月份 2008-12 的无风险收益率: 0.002076
# 月份 2009-01 - 主板股票数: 1210, ami6唯一值数: 1209
# 月份 2009-01 的无风险收益率: 0.001856
# 月份 2009-02 - 主板股票数: 1214, ami6唯一值数: 1213
# 月份 2009-02 的无风险收益率: 0.001856
# 月份 2009-03 - 主板股票数: 1215, ami6唯一值数: 1215
# 月份 2009-03 的无风险收益率: 0.001856
# 月份 2009-04 - 主板股票数: 1341, ami6唯一值数: 1341
# 月份 2009-04 的无风险收益率: 0.001856
# 月份 2009-05 - 主板股票数: 1344, ami6唯一值数: 1223
# 月份 2009-05 的无风险收益率: 0.001856
# 月份 2009-06 - 主板股票数: 1346, ami6唯一值数: 1225
# 月份 2009-06 的无风险收益率: 0.001856
# 月份 2009-07 - 主板股票数: 1350, ami6唯一值数: 1229
# 月份 2009-07 的无风险收益率: 0.001856
# 月份 2009-08 - 主板股票数: 1350, ami6唯一值数: 1228
# 月份 2009-08 的无风险收益率: 0.001856
# 月份 2009-09 - 主板股票数: 1356, ami6唯一值数: 1234
# 月份 2009-09 的无风险收益率: 0.001856
# 月份 2009-10 - 主板股票数: 1355, ami6唯一值数: 1354
# 月份 2009-10 的无风险收益率: 0.001856
# 月份 2009-11 - 主板股票数: 1360, ami6唯一值数: 1359
# 月份 2009-11 的无风险收益率: 0.001856
# 月份 2009-12 - 主板股票数: 1357, ami6唯一值数: 1355
# 月份 2009-12 的无风险收益率: 0.001856
# 月份 2010-01 - 主板股票数: 1354, ami6唯一值数: 1353
# 月份 2010-01 的无风险收益率: 0.001856
# 月份 2010-02 - 主板股票数: 1357, ami6唯一值数: 1355
# 月份 2010-02 的无风险收益率: 0.001856
# 月份 2010-03 - 主板股票数: 1357, ami6唯一值数: 1356
# 月份 2010-03 的无风险收益率: 0.001856
# 月份 2010-04 - 主板股票数: 1409, ami6唯一值数: 1408
# 月份 2010-04 的无风险收益率: 0.001856
# 月份 2010-05 - 主板股票数: 1400, ami6唯一值数: 1346
# 月份 2010-05 的无风险收益率: 0.001856
# 月份 2010-06 - 主板股票数: 1396, ami6唯一值数: 1342
# 月份 2010-06 的无风险收益率: 0.001856
# 月份 2010-07 - 主板股票数: 1398, ami6唯一值数: 1344
# 月份 2010-07 的无风险收益率: 0.001856
# 月份 2010-08 - 主板股票数: 1392, ami6唯一值数: 1338
# 月份 2010-08 的无风险收益率: 0.001856
# 月份 2010-09 - 主板股票数: 1392, ami6唯一值数: 1338
# 月份 2010-09 的无风险收益率: 0.001856
# 月份 2010-10 - 主板股票数: 1391, ami6唯一值数: 1391
# 月份 2010-10 的无风险收益率: 0.001856
# 月份 2010-11 - 主板股票数: 1391, ami6唯一值数: 1391
# 月份 2010-11 的无风险收益率: 0.0020599999999999998
# 月份 2010-12 - 主板股票数: 1386, ami6唯一值数: 1386
# 月份 2010-12 的无风险收益率: 0.0020599999999999998
# 月份 2011-01 - 主板股票数: 1381, ami6唯一值数: 1381
# 月份 2011-01 的无风险收益率: 0.0022630000000000003
# 月份 2011-02 - 主板股票数: 1387, ami6唯一值数: 1387
# 月份 2011-02 的无风险收益率: 0.0022630000000000003
# 月份 2011-03 - 主板股票数: 1380, ami6唯一值数: 1380
# 月份 2011-03 的无风险收益率: 0.0024660000000000003
# 月份 2011-04 - 主板股票数: 1467, ami6唯一值数: 1467
# 月份 2011-04 的无风险收益率: 0.0024660000000000003
# 月份 2011-05 - 主板股票数: 1464, ami6唯一值数: 1372
# 月份 2011-05 的无风险收益率: 0.0026690000000000004
# 月份 2011-06 - 主板股票数: 1465, ami6唯一值数: 1373
# 月份 2011-06 的无风险收益率: 0.0026690000000000004
# 月份 2011-07 - 主板股票数: 1464, ami6唯一值数: 1373
# 月份 2011-07 的无风险收益率: 0.0026690000000000004
# 月份 2011-08 - 主板股票数: 1464, ami6唯一值数: 1373
# 月份 2011-08 的无风险收益率: 0.0028710000000000003
# 月份 2011-09 - 主板股票数: 1467, ami6唯一值数: 1376
# 月份 2011-09 的无风险收益率: 0.0028710000000000003
# 月份 2011-10 - 主板股票数: 1467, ami6唯一值数: 1467
# 月份 2011-10 的无风险收益率: 0.0028710000000000003
# 月份 2011-11 - 主板股票数: 1461, ami6唯一值数: 1461
# 月份 2011-11 的无风险收益率: 0.0028710000000000003
# 月份 2011-12 - 主板股票数: 1464, ami6唯一值数: 1463
# 月份 2011-12 的无风险收益率: 0.0028710000000000003
# 月份 2012-01 - 主板股票数: 1469, ami6唯一值数: 1469
# 月份 2012-01 的无风险收益率: 0.0028710000000000003
# 月份 2012-02 - 主板股票数: 1467, ami6唯一值数: 1467
# 月份 2012-02 的无风险收益率: 0.0028710000000000003
# 月份 2012-03 - 主板股票数: 1466, ami6唯一值数: 1465
# 月份 2012-03 的无风险收益率: 0.0028710000000000003
# 月份 2012-04 - 主板股票数: 1675, ami6唯一值数: 1674
# 月份 2012-04 的无风险收益率: 0.0028710000000000003
# 月份 2012-05 - 主板股票数: 1677, ami6唯一值数: 1468
# 月份 2012-05 的无风险收益率: 0.0028710000000000003
# 月份 2012-06 - 主板股票数: 1679, ami6唯一值数: 1471
# 月份 2012-06 的无风险收益率: 0.0028710000000000003
# 月份 2012-07 - 主板股票数: 1686, ami6唯一值数: 1478
# 月份 2012-07 的无风险收益率: 0.0026690000000000004
# 月份 2012-08 - 主板股票数: 1684, ami6唯一值数: 1476
# 月份 2012-08 的无风险收益率: 0.0024660000000000003
# 月份 2012-09 - 主板股票数: 1686, ami6唯一值数: 1478
# 月份 2012-09 的无风险收益率: 0.0024660000000000003
# 月份 2012-10 - 主板股票数: 1689, ami6唯一值数: 1688
# 月份 2012-10 的无风险收益率: 0.0024660000000000003
# 月份 2012-11 - 主板股票数: 1696, ami6唯一值数: 1695
# 月份 2012-11 的无风险收益率: 0.0024660000000000003
# 月份 2012-12 - 主板股票数: 1694, ami6唯一值数: 1692
# 月份 2012-12 的无风险收益率: 0.0024660000000000003
# 月份 2013-01 - 主板股票数: 1688, ami6唯一值数: 1686
# 月份 2013-01 的无风险收益率: 0.0024660000000000003
# 月份 2013-02 - 主板股票数: 1683, ami6唯一值数: 1681
# 月份 2013-02 的无风险收益率: 0.0024660000000000003
# 月份 2013-03 - 主板股票数: 1678, ami6唯一值数: 1675
# 月份 2013-03 的无风险收益率: 0.0024660000000000003
# 月份 2013-04 - 主板股票数: 1799, ami6唯一值数: 1797
# 月份 2013-04 的无风险收益率: 0.0024660000000000003
# 月份 2013-05 - 主板股票数: 1795, ami6唯一值数: 1669
# 月份 2013-05 的无风险收益率: 0.0024660000000000003
# 月份 2013-06 - 主板股票数: 1780, ami6唯一值数: 1655
# 月份 2013-06 的无风险收益率: 0.0024660000000000003
# 月份 2013-07 - 主板股票数: 1783, ami6唯一值数: 1659
# 月份 2013-07 的无风险收益率: 0.0024660000000000003
# 月份 2013-08 - 主板股票数: 1779, ami6唯一值数: 1657
# 月份 2013-08 的无风险收益率: 0.0024660000000000003
# 月份 2013-09 - 主板股票数: 1770, ami6唯一值数: 1649
# 月份 2013-09 的无风险收益率: 0.0024660000000000003
# 月份 2013-10 - 主板股票数: 1768, ami6唯一值数: 1768
# 月份 2013-10 的无风险收益率: 0.0024660000000000003
# 月份 2013-11 - 主板股票数: 1761, ami6唯一值数: 1760
# 月份 2013-11 的无风险收益率: 0.0024660000000000003
# 月份 2013-12 - 主板股票数: 1767, ami6唯一值数: 1765
# 月份 2013-12 的无风险收益率: 0.0024660000000000003
# 月份 2014-01 - 主板股票数: 1768, ami6唯一值数: 1765
# 月份 2014-01 的无风险收益率: 0.0024660000000000003
# 月份 2014-02 - 主板股票数: 1765, ami6唯一值数: 1762
# 月份 2014-02 的无风险收益率: 0.0024660000000000003
# 月份 2014-03 - 主板股票数: 1758, ami6唯一值数: 1754
# 月份 2014-03 的无风险收益率: 0.0024660000000000003
# 月份 2014-04 - 主板股票数: 1800, ami6唯一值数: 1796
# 月份 2014-04 的无风险收益率: 0.0024660000000000003
# 月份 2014-05 - 主板股票数: 1769, ami6唯一值数: 1706
# 月份 2014-05 的无风险收益率: 0.0024660000000000003
# 月份 2014-06 - 主板股票数: 1757, ami6唯一值数: 1694
# 月份 2014-06 的无风险收益率: 0.0024660000000000003
# 月份 2014-07 - 主板股票数: 1736, ami6唯一值数: 1675
# 月份 2014-07 的无风险收益率: 0.0024660000000000003
# 月份 2014-08 - 主板股票数: 1727, ami6唯一值数: 1666
# 月份 2014-08 的无风险收益率: 0.0024660000000000003
# 月份 2014-09 - 主板股票数: 1712, ami6唯一值数: 1653
# 月份 2014-09 的无风险收益率: 0.0024660000000000003
# 月份 2014-10 - 主板股票数: 1688, ami6唯一值数: 1686
# 月份 2014-10 的无风险收益率: 0.0024660000000000003
# 月份 2014-11 - 主板股票数: 1686, ami6唯一值数: 1685
# 月份 2014-11 的无风险收益率: 0.0024660000000000003
# 月份 2014-12 - 主板股票数: 1687, ami6唯一值数: 1686
# 月份 2014-12 的无风险收益率: 0.0022630000000000003
# 月份 2015-01 - 主板股票数: 1679, ami6唯一值数: 1677
# 月份 2015-01 的无风险收益率: 0.0022630000000000003
# 月份 2015-02 - 主板股票数: 1671, ami6唯一值数: 1667
# 月份 2015-02 的无风险收益率: 0.0022630000000000003
# 月份 2015-03 - 主板股票数: 1664, ami6唯一值数: 1660
# 月份 2015-03 的无风险收益率: 0.0020599999999999998
# 月份 2015-04 - 主板股票数: 1669, ami6唯一值数: 1665
# 月份 2015-04 的无风险收益率: 0.0020599999999999998
# 月份 2015-05 - 主板股票数: 1649, ami6唯一值数: 1630
# 月份 2015-05 的无风险收益率: 0.0020599999999999998
# 月份 2015-06 - 主板股票数: 1604, ami6唯一值数: 1585
# 月份 2015-06 的无风险收益率: 0.001856
# 月份 2015-07 - 主板股票数: 1544, ami6唯一值数: 1525
# 月份 2015-07 的无风险收益率: 0.0016520000000000003
# 月份 2015-08 - 主板股票数: 1502, ami6唯一值数: 1484
# 月份 2015-08 的无风险收益率: 0.0016520000000000003
# 月份 2015-09 - 主板股票数: 1482, ami6唯一值数: 1464
# 月份 2015-09 的无风险收益率: 0.001447
# 月份 2015-10 - 主板股票数: 1489, ami6唯一值数: 1486
# 月份 2015-10 的无风险收益率: 0.001447
# 月份 2015-11 - 主板股票数: 1507, ami6唯一值数: 1506
# 月份 2015-11 的无风险收益率: 0.0012410000000000001
# 月份 2015-12 - 主板股票数: 1518, ami6唯一值数: 1517
# 月份 2015-12 的无风险收益率: 0.0012410000000000001
# 月份 2016-01 - 主板股票数: 1536, ami6唯一值数: 1533
# 月份 2016-01 的无风险收益率: 0.0012410000000000001
# 月份 2016-02 - 主板股票数: 1577, ami6唯一值数: 1574
# 月份 2016-02 的无风险收益率: 0.0012410000000000001
# 月份 2016-03 - 主板股票数: 1612, ami6唯一值数: 1610
# 月份 2016-03 的无风险收益率: 0.0012410000000000001
# 月份 2016-04 - 主板股票数: 1712, ami6唯一值数: 1709
# 月份 2016-04 的无风险收益率: 0.0012410000000000001
# 月份 2016-05 - 主板股票数: 1734, ami6唯一值数: 1663
# 月份 2016-05 的无风险收益率: 0.0012410000000000001
# 月份 2016-06 - 主板股票数: 1747, ami6唯一值数: 1676
# 月份 2016-06 的无风险收益率: 0.0012410000000000001
# 月份 2016-07 - 主板股票数: 1754, ami6唯一值数: 1684
# 月份 2016-07 的无风险收益率: 0.0012410000000000001
# 月份 2016-08 - 主板股票数: 1774, ami6唯一值数: 1705
# 月份 2016-08 的无风险收益率: 0.0012410000000000001
# 月份 2016-09 - 主板股票数: 1777, ami6唯一值数: 1711
# 月份 2016-09 的无风险收益率: 0.0012410000000000001
# 月份 2016-10 - 主板股票数: 1775, ami6唯一值数: 1771
# 月份 2016-10 的无风险收益率: 0.0012410000000000001
# 月份 2016-11 - 主板股票数: 1796, ami6唯一值数: 1791
# 月份 2016-11 的无风险收益率: 0.0012410000000000001
# 月份 2016-12 - 主板股票数: 1817, ami6唯一值数: 1811
# 月份 2016-12 的无风险收益率: 0.0012410000000000001
# 月份 2017-01 - 主板股票数: 1820, ami6唯一值数: 1813
# 月份 2017-01 的无风险收益率: 0.0012410000000000001
# 月份 2017-02 - 主板股票数: 1826, ami6唯一值数: 1819
# 月份 2017-02 的无风险收益率: 0.0012410000000000001
# 月份 2017-03 - 主板股票数: 1827, ami6唯一值数: 1822
# 月份 2017-03 的无风险收益率: 0.0012410000000000001
# 月份 2017-04 - 主板股票数: 1944, ami6唯一值数: 1941
# 月份 2017-04 的无风险收益率: 0.0012410000000000001
# 月份 2017-05 - 主板股票数: 1932, ami6唯一值数: 1824
# 月份 2017-05 的无风险收益率: 0.0012410000000000001
# 月份 2017-06 - 主板股票数: 1924, ami6唯一值数: 1820
# 月份 2017-06 的无风险收益率: 0.0012410000000000001
# 月份 2017-07 - 主板股票数: 1919, ami6唯一值数: 1819
# 月份 2017-07 的无风险收益率: 0.0012410000000000001
# 月份 2017-08 - 主板股票数: 1919, ami6唯一值数: 1819
# 月份 2017-08 的无风险收益率: 0.0012410000000000001
# 月份 2017-09 - 主板股票数: 1935, ami6唯一值数: 1832
# 月份 2017-09 的无风险收益率: 0.0012410000000000001
# 月份 2017-10 - 主板股票数: 1942, ami6唯一值数: 1937
# 月份 2017-10 的无风险收益率: 0.0012410000000000001
# 月份 2017-11 - 主板股票数: 1940, ami6唯一值数: 1934
# 月份 2017-11 的无风险收益率: 0.0012410000000000001
# 月份 2017-12 - 主板股票数: 1949, ami6唯一值数: 1942
# 月份 2017-12 的无风险收益率: 0.0012410000000000001
# 月份 2018-01 - 主板股票数: 1948, ami6唯一值数: 1940
# 月份 2018-01 的无风险收益率: 0.0012410000000000001
# 月份 2018-02 - 主板股票数: 1955, ami6唯一值数: 1950
# 月份 2018-02 的无风险收益率: 0.0012410000000000001
# 月份 2018-03 - 主板股票数: 1941, ami6唯一值数: 1934
# 月份 2018-03 的无风险收益率: 0.0012410000000000001
# 月份 2018-04 - 主板股票数: 2054, ami6唯一值数: 2046
# 月份 2018-04 的无风险收益率: 0.0012410000000000001
# 月份 2018-05 - 主板股票数: 2045, ami6唯一值数: 1919
# 月份 2018-05 的无风险收益率: 0.0012410000000000001
# 月份 2018-06 - 主板股票数: 2047, ami6唯一值数: 1925
# 月份 2018-06 的无风险收益率: 0.0012410000000000001
# 月份 2018-07 - 主板股票数: 2037, ami6唯一值数: 1915
# 月份 2018-07 的无风险收益率: 0.0012410000000000001
# 月份 2018-08 - 主板股票数: 2065, ami6唯一值数: 1945
# 月份 2018-08 的无风险收益率: 0.0012410000000000001
# 月份 2018-09 - 主板股票数: 2085, ami6唯一值数: 1963
# 月份 2018-09 的无风险收益率: 0.0012410000000000001
# 月份 2018-10 - 主板股票数: 2133, ami6唯一值数: 2128
# 月份 2018-10 的无风险收益率: 0.0012410000000000001
# 月份 2018-11 - 主板股票数: 2165, ami6唯一值数: 2157
# 月份 2018-11 的无风险收益率: 0.0012410000000000001
# 月份 2018-12 - 主板股票数: 2198, ami6唯一值数: 2190
# 月份 2018-12 的无风险收益率: 0.0012410000000000001
# 月份 2019-01 - 主板股票数: 2230, ami6唯一值数: 2221
# 月份 2019-01 的无风险收益率: 0.0012410000000000001
# 月份 2019-02 - 主板股票数: 2249, ami6唯一值数: 2241
# 月份 2019-02 的无风险收益率: 0.0012410000000000001
# 月份 2019-03 - 主板股票数: 2266, ami6唯一值数: 2258
# 月份 2019-03 的无风险收益率: 0.0012410000000000001
# 月份 2019-04 - 主板股票数: 2436, ami6唯一值数: 2433
# 月份 2019-04 的无风险收益率: 0.0012410000000000001
# 月份 2019-05 - 主板股票数: 2442, ami6唯一值数: 2285
# 月份 2019-05 的无风险收益率: 0.0012410000000000001
# 月份 2019-06 - 主板股票数: 2442, ami6唯一值数: 2286
# 月份 2019-06 的无风险收益率: 0.0012410000000000001
# 月份 2019-07 - 主板股票数: 2442, ami6唯一值数: 2286
# 月份 2019-07 的无风险收益率: 0.0012410000000000001
# 月份 2019-08 - 主板股票数: 2442, ami6唯一值数: 2286
# 月份 2019-08 的无风险收益率: 0.0012410000000000001
# 月份 2019-09 - 主板股票数: 2442, ami6唯一值数: 2286
# 月份 2019-09 的无风险收益率: 0.0012410000000000001
# 月份 2019-10 - 主板股票数: 2442, ami6唯一值数: 2441
# 月份 2019-10 的无风险收益率: 0.0012410000000000001
# 月份 2019-11 - 主板股票数: 2443, ami6唯一值数: 2443
# 月份 2019-11 的无风险收益率: 0.0012410000000000001
# 月份 2019-12 - 主板股票数: 2443, ami6唯一值数: 2443
# 月份 2019-12 的无风险收益率: 0.0012410000000000001
# 月份 2020-01 - 主板股票数: 2443, ami6唯一值数: 2443
# 月份 2020-01 的无风险收益率: 0.0012410000000000001
# 月份 2020-02 - 主板股票数: 2443, ami6唯一值数: 2443
# 月份 2020-02 的无风险收益率: 0.0012410000000000001
# 月份 2020-03 - 主板股票数: 2443, ami6唯一值数: 2443
# 月份 2020-03 的无风险收益率: 0.0012410000000000001
# 月份 2020-04 - 主板股票数: 2553, ami6唯一值数: 2553
# 月份 2020-04 的无风险收益率: 0.0012410000000000001
# 月份 2020-05 - 主板股票数: 2552, ami6唯一值数: 2440
# 月份 2020-05 的无风险收益率: 0.0012410000000000001
# 月份 2020-06 - 主板股票数: 2552, ami6唯一值数: 2439
# 月份 2020-06 的无风险收益率: 0.0012410000000000001
# 月份 2020-07 - 主板股票数: 2552, ami6唯一值数: 2439
# 月份 2020-07 的无风险收益率: 0.0012410000000000001
# 月份 2020-08 - 主板股票数: 2551, ami6唯一值数: 2438
# 月份 2020-08 的无风险收益率: 0.0012410000000000001
# 月份 2020-09 - 主板股票数: 2551, ami6唯一值数: 2438
# 月份 2020-09 的无风险收益率: 0.0012410000000000001
# 月份 2020-10 - 主板股票数: 2551, ami6唯一值数: 2550
# 月份 2020-10 的无风险收益率: 0.0012410000000000001
# 月份 2020-11 - 主板股票数: 2553, ami6唯一值数: 2553
# 月份 2020-11 的无风险收益率: 0.0012410000000000001
# 月份 2020-12 - 主板股票数: 2554, ami6唯一值数: 2554
# 月份 2020-12 的无风险收益率: 0.0012410000000000001
# 月份 2021-01 - 主板股票数: 2555, ami6唯一值数: 2555
# 月份 2021-01 的无风险收益率: 0.0012410000000000001
# 月份 2021-02 - 主板股票数: 2556, ami6唯一值数: 2556
# 月份 2021-02 的无风险收益率: 0.0012410000000000001
# 月份 2021-03 - 主板股票数: 2556, ami6唯一值数: 2556
# 月份 2021-03 的无风险收益率: 0.0012410000000000001
# 月份 2021-04 - 主板股票数: 2632, ami6唯一值数: 2632
# 月份 2021-04 的无风险收益率: 0.0012410000000000001
# 月份 2021-05 - 主板股票数: 2633, ami6唯一值数: 2558
# 月份 2021-05 的无风险收益率: 0.0012410000000000001
# 月份 2021-06 - 主板股票数: 2633, ami6唯一值数: 2558
# 月份 2021-06 的无风险收益率: 0.0012410000000000001
# 月份 2021-07 - 主板股票数: 2633, ami6唯一值数: 2558
# 月份 2021-07 的无风险收益率: 0.0012410000000000001
# 月份 2021-08 - 主板股票数: 2633, ami6唯一值数: 2558
# 月份 2021-08 的无风险收益率: 0.0012410000000000001
# 月份 2021-09 - 主板股票数: 2633, ami6唯一值数: 2558
# 月份 2021-09 的无风险收益率: 0.0012410000000000001
# 月份 2021-10 - 主板股票数: 2633, ami6唯一值数: 2633
# 月份 2021-10 的无风险收益率: 0.0012410000000000001
# 月份 2021-11 - 主板股票数: 2633, ami6唯一值数: 2633
# 月份 2021-11 的无风险收益率: 0.0012410000000000001
# 月份 2021-12 - 主板股票数: 2633, ami6唯一值数: 2633
# 月份 2021-12 的无风险收益率: 0.0012410000000000001
# 月份 2022-01 - 主板股票数: 2634, ami6唯一值数: 2634
# 月份 2022-01 的无风险收益率: 0.0012410000000000001
# 月份 2022-02 - 主板股票数: 2634, ami6唯一值数: 2634
# 月份 2022-02 的无风险收益率: 0.0012410000000000001
# 月份 2022-03 - 主板股票数: 2634, ami6唯一值数: 2634
# 月份 2022-03 的无风险收益率: 0.0012410000000000001
# 月份 2022-04 - 主板股票数: 2802, ami6唯一值数: 2802
# 月份 2022-04 的无风险收益率: 0.0012410000000000001
# 月份 2022-05 - 主板股票数: 2802, ami6唯一值数: 2634
# 月份 2022-05 的无风险收益率: 0.0012410000000000001
# 月份 2022-06 - 主板股票数: 2801, ami6唯一值数: 2633
# 月份 2022-06 的无风险收益率: 0.0012410000000000001
# 月份 2022-07 - 主板股票数: 2801, ami6唯一值数: 2633
# 月份 2022-07 的无风险收益率: 0.0012410000000000001
# 月份 2022-08 - 主板股票数: 2801, ami6唯一值数: 2633
# 月份 2022-08 的无风险收益率: 0.0012410000000000001
# 月份 2022-09 - 主板股票数: 2801, ami6唯一值数: 2633
# 月份 2022-09 的无风险收益率: 0.0012410000000000001
# 月份 2022-10 - 主板股票数: 2801, ami6唯一值数: 2801
# 月份 2022-10 的无风险收益率: 0.0013650000000000001
# 月份 2022-11 - 主板股票数: 2801, ami6唯一值数: 2801
# 月份 2022-11 的无风险收益率: 0.0013650000000000001
# 月份 2022-12 - 主板股票数: 2802, ami6唯一值数: 2802
# 月份 2022-12 的无风险收益率: 0.0013650000000000001
# 月份 2023-01 - 主板股票数: 2803, ami6唯一值数: 2803
# 月份 2023-01 的无风险收益率: 0.0013650000000000001
# 月份 2023-02 - 主板股票数: 2803, ami6唯一值数: 2803
# 月份 2023-02 的无风险收益率: 0.0013650000000000001
# 月份 2023-03 - 主板股票数: 2803, ami6唯一值数: 2803
# 月份 2023-03 的无风险收益率: 0.0013650000000000001
# 月份 2023-04 - 主板股票数: 2987, ami6唯一值数: 2987
# 月份 2023-04 的无风险收益率: 0.0013650000000000001
# 月份 2023-05 - 主板股票数: 2984, ami6唯一值数: 2800
# 月份 2023-05 的无风险收益率: 0.0013650000000000001
# 月份 2023-06 - 主板股票数: 2984, ami6唯一值数: 2800
# 月份 2023-06 的无风险收益率: 0.0013650000000000001
# 月份 2023-07 - 主板股票数: 2984, ami6唯一值数: 2800
# 月份 2023-07 的无风险收益率: 0.0013650000000000001
# 月份 2023-08 - 主板股票数: 2984, ami6唯一值数: 2800
# 月份 2023-08 的无风险收益率: 0.0013650000000000001
# 月份 2023-09 - 主板股票数: 2984, ami6唯一值数: 2800
# 月份 2023-09 的无风险收益率: 0.001283
# 月份 2023-10 - 主板股票数: 2984, ami6唯一值数: 2984
# 月份 2023-10 的无风险收益率: 0.001283
# 月份 2023-11 - 主板股票数: 2986, ami6唯一值数: 2986
# 月份 2023-11 的无风险收益率: 0.001283
# 月份 2023-12 - 主板股票数: 2987, ami6唯一值数: 2987
# 月份 2023-12 的无风险收益率: 0.001283
# 月份 2024-01 - 主板股票数: 2987, ami6唯一值数: 2987
# 月份 2024-01 的无风险收益率: 0.001283
# 月份 2024-02 - 主板股票数: 2985, ami6唯一值数: 2985
# 月份 2024-02 的无风险收益率: 0.001283
# ami6 投资组合完成，生成记录数: 220
# ami6 投资组合已导出至 output\ami6.xlsx
# ami9 计算完成，非缺失值数: 481915
#
# 开始构造 ami9 投资组合
# 月份 2005-06 - 主板股票数: 1075, ami9唯一值数: 1067
# 月份 2005-06 的无风险收益率: 0.001856
# 月份 2005-07 - 主板股票数: 1074, ami9唯一值数: 0
# 跳过月份 2005-07，因为ami9的主板股票唯一值数目少于5
# 月份 2005-08 - 主板股票数: 1073, ami9唯一值数: 0
# 跳过月份 2005-08，因为ami9的主板股票唯一值数目少于5
# 月份 2005-09 - 主板股票数: 1072, ami9唯一值数: 0
# 跳过月份 2005-09，因为ami9的主板股票唯一值数目少于5
# 月份 2005-10 - 主板股票数: 1070, ami9唯一值数: 1
# 跳过月份 2005-10，因为ami9的主板股票唯一值数目少于5
# 月份 2005-11 - 主板股票数: 1069, ami9唯一值数: 2
# 跳过月份 2005-11，因为ami9的主板股票唯一值数目少于5
# 月份 2005-12 - 主板股票数: 1063, ami9唯一值数: 2
# 跳过月份 2005-12，因为ami9的主板股票唯一值数目少于5
# 月份 2006-01 - 主板股票数: 1045, ami9唯一值数: 0
# 跳过月份 2006-01，因为ami9的主板股票唯一值数目少于5
# 月份 2006-02 - 主板股票数: 1028, ami9唯一值数: 0
# 跳过月份 2006-02，因为ami9的主板股票唯一值数目少于5
# 月份 2006-03 - 主板股票数: 1014, ami9唯一值数: 1006
# 月份 2006-03 的无风险收益率: 0.001856
# 月份 2006-04 - 主板股票数: 1073, ami9唯一值数: 1062
# 月份 2006-04 的无风险收益率: 0.001856
# 月份 2006-05 - 主板股票数: 1040, ami9唯一值数: 937
# 月份 2006-05 的无风险收益率: 0.001856
# 月份 2006-06 - 主板股票数: 1042, ami9唯一值数: 930
# 月份 2006-06 的无风险收益率: 0.001856
# 月份 2006-07 - 主板股票数: 1046, ami9唯一值数: 917
# 月份 2006-07 的无风险收益率: 0.001856
# 月份 2006-08 - 主板股票数: 1044, ami9唯一值数: 900
# 月份 2006-08 的无风险收益率: 0.001856
# 月份 2006-09 - 主板股票数: 1051, ami9唯一值数: 953
# 月份 2006-09 的无风险收益率: 0.002076
# 月份 2006-10 - 主板股票数: 1064, ami9唯一值数: 965
# 月份 2006-10 的无风险收益率: 0.002076
# 月份 2006-11 - 主板股票数: 1079, ami9唯一值数: 981
# 月份 2006-11 的无风险收益率: 0.002076
# 月份 2006-12 - 主板股票数: 1080, ami9唯一值数: 983
# 月份 2006-12 的无风险收益率: 0.002076
# 月份 2007-01 - 主板股票数: 1066, ami9唯一值数: 1055
# 月份 2007-01 的无风险收益率: 0.002076
# 月份 2007-02 - 主板股票数: 1069, ami9唯一值数: 1058
# 月份 2007-02 的无风险收益率: 0.002076
# 月份 2007-03 - 主板股票数: 1076, ami9唯一值数: 1066
# 月份 2007-03 的无风险收益率: 0.002076
# 月份 2007-04 - 主板股票数: 1096, ami9唯一值数: 1087
# 月份 2007-04 的无风险收益率: 0.002296
# 月份 2007-05 - 主板股票数: 1074, ami9唯一值数: 1054
# 月份 2007-05 的无风险收益率: 0.002296
# 月份 2007-06 - 主板股票数: 1076, ami9唯一值数: 1058
# 月份 2007-06 的无风险收益率: 0.002515
# 月份 2007-07 - 主板股票数: 1087, ami9唯一值数: 1073
# 月份 2007-07 的无风险收益率: 0.002515
# 月份 2007-08 - 主板股票数: 1092, ami9唯一值数: 1081
# 月份 2007-08 的无风险收益率: 0.002734
# 月份 2007-09 - 主板股票数: 1084, ami9唯一值数: 1074
# 月份 2007-09 的无风险收益率: 0.002952
# 月份 2007-10 - 主板股票数: 1076, ami9唯一值数: 1066
# 月份 2007-10 的无风险收益率: 0.0031690000000000004
# 月份 2007-11 - 主板股票数: 1082, ami9唯一值数: 1072
# 月份 2007-11 的无风险收益率: 0.0031690000000000004
# 月份 2007-12 - 主板股票数: 1077, ami9唯一值数: 1068
# 月份 2007-12 的无风险收益率: 0.0031690000000000004
# 月份 2008-01 - 主板股票数: 1074, ami9唯一值数: 1074
# 月份 2008-01 的无风险收益率: 0.003386
# 月份 2008-02 - 主板股票数: 1069, ami9唯一值数: 1069
# 月份 2008-02 的无风险收益率: 0.003386
# 月份 2008-03 - 主板股票数: 1074, ami9唯一值数: 1073
# 月份 2008-03 的无风险收益率: 0.003386
# 月份 2008-04 - 主板股票数: 1157, ami9唯一值数: 1156
# 月份 2008-04 的无风险收益率: 0.003386
# 月份 2008-05 - 主板股票数: 1143, ami9唯一值数: 1061
# 月份 2008-05 的无风险收益率: 0.003386
# 月份 2008-06 - 主板股票数: 1154, ami9唯一值数: 1072
# 月份 2008-06 的无风险收益率: 0.003386
# 月份 2008-07 - 主板股票数: 1159, ami9唯一值数: 1077
# 月份 2008-07 的无风险收益率: 0.003386
# 月份 2008-08 - 主板股票数: 1163, ami9唯一值数: 1082
# 月份 2008-08 的无风险收益率: 0.003386
# 月份 2008-09 - 主板股票数: 1172, ami9唯一值数: 1090
# 月份 2008-09 的无风险收益率: 0.003386
# 月份 2008-10 - 主板股票数: 1190, ami9唯一值数: 1106
# 月份 2008-10 的无风险收益率: 0.003386
# 月份 2008-11 - 主板股票数: 1204, ami9唯一值数: 1120
# 月份 2008-11 的无风险收益率: 0.002952
# 月份 2008-12 - 主板股票数: 1215, ami9唯一值数: 1131
# 月份 2008-12 的无风险收益率: 0.002076
# 月份 2009-01 - 主板股票数: 1210, ami9唯一值数: 1208
# 月份 2009-01 的无风险收益率: 0.001856
# 月份 2009-02 - 主板股票数: 1214, ami9唯一值数: 1213
# 月份 2009-02 的无风险收益率: 0.001856
# 月份 2009-03 - 主板股票数: 1215, ami9唯一值数: 1214
# 月份 2009-03 的无风险收益率: 0.001856
# 月份 2009-04 - 主板股票数: 1341, ami9唯一值数: 1340
# 月份 2009-04 的无风险收益率: 0.001856
# 月份 2009-05 - 主板股票数: 1344, ami9唯一值数: 1222
# 月份 2009-05 的无风险收益率: 0.001856
# 月份 2009-06 - 主板股票数: 1346, ami9唯一值数: 1225
# 月份 2009-06 的无风险收益率: 0.001856
# 月份 2009-07 - 主板股票数: 1350, ami9唯一值数: 1229
# 月份 2009-07 的无风险收益率: 0.001856
# 月份 2009-08 - 主板股票数: 1350, ami9唯一值数: 1228
# 月份 2009-08 的无风险收益率: 0.001856
# 月份 2009-09 - 主板股票数: 1356, ami9唯一值数: 1234
# 月份 2009-09 的无风险收益率: 0.001856
# 月份 2009-10 - 主板股票数: 1355, ami9唯一值数: 1233
# 月份 2009-10 的无风险收益率: 0.001856
# 月份 2009-11 - 主板股票数: 1360, ami9唯一值数: 1238
# 月份 2009-11 的无风险收益率: 0.001856
# 月份 2009-12 - 主板股票数: 1357, ami9唯一值数: 1234
# 月份 2009-12 的无风险收益率: 0.001856
# 月份 2010-01 - 主板股票数: 1354, ami9唯一值数: 1352
# 月份 2010-01 的无风险收益率: 0.001856
# 月份 2010-02 - 主板股票数: 1357, ami9唯一值数: 1354
# 月份 2010-02 的无风险收益率: 0.001856
# 月份 2010-03 - 主板股票数: 1357, ami9唯一值数: 1354
# 月份 2010-03 的无风险收益率: 0.001856
# 月份 2010-04 - 主板股票数: 1409, ami9唯一值数: 1407
# 月份 2010-04 的无风险收益率: 0.001856
# 月份 2010-05 - 主板股票数: 1400, ami9唯一值数: 1344
# 月份 2010-05 的无风险收益率: 0.001856
# 月份 2010-06 - 主板股票数: 1396, ami9唯一值数: 1341
# 月份 2010-06 的无风险收益率: 0.001856
# 月份 2010-07 - 主板股票数: 1398, ami9唯一值数: 1343
# 月份 2010-07 的无风险收益率: 0.001856
# 月份 2010-08 - 主板股票数: 1392, ami9唯一值数: 1338
# 月份 2010-08 的无风险收益率: 0.001856
# 月份 2010-09 - 主板股票数: 1392, ami9唯一值数: 1338
# 月份 2010-09 的无风险收益率: 0.001856
# 月份 2010-10 - 主板股票数: 1391, ami9唯一值数: 1337
# 月份 2010-10 的无风险收益率: 0.001856
# 月份 2010-11 - 主板股票数: 1391, ami9唯一值数: 1337
# 月份 2010-11 的无风险收益率: 0.0020599999999999998
# 月份 2010-12 - 主板股票数: 1386, ami9唯一值数: 1332
# 月份 2010-12 的无风险收益率: 0.0020599999999999998
# 月份 2011-01 - 主板股票数: 1381, ami9唯一值数: 1381
# 月份 2011-01 的无风险收益率: 0.0022630000000000003
# 月份 2011-02 - 主板股票数: 1387, ami9唯一值数: 1387
# 月份 2011-02 的无风险收益率: 0.0022630000000000003
# 月份 2011-03 - 主板股票数: 1380, ami9唯一值数: 1380
# 月份 2011-03 的无风险收益率: 0.0024660000000000003
# 月份 2011-04 - 主板股票数: 1467, ami9唯一值数: 1467
# 月份 2011-04 的无风险收益率: 0.0024660000000000003
# 月份 2011-05 - 主板股票数: 1464, ami9唯一值数: 1372
# 月份 2011-05 的无风险收益率: 0.0026690000000000004
# 月份 2011-06 - 主板股票数: 1465, ami9唯一值数: 1373
# 月份 2011-06 的无风险收益率: 0.0026690000000000004
# 月份 2011-07 - 主板股票数: 1464, ami9唯一值数: 1373
# 月份 2011-07 的无风险收益率: 0.0026690000000000004
# 月份 2011-08 - 主板股票数: 1464, ami9唯一值数: 1373
# 月份 2011-08 的无风险收益率: 0.0028710000000000003
# 月份 2011-09 - 主板股票数: 1467, ami9唯一值数: 1376
# 月份 2011-09 的无风险收益率: 0.0028710000000000003
# 月份 2011-10 - 主板股票数: 1467, ami9唯一值数: 1376
# 月份 2011-10 的无风险收益率: 0.0028710000000000003
# 月份 2011-11 - 主板股票数: 1461, ami9唯一值数: 1370
# 月份 2011-11 的无风险收益率: 0.0028710000000000003
# 月份 2011-12 - 主板股票数: 1464, ami9唯一值数: 1372
# 月份 2011-12 的无风险收益率: 0.0028710000000000003
# 月份 2012-01 - 主板股票数: 1469, ami9唯一值数: 1468
# 月份 2012-01 的无风险收益率: 0.0028710000000000003
# 月份 2012-02 - 主板股票数: 1467, ami9唯一值数: 1466
# 月份 2012-02 的无风险收益率: 0.0028710000000000003
# 月份 2012-03 - 主板股票数: 1466, ami9唯一值数: 1464
# 月份 2012-03 的无风险收益率: 0.0028710000000000003
# 月份 2012-04 - 主板股票数: 1675, ami9唯一值数: 1674
# 月份 2012-04 的无风险收益率: 0.0028710000000000003
# 月份 2012-05 - 主板股票数: 1677, ami9唯一值数: 1468
# 月份 2012-05 的无风险收益率: 0.0028710000000000003
# 月份 2012-06 - 主板股票数: 1679, ami9唯一值数: 1470
# 月份 2012-06 的无风险收益率: 0.0028710000000000003
# 月份 2012-07 - 主板股票数: 1686, ami9唯一值数: 1477
# 月份 2012-07 的无风险收益率: 0.0026690000000000004
# 月份 2012-08 - 主板股票数: 1684, ami9唯一值数: 1475
# 月份 2012-08 的无风险收益率: 0.0024660000000000003
# 月份 2012-09 - 主板股票数: 1686, ami9唯一值数: 1478
# 月份 2012-09 的无风险收益率: 0.0024660000000000003
# 月份 2012-10 - 主板股票数: 1689, ami9唯一值数: 1481
# 月份 2012-10 的无风险收益率: 0.0024660000000000003
# 月份 2012-11 - 主板股票数: 1696, ami9唯一值数: 1487
# 月份 2012-11 的无风险收益率: 0.0024660000000000003
# 月份 2012-12 - 主板股票数: 1694, ami9唯一值数: 1485
# 月份 2012-12 的无风险收益率: 0.0024660000000000003
# 月份 2013-01 - 主板股票数: 1688, ami9唯一值数: 1685
# 月份 2013-01 的无风险收益率: 0.0024660000000000003
# 月份 2013-02 - 主板股票数: 1683, ami9唯一值数: 1681
# 月份 2013-02 的无风险收益率: 0.0024660000000000003
# 月份 2013-03 - 主板股票数: 1678, ami9唯一值数: 1675
# 月份 2013-03 的无风险收益率: 0.0024660000000000003
# 月份 2013-04 - 主板股票数: 1799, ami9唯一值数: 1796
# 月份 2013-04 的无风险收益率: 0.0024660000000000003
# 月份 2013-05 - 主板股票数: 1795, ami9唯一值数: 1667
# 月份 2013-05 的无风险收益率: 0.0024660000000000003
# 月份 2013-06 - 主板股票数: 1780, ami9唯一值数: 1652
# 月份 2013-06 的无风险收益率: 0.0024660000000000003
# 月份 2013-07 - 主板股票数: 1783, ami9唯一值数: 1657
# 月份 2013-07 的无风险收益率: 0.0024660000000000003
# 月份 2013-08 - 主板股票数: 1779, ami9唯一值数: 1656
# 月份 2013-08 的无风险收益率: 0.0024660000000000003
# 月份 2013-09 - 主板股票数: 1770, ami9唯一值数: 1648
# 月份 2013-09 的无风险收益率: 0.0024660000000000003
# 月份 2013-10 - 主板股票数: 1768, ami9唯一值数: 1647
# 月份 2013-10 的无风险收益率: 0.0024660000000000003
# 月份 2013-11 - 主板股票数: 1761, ami9唯一值数: 1640
# 月份 2013-11 的无风险收益率: 0.0024660000000000003
# 月份 2013-12 - 主板股票数: 1767, ami9唯一值数: 1646
# 月份 2013-12 的无风险收益率: 0.0024660000000000003
# 月份 2014-01 - 主板股票数: 1768, ami9唯一值数: 1765
# 月份 2014-01 的无风险收益率: 0.0024660000000000003
# 月份 2014-02 - 主板股票数: 1765, ami9唯一值数: 1762
# 月份 2014-02 的无风险收益率: 0.0024660000000000003
# 月份 2014-03 - 主板股票数: 1758, ami9唯一值数: 1754
# 月份 2014-03 的无风险收益率: 0.0024660000000000003
# 月份 2014-04 - 主板股票数: 1800, ami9唯一值数: 1796
# 月份 2014-04 的无风险收益率: 0.0024660000000000003
# 月份 2014-05 - 主板股票数: 1769, ami9唯一值数: 1702
# 月份 2014-05 的无风险收益率: 0.0024660000000000003
# 月份 2014-06 - 主板股票数: 1757, ami9唯一值数: 1689
# 月份 2014-06 的无风险收益率: 0.0024660000000000003
# 月份 2014-07 - 主板股票数: 1736, ami9唯一值数: 1668
# 月份 2014-07 的无风险收益率: 0.0024660000000000003
# 月份 2014-08 - 主板股票数: 1727, ami9唯一值数: 1665
# 月份 2014-08 的无风险收益率: 0.0024660000000000003
# 月份 2014-09 - 主板股票数: 1712, ami9唯一值数: 1652
# 月份 2014-09 的无风险收益率: 0.0024660000000000003
# 月份 2014-10 - 主板股票数: 1688, ami9唯一值数: 1628
# 月份 2014-10 的无风险收益率: 0.0024660000000000003
# 月份 2014-11 - 主板股票数: 1686, ami9唯一值数: 1626
# 月份 2014-11 的无风险收益率: 0.0024660000000000003
# 月份 2014-12 - 主板股票数: 1687, ami9唯一值数: 1629
# 月份 2014-12 的无风险收益率: 0.0022630000000000003
# 月份 2015-01 - 主板股票数: 1679, ami9唯一值数: 1675
# 月份 2015-01 的无风险收益率: 0.0022630000000000003
# 月份 2015-02 - 主板股票数: 1671, ami9唯一值数: 1667
# 月份 2015-02 的无风险收益率: 0.0022630000000000003
# 月份 2015-03 - 主板股票数: 1664, ami9唯一值数: 1660
# 月份 2015-03 的无风险收益率: 0.0020599999999999998
# 月份 2015-04 - 主板股票数: 1669, ami9唯一值数: 1664
# 月份 2015-04 的无风险收益率: 0.0020599999999999998
# 月份 2015-05 - 主板股票数: 1649, ami9唯一值数: 1626
# 月份 2015-05 的无风险收益率: 0.0020599999999999998
# 月份 2015-06 - 主板股票数: 1604, ami9唯一值数: 1581
# 月份 2015-06 的无风险收益率: 0.001856
# 月份 2015-07 - 主板股票数: 1544, ami9唯一值数: 1521
# 月份 2015-07 的无风险收益率: 0.0016520000000000003
# 月份 2015-08 - 主板股票数: 1502, ami9唯一值数: 1482
# 月份 2015-08 的无风险收益率: 0.0016520000000000003
# 月份 2015-09 - 主板股票数: 1482, ami9唯一值数: 1463
# 月份 2015-09 的无风险收益率: 0.001447
# 月份 2015-10 - 主板股票数: 1489, ami9唯一值数: 1467
# 月份 2015-10 的无风险收益率: 0.001447
# 月份 2015-11 - 主板股票数: 1507, ami9唯一值数: 1487
# 月份 2015-11 的无风险收益率: 0.0012410000000000001
# 月份 2015-12 - 主板股票数: 1518, ami9唯一值数: 1499
# 月份 2015-12 的无风险收益率: 0.0012410000000000001
# 月份 2016-01 - 主板股票数: 1536, ami9唯一值数: 1530
# 月份 2016-01 的无风险收益率: 0.0012410000000000001
# 月份 2016-02 - 主板股票数: 1577, ami9唯一值数: 1574
# 月份 2016-02 的无风险收益率: 0.0012410000000000001
# 月份 2016-03 - 主板股票数: 1612, ami9唯一值数: 1609
# 月份 2016-03 的无风险收益率: 0.0012410000000000001
# 月份 2016-04 - 主板股票数: 1712, ami9唯一值数: 1708
# 月份 2016-04 的无风险收益率: 0.0012410000000000001
# 月份 2016-05 - 主板股票数: 1734, ami9唯一值数: 1662
# 月份 2016-05 的无风险收益率: 0.0012410000000000001
# 月份 2016-06 - 主板股票数: 1747, ami9唯一值数: 1675
# 月份 2016-06 的无风险收益率: 0.0012410000000000001
# 月份 2016-07 - 主板股票数: 1754, ami9唯一值数: 1682
# 月份 2016-07 的无风险收益率: 0.0012410000000000001
# 月份 2016-08 - 主板股票数: 1774, ami9唯一值数: 1702
# 月份 2016-08 的无风险收益率: 0.0012410000000000001
# 月份 2016-09 - 主板股票数: 1777, ami9唯一值数: 1709
# 月份 2016-09 的无风险收益率: 0.0012410000000000001
# 月份 2016-10 - 主板股票数: 1775, ami9唯一值数: 1706
# 月份 2016-10 的无风险收益率: 0.0012410000000000001
# 月份 2016-11 - 主板股票数: 1796, ami9唯一值数: 1725
# 月份 2016-11 的无风险收益率: 0.0012410000000000001
# 月份 2016-12 - 主板股票数: 1817, ami9唯一值数: 1747
# 月份 2016-12 的无风险收益率: 0.0012410000000000001
# 月份 2017-01 - 主板股票数: 1820, ami9唯一值数: 1812
# 月份 2017-01 的无风险收益率: 0.0012410000000000001
# 月份 2017-02 - 主板股票数: 1826, ami9唯一值数: 1818
# 月份 2017-02 的无风险收益率: 0.0012410000000000001
# 月份 2017-03 - 主板股票数: 1827, ami9唯一值数: 1819
# 月份 2017-03 的无风险收益率: 0.0012410000000000001
# 月份 2017-04 - 主板股票数: 1944, ami9唯一值数: 1936
# 月份 2017-04 的无风险收益率: 0.0012410000000000001
# 月份 2017-05 - 主板股票数: 1932, ami9唯一值数: 1819
# 月份 2017-05 的无风险收益率: 0.0012410000000000001
# 月份 2017-06 - 主板股票数: 1924, ami9唯一值数: 1815
# 月份 2017-06 的无风险收益率: 0.0012410000000000001
# 月份 2017-07 - 主板股票数: 1919, ami9唯一值数: 1815
# 月份 2017-07 的无风险收益率: 0.0012410000000000001
# 月份 2017-08 - 主板股票数: 1919, ami9唯一值数: 1814
# 月份 2017-08 的无风险收益率: 0.0012410000000000001
# 月份 2017-09 - 主板股票数: 1935, ami9唯一值数: 1831
# 月份 2017-09 的无风险收益率: 0.0012410000000000001
# 月份 2017-10 - 主板股票数: 1942, ami9唯一值数: 1838
# 月份 2017-10 的无风险收益率: 0.0012410000000000001
# 月份 2017-11 - 主板股票数: 1940, ami9唯一值数: 1834
# 月份 2017-11 的无风险收益率: 0.0012410000000000001
# 月份 2017-12 - 主板股票数: 1949, ami9唯一值数: 1843
# 月份 2017-12 的无风险收益率: 0.0012410000000000001
# 月份 2018-01 - 主板股票数: 1948, ami9唯一值数: 1937
# 月份 2018-01 的无风险收益率: 0.0012410000000000001
# 月份 2018-02 - 主板股票数: 1955, ami9唯一值数: 1945
# 月份 2018-02 的无风险收益率: 0.0012410000000000001
# 月份 2018-03 - 主板股票数: 1941, ami9唯一值数: 1930
# 月份 2018-03 的无风险收益率: 0.0012410000000000001
# 月份 2018-04 - 主板股票数: 2054, ami9唯一值数: 2042
# 月份 2018-04 的无风险收益率: 0.0012410000000000001
# 月份 2018-05 - 主板股票数: 2045, ami9唯一值数: 1916
# 月份 2018-05 的无风险收益率: 0.0012410000000000001
# 月份 2018-06 - 主板股票数: 2047, ami9唯一值数: 1918
# 月份 2018-06 的无风险收益率: 0.0012410000000000001
# 月份 2018-07 - 主板股票数: 2037, ami9唯一值数: 1909
# ...
# 月份 2010-03 的无风险收益率: 0.001856
# 月份 2010-04 - 主板股票数: 1409, dfin_standardized唯一值数: 1392
# 月份 2010-04 的无风险收益率: 0.001856
# 月份 2010-05 - 主板股票数: 1400, dfin_standardized唯一值数: 1383
# 月份 2010-05 的无风险收益率: 0.001856
# 月份 2010-06 - 主板股票数: 1396, dfin_standardized唯一值数: 1379
# 月份 2010-06 的无风险收益率: 0.001856
# 月份 2010-07 - 主板股票数: 1398, dfin_standardized唯一值数: 1381
# 月份 2010-07 的无风险收益率: 0.001856
# 月份 2010-08 - 主板股票数: 1392, dfin_standardized唯一值数: 1375
# 月份 2010-08 的无风险收益率: 0.001856
# 月份 2010-09 - 主板股票数: 1392, dfin_standardized唯一值数: 1375
# 月份 2010-09 的无风险收益率: 0.001856
# 月份 2010-10 - 主板股票数: 1391, dfin_standardized唯一值数: 1373
# 月份 2010-10 的无风险收益率: 0.001856
# 月份 2010-11 - 主板股票数: 1391, dfin_standardized唯一值数: 1373
# 月份 2010-11 的无风险收益率: 0.0020599999999999998
# 月份 2010-12 - 主板股票数: 1386, dfin_standardized唯一值数: 1369
# 月份 2010-12 的无风险收益率: 0.0020599999999999998
# 月份 2011-01 - 主板股票数: 1381, dfin_standardized唯一值数: 1364
# 月份 2011-01 的无风险收益率: 0.0022630000000000003
# 月份 2011-02 - 主板股票数: 1387, dfin_standardized唯一值数: 1370
# 月份 2011-02 的无风险收益率: 0.0022630000000000003
# 月份 2011-03 - 主板股票数: 1380, dfin_standardized唯一值数: 1363
# 月份 2011-03 的无风险收益率: 0.0024660000000000003
# 月份 2011-04 - 主板股票数: 1467, dfin_standardized唯一值数: 1438
# 月份 2011-04 的无风险收益率: 0.0024660000000000003
# 月份 2011-05 - 主板股票数: 1464, dfin_standardized唯一值数: 1436
# 月份 2011-05 的无风险收益率: 0.0026690000000000004
# 月份 2011-06 - 主板股票数: 1465, dfin_standardized唯一值数: 1437
# 月份 2011-06 的无风险收益率: 0.0026690000000000004
# 月份 2011-07 - 主板股票数: 1464, dfin_standardized唯一值数: 1436
# 月份 2011-07 的无风险收益率: 0.0026690000000000004
# 月份 2011-08 - 主板股票数: 1464, dfin_standardized唯一值数: 1437
# 月份 2011-08 的无风险收益率: 0.0028710000000000003
# 月份 2011-09 - 主板股票数: 1467, dfin_standardized唯一值数: 1440
# 月份 2011-09 的无风险收益率: 0.0028710000000000003
# 月份 2011-10 - 主板股票数: 1467, dfin_standardized唯一值数: 1440
# 月份 2011-10 的无风险收益率: 0.0028710000000000003
# 月份 2011-11 - 主板股票数: 1461, dfin_standardized唯一值数: 1433
# 月份 2011-11 的无风险收益率: 0.0028710000000000003
# 月份 2011-12 - 主板股票数: 1464, dfin_standardized唯一值数: 1434
# 月份 2011-12 的无风险收益率: 0.0028710000000000003
# 月份 2012-01 - 主板股票数: 1469, dfin_standardized唯一值数: 1438
# 月份 2012-01 的无风险收益率: 0.0028710000000000003
# 月份 2012-02 - 主板股票数: 1467, dfin_standardized唯一值数: 1437
# 月份 2012-02 的无风险收益率: 0.0028710000000000003
# 月份 2012-03 - 主板股票数: 1466, dfin_standardized唯一值数: 1436
# 月份 2012-03 的无风险收益率: 0.0028710000000000003
# 月份 2012-04 - 主板股票数: 1675, dfin_standardized唯一值数: 1637
# 月份 2012-04 的无风险收益率: 0.0028710000000000003
# 月份 2012-05 - 主板股票数: 1677, dfin_standardized唯一值数: 1638
# 月份 2012-05 的无风险收益率: 0.0028710000000000003
# 月份 2012-06 - 主板股票数: 1679, dfin_standardized唯一值数: 1640
# 月份 2012-06 的无风险收益率: 0.0028710000000000003
# 月份 2012-07 - 主板股票数: 1686, dfin_standardized唯一值数: 1646
# 月份 2012-07 的无风险收益率: 0.0026690000000000004
# 月份 2012-08 - 主板股票数: 1684, dfin_standardized唯一值数: 1643
# 月份 2012-08 的无风险收益率: 0.0024660000000000003
# 月份 2012-09 - 主板股票数: 1686, dfin_standardized唯一值数: 1645
# 月份 2012-09 的无风险收益率: 0.0024660000000000003
# 月份 2012-10 - 主板股票数: 1689, dfin_standardized唯一值数: 1649
# 月份 2012-10 的无风险收益率: 0.0024660000000000003
# 月份 2012-11 - 主板股票数: 1696, dfin_standardized唯一值数: 1656
# 月份 2012-11 的无风险收益率: 0.0024660000000000003
# 月份 2012-12 - 主板股票数: 1694, dfin_standardized唯一值数: 1654
# 月份 2012-12 的无风险收益率: 0.0024660000000000003
# 月份 2013-01 - 主板股票数: 1688, dfin_standardized唯一值数: 1648
# 月份 2013-01 的无风险收益率: 0.0024660000000000003
# 月份 2013-02 - 主板股票数: 1683, dfin_standardized唯一值数: 1644
# 月份 2013-02 的无风险收益率: 0.0024660000000000003
# 月份 2013-03 - 主板股票数: 1678, dfin_standardized唯一值数: 1639
# 月份 2013-03 的无风险收益率: 0.0024660000000000003
# 月份 2013-04 - 主板股票数: 1799, dfin_standardized唯一值数: 1741
# 月份 2013-04 的无风险收益率: 0.0024660000000000003
# 月份 2013-05 - 主板股票数: 1795, dfin_standardized唯一值数: 1737
# 月份 2013-05 的无风险收益率: 0.0024660000000000003
# 月份 2013-06 - 主板股票数: 1780, dfin_standardized唯一值数: 1721
# 月份 2013-06 的无风险收益率: 0.0024660000000000003
# 月份 2013-07 - 主板股票数: 1783, dfin_standardized唯一值数: 1722
# 月份 2013-07 的无风险收益率: 0.0024660000000000003
# 月份 2013-08 - 主板股票数: 1779, dfin_standardized唯一值数: 1720
# 月份 2013-08 的无风险收益率: 0.0024660000000000003
# 月份 2013-09 - 主板股票数: 1770, dfin_standardized唯一值数: 1710
# 月份 2013-09 的无风险收益率: 0.0024660000000000003
# 月份 2013-10 - 主板股票数: 1768, dfin_standardized唯一值数: 1709
# 月份 2013-10 的无风险收益率: 0.0024660000000000003
# 月份 2013-11 - 主板股票数: 1761, dfin_standardized唯一值数: 1703
# 月份 2013-11 的无风险收益率: 0.0024660000000000003
# 月份 2013-12 - 主板股票数: 1767, dfin_standardized唯一值数: 1708
# 月份 2013-12 的无风险收益率: 0.0024660000000000003
# 月份 2014-01 - 主板股票数: 1768, dfin_standardized唯一值数: 1709
# 月份 2014-01 的无风险收益率: 0.0024660000000000003
# 月份 2014-02 - 主板股票数: 1765, dfin_standardized唯一值数: 1706
# 月份 2014-02 的无风险收益率: 0.0024660000000000003
# 月份 2014-03 - 主板股票数: 1758, dfin_standardized唯一值数: 1697
# 月份 2014-03 的无风险收益率: 0.0024660000000000003
# 月份 2014-04 - 主板股票数: 1800, dfin_standardized唯一值数: 1748
# 月份 2014-04 的无风险收益率: 0.0024660000000000003
# 月份 2014-05 - 主板股票数: 1769, dfin_standardized唯一值数: 1720
# 月份 2014-05 的无风险收益率: 0.0024660000000000003
# 月份 2014-06 - 主板股票数: 1757, dfin_standardized唯一值数: 1709
# 月份 2014-06 的无风险收益率: 0.0024660000000000003
# 月份 2014-07 - 主板股票数: 1736, dfin_standardized唯一值数: 1688
# 月份 2014-07 的无风险收益率: 0.0024660000000000003
# 月份 2014-08 - 主板股票数: 1727, dfin_standardized唯一值数: 1681
# 月份 2014-08 的无风险收益率: 0.0024660000000000003
# 月份 2014-09 - 主板股票数: 1712, dfin_standardized唯一值数: 1667
# 月份 2014-09 的无风险收益率: 0.0024660000000000003
# 月份 2014-10 - 主板股票数: 1688, dfin_standardized唯一值数: 1643
# 月份 2014-10 的无风险收益率: 0.0024660000000000003
# 月份 2014-11 - 主板股票数: 1686, dfin_standardized唯一值数: 1642
# 月份 2014-11 的无风险收益率: 0.0024660000000000003
# 月份 2014-12 - 主板股票数: 1687, dfin_standardized唯一值数: 1641
# 月份 2014-12 的无风险收益率: 0.0022630000000000003
# 月份 2015-01 - 主板股票数: 1679, dfin_standardized唯一值数: 1634
# 月份 2015-01 的无风险收益率: 0.0022630000000000003
# 月份 2015-02 - 主板股票数: 1671, dfin_standardized唯一值数: 1626
# 月份 2015-02 的无风险收益率: 0.0022630000000000003
# 月份 2015-03 - 主板股票数: 1664, dfin_standardized唯一值数: 1620
# 月份 2015-03 的无风险收益率: 0.0020599999999999998
# 月份 2015-04 - 主板股票数: 1669, dfin_standardized唯一值数: 1631
# 月份 2015-04 的无风险收益率: 0.0020599999999999998
# 月份 2015-05 - 主板股票数: 1649, dfin_standardized唯一值数: 1612
# 月份 2015-05 的无风险收益率: 0.0020599999999999998
# 月份 2015-06 - 主板股票数: 1604, dfin_standardized唯一值数: 1569
# 月份 2015-06 的无风险收益率: 0.001856
# 月份 2015-07 - 主板股票数: 1544, dfin_standardized唯一值数: 1509
# 月份 2015-07 的无风险收益率: 0.0016520000000000003
# 月份 2015-08 - 主板股票数: 1502, dfin_standardized唯一值数: 1468
# 月份 2015-08 的无风险收益率: 0.0016520000000000003
# 月份 2015-09 - 主板股票数: 1482, dfin_standardized唯一值数: 1448
# 月份 2015-09 的无风险收益率: 0.001447
# 月份 2015-10 - 主板股票数: 1489, dfin_standardized唯一值数: 1454
# 月份 2015-10 的无风险收益率: 0.001447
# 月份 2015-11 - 主板股票数: 1507, dfin_standardized唯一值数: 1470
# 月份 2015-11 的无风险收益率: 0.0012410000000000001
# 月份 2015-12 - 主板股票数: 1518, dfin_standardized唯一值数: 1481
# 月份 2015-12 的无风险收益率: 0.0012410000000000001
# 月份 2016-01 - 主板股票数: 1536, dfin_standardized唯一值数: 1498
# 月份 2016-01 的无风险收益率: 0.0012410000000000001
# 月份 2016-02 - 主板股票数: 1577, dfin_standardized唯一值数: 1535
# 月份 2016-02 的无风险收益率: 0.0012410000000000001
# 月份 2016-03 - 主板股票数: 1612, dfin_standardized唯一值数: 1569
# 月份 2016-03 的无风险收益率: 0.0012410000000000001
# 月份 2016-04 - 主板股票数: 1712, dfin_standardized唯一值数: 1688
# 月份 2016-04 的无风险收益率: 0.0012410000000000001
# 月份 2016-05 - 主板股票数: 1734, dfin_standardized唯一值数: 1711
# 月份 2016-05 的无风险收益率: 0.0012410000000000001
# 月份 2016-06 - 主板股票数: 1747, dfin_standardized唯一值数: 1724
# 月份 2016-06 的无风险收益率: 0.0012410000000000001
# 月份 2016-07 - 主板股票数: 1754, dfin_standardized唯一值数: 1731
# 月份 2016-07 的无风险收益率: 0.0012410000000000001
# 月份 2016-08 - 主板股票数: 1774, dfin_standardized唯一值数: 1751
# 月份 2016-08 的无风险收益率: 0.0012410000000000001
# 月份 2016-09 - 主板股票数: 1777, dfin_standardized唯一值数: 1754
# 月份 2016-09 的无风险收益率: 0.0012410000000000001
# 月份 2016-10 - 主板股票数: 1775, dfin_standardized唯一值数: 1752
# 月份 2016-10 的无风险收益率: 0.0012410000000000001
# 月份 2016-11 - 主板股票数: 1796, dfin_standardized唯一值数: 1772
# 月份 2016-11 的无风险收益率: 0.0012410000000000001
# 月份 2016-12 - 主板股票数: 1817, dfin_standardized唯一值数: 1790
# 月份 2016-12 的无风险收益率: 0.0012410000000000001
# 月份 2017-01 - 主板股票数: 1820, dfin_standardized唯一值数: 1794
# 月份 2017-01 的无风险收益率: 0.0012410000000000001
# 月份 2017-02 - 主板股票数: 1826, dfin_standardized唯一值数: 1801
# 月份 2017-02 的无风险收益率: 0.0012410000000000001
# 月份 2017-03 - 主板股票数: 1827, dfin_standardized唯一值数: 1802
# 月份 2017-03 的无风险收益率: 0.0012410000000000001
# 月份 2017-04 - 主板股票数: 1944, dfin_standardized唯一值数: 1909
# 月份 2017-04 的无风险收益率: 0.0012410000000000001
# 月份 2017-05 - 主板股票数: 1932, dfin_standardized唯一值数: 1897
# 月份 2017-05 的无风险收益率: 0.0012410000000000001
# 月份 2017-06 - 主板股票数: 1924, dfin_standardized唯一值数: 1889
# 月份 2017-06 的无风险收益率: 0.0012410000000000001
# 月份 2017-07 - 主板股票数: 1919, dfin_standardized唯一值数: 1884
# 月份 2017-07 的无风险收益率: 0.0012410000000000001
# 月份 2017-08 - 主板股票数: 1919, dfin_standardized唯一值数: 1885
# 月份 2017-08 的无风险收益率: 0.0012410000000000001
# 月份 2017-09 - 主板股票数: 1935, dfin_standardized唯一值数: 1900
# 月份 2017-09 的无风险收益率: 0.0012410000000000001
# 月份 2017-10 - 主板股票数: 1942, dfin_standardized唯一值数: 1907
# 月份 2017-10 的无风险收益率: 0.0012410000000000001
# 月份 2017-11 - 主板股票数: 1940, dfin_standardized唯一值数: 1905
# 月份 2017-11 的无风险收益率: 0.0012410000000000001
# 月份 2017-12 - 主板股票数: 1949, dfin_standardized唯一值数: 1914
# 月份 2017-12 的无风险收益率: 0.0012410000000000001
# 月份 2018-01 - 主板股票数: 1948, dfin_standardized唯一值数: 1913
# 月份 2018-01 的无风险收益率: 0.0012410000000000001
# 月份 2018-02 - 主板股票数: 1955, dfin_standardized唯一值数: 1919
# 月份 2018-02 的无风险收益率: 0.0012410000000000001
# 月份 2018-03 - 主板股票数: 1941, dfin_standardized唯一值数: 1907
# 月份 2018-03 的无风险收益率: 0.0012410000000000001
# 月份 2018-04 - 主板股票数: 2054, dfin_standardized唯一值数: 2030
# 月份 2018-04 的无风险收益率: 0.0012410000000000001
# 月份 2018-05 - 主板股票数: 2045, dfin_standardized唯一值数: 2022
# 月份 2018-05 的无风险收益率: 0.0012410000000000001
# 月份 2018-06 - 主板股票数: 2047, dfin_standardized唯一值数: 2023
# 月份 2018-06 的无风险收益率: 0.0012410000000000001
# 月份 2018-07 - 主板股票数: 2037, dfin_standardized唯一值数: 2013
# 月份 2018-07 的无风险收益率: 0.0012410000000000001
# 月份 2018-08 - 主板股票数: 2065, dfin_standardized唯一值数: 2040
# 月份 2018-08 的无风险收益率: 0.0012410000000000001
# 月份 2018-09 - 主板股票数: 2085, dfin_standardized唯一值数: 2059
# 月份 2018-09 的无风险收益率: 0.0012410000000000001
# 月份 2018-10 - 主板股票数: 2133, dfin_standardized唯一值数: 2106
# 月份 2018-10 的无风险收益率: 0.0012410000000000001
# 月份 2018-11 - 主板股票数: 2165, dfin_standardized唯一值数: 2138
# 月份 2018-11 的无风险收益率: 0.0012410000000000001
# 月份 2018-12 - 主板股票数: 2198, dfin_standardized唯一值数: 2170
# 月份 2018-12 的无风险收益率: 0.0012410000000000001
# 月份 2019-01 - 主板股票数: 2230, dfin_standardized唯一值数: 2202
# 月份 2019-01 的无风险收益率: 0.0012410000000000001
# 月份 2019-02 - 主板股票数: 2249, dfin_standardized唯一值数: 2221
# 月份 2019-02 的无风险收益率: 0.0012410000000000001
# 月份 2019-03 - 主板股票数: 2266, dfin_standardized唯一值数: 2238
# 月份 2019-03 的无风险收益率: 0.0012410000000000001
# 月份 2019-04 - 主板股票数: 2436, dfin_standardized唯一值数: 2403
# 月份 2019-04 的无风险收益率: 0.0012410000000000001
# 月份 2019-05 - 主板股票数: 2442, dfin_standardized唯一值数: 2409
# 月份 2019-05 的无风险收益率: 0.0012410000000000001
# 月份 2019-06 - 主板股票数: 2442, dfin_standardized唯一值数: 2409
# 月份 2019-06 的无风险收益率: 0.0012410000000000001
# 月份 2019-07 - 主板股票数: 2442, dfin_standardized唯一值数: 2409
# 月份 2019-07 的无风险收益率: 0.0012410000000000001
# 月份 2019-08 - 主板股票数: 2442, dfin_standardized唯一值数: 2409
# 月份 2019-08 的无风险收益率: 0.0012410000000000001
# 月份 2019-09 - 主板股票数: 2442, dfin_standardized唯一值数: 2409
# 月份 2019-09 的无风险收益率: 0.0012410000000000001
# 月份 2019-10 - 主板股票数: 2442, dfin_standardized唯一值数: 2409
# 月份 2019-10 的无风险收益率: 0.0012410000000000001
# 月份 2019-11 - 主板股票数: 2443, dfin_standardized唯一值数: 2410
# 月份 2019-11 的无风险收益率: 0.0012410000000000001
# 月份 2019-12 - 主板股票数: 2443, dfin_standardized唯一值数: 2410
# 月份 2019-12 的无风险收益率: 0.0012410000000000001
# 月份 2020-01 - 主板股票数: 2443, dfin_standardized唯一值数: 2410
# 月份 2020-01 的无风险收益率: 0.0012410000000000001
# 月份 2020-02 - 主板股票数: 2443, dfin_standardized唯一值数: 2410
# 月份 2020-02 的无风险收益率: 0.0012410000000000001
# 月份 2020-03 - 主板股票数: 2443, dfin_standardized唯一值数: 2410
# 月份 2020-03 的无风险收益率: 0.0012410000000000001
# 月份 2020-04 - 主板股票数: 2553, dfin_standardized唯一值数: 2532
# 月份 2020-04 的无风险收益率: 0.0012410000000000001
# 月份 2020-05 - 主板股票数: 2552, dfin_standardized唯一值数: 2531
# 月份 2020-05 的无风险收益率: 0.0012410000000000001
# 月份 2020-06 - 主板股票数: 2552, dfin_standardized唯一值数: 2531
# 月份 2020-06 的无风险收益率: 0.0012410000000000001
# 月份 2020-07 - 主板股票数: 2552, dfin_standardized唯一值数: 2531
# 月份 2020-07 的无风险收益率: 0.0012410000000000001
# 月份 2020-08 - 主板股票数: 2551, dfin_standardized唯一值数: 2530
# 月份 2020-08 的无风险收益率: 0.0012410000000000001
# 月份 2020-09 - 主板股票数: 2551, dfin_standardized唯一值数: 2530
# 月份 2020-09 的无风险收益率: 0.0012410000000000001
# 月份 2020-10 - 主板股票数: 2551, dfin_standardized唯一值数: 2530
# 月份 2020-10 的无风险收益率: 0.0012410000000000001
# 月份 2020-11 - 主板股票数: 2553, dfin_standardized唯一值数: 2532
# 月份 2020-11 的无风险收益率: 0.0012410000000000001
# 月份 2020-12 - 主板股票数: 2554, dfin_standardized唯一值数: 2533
# 月份 2020-12 的无风险收益率: 0.0012410000000000001
# 月份 2021-01 - 主板股票数: 2555, dfin_standardized唯一值数: 2534
# 月份 2021-01 的无风险收益率: 0.0012410000000000001
# 月份 2021-02 - 主板股票数: 2556, dfin_standardized唯一值数: 2535
# 月份 2021-02 的无风险收益率: 0.0012410000000000001
# 月份 2021-03 - 主板股票数: 2556, dfin_standardized唯一值数: 2535
# 月份 2021-03 的无风险收益率: 0.0012410000000000001
# 月份 2021-04 - 主板股票数: 2632, dfin_standardized唯一值数: 2610
# 月份 2021-04 的无风险收益率: 0.0012410000000000001
# 月份 2021-05 - 主板股票数: 2633, dfin_standardized唯一值数: 2611
# 月份 2021-05 的无风险收益率: 0.0012410000000000001
# 月份 2021-06 - 主板股票数: 2633, dfin_standardized唯一值数: 2611
# 月份 2021-06 的无风险收益率: 0.0012410000000000001
# 月份 2021-07 - 主板股票数: 2633, dfin_standardized唯一值数: 2611
# 月份 2021-07 的无风险收益率: 0.0012410000000000001
# 月份 2021-08 - 主板股票数: 2633, dfin_standardized唯一值数: 2611
# 月份 2021-08 的无风险收益率: 0.0012410000000000001
# 月份 2021-09 - 主板股票数: 2633, dfin_standardized唯一值数: 2611
# 月份 2021-09 的无风险收益率: 0.0012410000000000001
# 月份 2021-10 - 主板股票数: 2633, dfin_standardized唯一值数: 2611
# 月份 2021-10 的无风险收益率: 0.0012410000000000001
# 月份 2021-11 - 主板股票数: 2633, dfin_standardized唯一值数: 2611
# 月份 2021-11 的无风险收益率: 0.0012410000000000001
# 月份 2021-12 - 主板股票数: 2633, dfin_standardized唯一值数: 2611
# 月份 2021-12 的无风险收益率: 0.0012410000000000001
# 月份 2022-01 - 主板股票数: 2634, dfin_standardized唯一值数: 2612
# 月份 2022-01 的无风险收益率: 0.0012410000000000001
# 月份 2022-02 - 主板股票数: 2634, dfin_standardized唯一值数: 2612
# 月份 2022-02 的无风险收益率: 0.0012410000000000001
# 月份 2022-03 - 主板股票数: 2634, dfin_standardized唯一值数: 2612
# 月份 2022-03 的无风险收益率: 0.0012410000000000001
# 月份 2022-04 - 主板股票数: 2802, dfin_standardized唯一值数: 2788
# 月份 2022-04 的无风险收益率: 0.0012410000000000001
# 月份 2022-05 - 主板股票数: 2802, dfin_standardized唯一值数: 2788
# 月份 2022-05 的无风险收益率: 0.0012410000000000001
# 月份 2022-06 - 主板股票数: 2801, dfin_standardized唯一值数: 2787
# 月份 2022-06 的无风险收益率: 0.0012410000000000001
# 月份 2022-07 - 主板股票数: 2801, dfin_standardized唯一值数: 2787
# 月份 2022-07 的无风险收益率: 0.0012410000000000001
# 月份 2022-08 - 主板股票数: 2801, dfin_standardized唯一值数: 2787
# 月份 2022-08 的无风险收益率: 0.0012410000000000001
# 月份 2022-09 - 主板股票数: 2801, dfin_standardized唯一值数: 2787
# 月份 2022-09 的无风险收益率: 0.0012410000000000001
# 月份 2022-10 - 主板股票数: 2801, dfin_standardized唯一值数: 2787
# 月份 2022-10 的无风险收益率: 0.0013650000000000001
# 月份 2022-11 - 主板股票数: 2801, dfin_standardized唯一值数: 2787
# 月份 2022-11 的无风险收益率: 0.0013650000000000001
# 月份 2022-12 - 主板股票数: 2802, dfin_standardized唯一值数: 2788
# 月份 2022-12 的无风险收益率: 0.0013650000000000001
# 月份 2023-01 - 主板股票数: 2803, dfin_standardized唯一值数: 2789
# 月份 2023-01 的无风险收益率: 0.0013650000000000001
# 月份 2023-02 - 主板股票数: 2803, dfin_standardized唯一值数: 2789
# 月份 2023-02 的无风险收益率: 0.0013650000000000001
# 月份 2023-03 - 主板股票数: 2803, dfin_standardized唯一值数: 2789
# 月份 2023-03 的无风险收益率: 0.0013650000000000001
# 月份 2023-04 - 主板股票数: 2987, dfin_standardized唯一值数: 2983
# 月份 2023-04 的无风险收益率: 0.0013650000000000001
# 月份 2023-05 - 主板股票数: 2984, dfin_standardized唯一值数: 2980
# 月份 2023-05 的无风险收益率: 0.0013650000000000001
# 月份 2023-06 - 主板股票数: 2984, dfin_standardized唯一值数: 2980
# 月份 2023-06 的无风险收益率: 0.0013650000000000001
# 月份 2023-07 - 主板股票数: 2984, dfin_standardized唯一值数: 2980
# 月份 2023-07 的无风险收益率: 0.0013650000000000001
# 月份 2023-08 - 主板股票数: 2984, dfin_standardized唯一值数: 2980
# 月份 2023-08 的无风险收益率: 0.0013650000000000001
# 月份 2023-09 - 主板股票数: 2984, dfin_standardized唯一值数: 2980
# 月份 2023-09 的无风险收益率: 0.001283
# 月份 2023-10 - 主板股票数: 2984, dfin_standardized唯一值数: 2980
# 月份 2023-10 的无风险收益率: 0.001283
# 月份 2023-11 - 主板股票数: 2986, dfin_standardized唯一值数: 2982
# 月份 2023-11 的无风险收益率: 0.001283
# 月份 2023-12 - 主板股票数: 2987, dfin_standardized唯一值数: 2983
# 月份 2023-12 的无风险收益率: 0.001283
# 月份 2024-01 - 主板股票数: 2987, dfin_standardized唯一值数: 2983
# 月份 2024-01 的无风险收益率: 0.001283
# 月份 2024-02 - 主板股票数: 2985, dfin_standardized唯一值数: 2981
# 月份 2024-02 的无风险收益率: 0.001283
# dfin_standardized 投资组合完成，生成记录数: 225
# dfin_standardized 投资组合已导出至 output\dfin_standardized.xlsx
#
# 所有投资组合已完成，结果存储在 output 目录。
